# %%
recipe_id_name = "sauce_raspberry_curd"

recipe_ru_name = "Малиновый курд"
recipe_time_ru = "30 мин"
recipe_portion_ru = "200 - 220 г"
ingredients_ru = [
    "150 г малины (свежей или замороженной)",
    "2 яйца",
    "50 г сахара",
    "30 сливочного масла",
    "2 ст.л. лимонного сока"
]

instruction_ru = [
"Пробейте блендером малину и протрите через сито, чтобы удалить косточки.",
"Взбейте яйца с половиной сахара.",
"В кастрюлю выложите малиновое пюре, лимонный сок и вторую половину сахара. Нагрейте почти до кипения.",
"Осторожно, постоянно помешивая яйца, влейте 1/3 горячего малинового пюре в яичную смесь. Эта процедура нужна, чтобы яйца не свернулись.",
"Тонкой струйкой, постоянно помешивая, влейте темперированную яичную смесь обратно в оставшееся пюре и, не переставая мешать, варите на очень медленном огне до появления характерных пыхов (как у заварного крема), то есть до загустения.",
"Слегка остудите крем, добавьте кусочки мягкого сливочного масла и очень хорошо взбейте венчиком.",
"Накройте пищевой пленкой так, чтобы она касалась поверхности крема, оставьте до полного остывания.",
]

note_ru = "Отличная начинка для для <a href='dessert_napoleon_cake.html' class='elegant-link keep-link'>dessert_cupcake_creamchease_straberry_jam</a> или как добавка к <a href='breakfast_oat_porridge.html' class='elegant-link keep-link'>овсяной каше</a>."

recipe_eng_name = "Raspberry Curd"
recipe_time_eng = "30 minutes"
recipe_portion_eng = "200 - 220 g"

ingredients_eng = [
    "150 g raspberries (fresh or frozen)",
    "2 eggs",
    "50 g sugar",
    "30 g butter",
    "2 tbsp lemon juice"
]

instruction_eng = [
    "Blend the raspberries and strain the puree through a sieve to remove the seeds.",
    "Whisk the eggs with half of the sugar.",
    "In a saucepan, combine the raspberry puree, lemon juice, and the remaining sugar. Heat until just below boiling.",
    "Carefully temper the eggs: while constantly whisking the egg mixture, slowly pour in about one-third of the hot raspberry puree. This prevents the eggs from curdling.",
    "In a thin stream, pour the tempered egg mixture back into the remaining puree, stirring constantly. Cook over very low heat until it thickens and begins to release gentle bubbles, similar to custard.",
    "Let the cream cool slightly, then add the softened butter in pieces and whisk thoroughly until smooth.",
    "Cover with plastic wrap touching the surface of the cream and leave to cool completely."
]

note_eng = "A wonderful filling for <a href='dessert_napoleon_cake.html' class='elegant-link keep-link'>cupcakes with cream cheese and strawberry jam</a> or as an addition to <a href='breakfast_oat_porridge.html' class='elegant-link keep-link'>oatmeal</a>."

# %% [markdown]
# # Организационные вопросики

# %%
index_html_output = f'''
                    <!-- Рецепт {recipe_ru_name} -->
                    <a href="recipes/{recipe_id_name}.html" class="recipe-card"> 
                        <div class="recipe-image">
                            <img src="site-photos/{recipe_id_name}.jpg" alt="{recipe_ru_name}"> 
                            <div class="recipe-overlay">
                                <i class="fas fa-external-link-alt"></i>
                            </div>
                        </div>
                        <div class="recipe-info">
                            <h3>{recipe_ru_name}</h3> 
                            <p class="recipe-time"><i class="far fa-clock"></i> {recipe_time_ru} </p> 
                        </div>
                    </a>
                    <!-- Рецепт {recipe_ru_name} конец -->
                    
                    '''

# %%
ingredients_spin_new_html = ''
for ing_list_length in ingredients_ru:
    ingredients_spin_new_html += "<li>" + ing_list_length + "</li> \n"

instruction_spin_new_html = ''
for inst_list_length in instruction_ru:
    instruction_spin_new_html += "<li>" + inst_list_length + "</li> \n"

# %%
if note_ru != '':
    notes_new_html = f'''
                <div class="note">
                <p><strong>Совет:</strong> {note_ru} </p>
                </div>'''
else:
    notes_new_html = ''

# %%
print(ingredients_spin_new_html)
print(instruction_spin_new_html)
# Out:
# <li>500 мл молока</li>
# <li>150 г сахара</li>
# <li>2 яйца</li>
# <li>40 г муки</li>
# <li>10 г ванильного сахара</li>
# <li>100 сливочного масла</li>
#
# <li>Достаньте из холодильника сливочное масло, чтобы оно размягчилось.</li>
# <li>В небольшой кастрюле венчиком взбейте муку, сахар, ванильный сахар и яйца до получения однородной массы.</li>
# <li>Постепенно влейте небольшое количество молока, тщательно взбивая, чтобы не было комочков.</li>
# <li>Продолжая взбивать, добавьте оставшееся молоко и перемешайте до полной однородности.</li>
# <li>Поставьте кастрюлю на медленный огонь. Варите, постоянно помешивая (особенно тщательно по дну), чтобы не образовались комочки.</li>
# <li>Когда заварной крем загустеет и вот-вот начнет закипать, снимите его с огня.</li>
# <li>Добавьте в горячий крем размягченное сливочное масло и перемешивайте, пока оно полностью не растает и не вмешается.</li>
# <li>Перелейте крем в широкую миску для более быстрого остывания. Накройте пищевой пленкой так, чтобы она касалась поверхности крема (это предотвратит образование корочки). Оставьте остывать на 2–3 часа.</li>

# %%
styler_text = '''<style>
        .recipe-page {
            max-width: 800px;
            margin: 40px auto;
            padding: 0 20px;
        }
        
        .back-link {
            display: inline-flex;
            align-items: center;
            gap: 8px;
            color: #8b4513;
            text-decoration: none;
            margin-bottom: 20px;
            font-weight: 500;
        }
        
        .back-link:hover {
            text-decoration: underline;
        }
        
        .recipe-header {
            text-align: center;
            margin-bottom: 40px;
        }
        
        .recipe-header h1 {
            color: #8b4513;
            font-size: 2.5rem;
            margin-bottom: 10px;
        }
        
        .recipe-meta {
            display: flex;
            justify-content: center;
            gap: 30px;
            color: #666;
            margin-bottom: 30px;
        }
        
        .recipe-image-main {
            width: 100%;
            height: 400px;
            object-fit: cover;
            border-radius: 15px;
            margin-bottom: 30px;
            box-shadow: 0 10px 25px rgba(0, 0, 0, 0.1);
        }
        
        .recipe-content {
            background: white;
            padding: 40px;
            border-radius: 15px;
            box-shadow: 0 5px 20px rgba(0, 0, 0, 0.05);
        }
        
        .ingredients, .instructions {
            margin-bottom: 40px;
        }
        
        .ingredients h2, .instructions h2 {
            color: #8b4513;
            border-bottom: 2px solid #f0e6d6;
            padding-bottom: 10px;
            margin-bottom: 20px;
        }
        
        .ingredients ul {
            list-style: none;
            padding: 0;
        }
        
        .ingredients li {
            padding: 8px 0;
            padding-left: 30px;
            position: relative;
            border-bottom: 1px solid #f0e6d6;
        }
        
        .ingredients li:before {
            content: "•";
            position: absolute;
            left: 0;
        }
        
        .instructions ol {
            padding-left: 20px;
        }
        
        .instructions li {
            margin-bottom: 15px;
            line-height: 1.6;
        }
        
        .note {
            background: #f9f3ec;
            padding: 20px;
            border-radius: 10px;
            border-left: 4px solid #d4a574;
            margin-top: 30px;
        }
    </style>'''

# %%
new_html_page_output = f'''
<!DOCTYPE html>
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>{recipe_ru_name} - Кулинарные заметки</title>
    <!-- Favicon (иконка вкладки) -->
    <link rel="icon" href="../assets/icons/icons8-girl-64.png" type="image/png">
    <link rel="stylesheet" href="../style.css">
    <script src="../script.js" defer></script>
    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css">
    {styler_text}
</head>
<body>
    <header class="main-header">
        <div class="header-top"> 
            <h1>Кулинарные заметки</h1>
        </div>
    </header>

    <main class="recipe-page">
        <a href="../index.html" class="back-link">
            <i class="fas fa-arrow-left"></i>
            Вернуться к рецептам
        </a>
        
        <div class="recipe-header">
            <h1>{recipe_ru_name}</h1>
            <div class="recipe-meta">
                <span><i class="far fa-clock"></i> {recipe_time_ru}</span>
                <span><i class="fas fa-user-friends"></i> {recipe_portion_ru}</span>
                
            </div>
        </div>
        
        <img src="../site-photos/{recipe_id_name}.jpg" 
             alt="{recipe_ru_name}" class="recipe-image-main">
        
        <div class="recipe-content">
            <div class="ingredients">
                <h2><i class="fas fa-shopping-basket"></i> Ингредиенты</h2>
                <ul>
                    {ingredients_spin_new_html}
                    

                </ul>
            </div>
            
            <div class="instructions">
                <h2><i class="fas fa-list-ol"></i> Способ приготовления</h2>
                <ol>
                    {instruction_spin_new_html}
                </ol>
            </div>
            
            {notes_new_html}
            
        </div>
    </main>

    <footer class="main-footer">
        <div class="footer-content">
            <div class="footer-lang-switcher">
                <button class="footer-lang-btn active" data-lang="ru">RU</button>
                <button class="footer-lang-btn" data-lang="en">EN</button>
            </div>
            <p>2026 Кулинарные заметки</p>
            <p class="footer-note">С любовью к вкусной еде ❤️</p>
        </div>
    </footer>

    <script src="../translations.js" defer></script>
    <script src="../script.js" defer></script>
</body>
</html>'''

# %%
meal_name_translation = f'''
        "{recipe_ru_name}": '''
meal_name_translation += '''{ '''
meal_name_translation += f''' 
            ru: "{recipe_ru_name}",
            en: "{recipe_eng_name}"'''
meal_name_translation += '''
            },'''

# %%
ingredient_shift_ru = ''
for ingredient_list in ingredients_ru:
    ingredient_shift_ru += '"' + ingredient_list + '", \n'

instruction_shift_ru = ''
for instruction_list in instruction_ru:
    instruction_shift_ru += '"' + instruction_list + '", \n'

ingredient_shift_eng = ''
for ingredient_list in ingredients_eng:
    ingredient_shift_eng += '"' + ingredient_list + '", \n'

instruction_shift_eng = ''
for instruction_list in instruction_eng:
    instruction_shift_eng += '"' + instruction_list + '", \n'

# %%
recipedetail_new_text = f'''
        "{recipe_id_name}": '''

recipedetail_new_text += ''' {
            ru: {
                title:'''
recipedetail_new_text += f''' "{recipe_ru_name}",
                meta: '''
recipedetail_new_text += ''' {
                    time: '''
recipedetail_new_text += f'''"{recipe_time_ru}",
                    servings: "{recipe_portion_ru}"
                 '''       
recipedetail_new_text += ''' },
                ingredients: [
                '''    
recipedetail_new_text += f'''{ingredient_shift_ru}
                ],
                instructions: [
                {instruction_shift_ru}
                ],
                note: "{note_ru}"
            '''     
recipedetail_new_text += ''' },
            en: {
                title:'''
recipedetail_new_text += f''' "{recipe_eng_name}",
                meta: '''
recipedetail_new_text += ''' {
                    time: '''
recipedetail_new_text += f'''"{recipe_time_eng}",
                    servings: "{recipe_portion_eng}"
                 '''       
recipedetail_new_text += ''' },
                ingredients: [
                '''    
recipedetail_new_text += f'''{ingredient_shift_eng}
                ],
                instructions: [
                {instruction_shift_eng}
                ],
                note: "{note_eng}"
            '''     
recipedetail_new_text += ''' }
        },'''

# %%
sript_js_add = f""" else if (path.includes('{recipe_id_name}')) """
sript_js_add += '''{
'''
sript_js_add += f"""recipeKey = '{recipe_id_name}';
"""
sript_js_add += '''}'''

# %% [markdown]
# # Добавление рецепта

# %% [markdown]
# ### 1. Добавляем в соответствующем месте в index.html следующее:

# %%
print(index_html_output)
# Out:
#                     <!-- Рецепт Заварной крем -->
#                     <a href="recipes/sauce_custard.html" class="recipe-card">
#                         <div class="recipe-image">
#                             <img src="site-photos/sauce_custard.jpg" alt="Заварной крем">
#                             <div class="recipe-overlay">
#                                 <i class="fas fa-external-link-alt"></i>
#                             </div>
#                         </div>
#                         <div class="recipe-info">
#                             <h3>Заварной крем</h3>
#                             <p class="recipe-time"><i class="far fa-clock"></i> 80 мин </p>
#                         </div>
#                     </a>
#                     <!-- Рецепт Заварной крем конец -->

# %% [markdown]
# ### 2.Далее создаем файл с названием:

# %%
print(recipe_id_name+'.html')
# Out:
# sauce_custard.html

# %% [markdown]
# ### 3. В новый файл вставляем следующее:

# %%
print(new_html_page_output)
# Out:
# <!DOCTYPE html>
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Заварной крем - Кулинарные заметки</title>
#     <!-- Favicon (иконка вкладки) -->
#     <link rel="icon" href="../assets/icons/icons8-girl-64.png" type="image/png">
#     <link rel="stylesheet" href="../style.css">
#     <script src="../script.js" defer></script>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css">
#     <style>
#         .recipe-page {
#             max-width: 800px;
#             margin: 40px auto;
#             padding: 0 20px;
#         }
#
#         .back-link {
#             display: inline-flex;
#             align-items: center;
#             gap: 8px;
#             color: #8b4513;
#             text-decoration: none;
#             margin-bottom: 20px;
#             font-weight: 500;
#         }
#
#         .back-link:hover {
#             text-decoration: underline;
#         }
#
#         .recipe-header {
#             text-align: center;
#             margin-bottom: 40px;
#         }
#
#         .recipe-header h1 {
#             color: #8b4513;
#             font-size: 2.5rem;
#             margin-bottom: 10px;
#         }
#
#         .recipe-meta {
#             display: flex;
#             justify-content: center;
#             gap: 30px;
#             color: #666;
#             margin-bottom: 30px;
#         }
#
#         .recipe-image-main {
#             width: 100%;
#             height: 400px;
#             object-fit: cover;
#             border-radius: 15px;
#             margin-bottom: 30px;
#             box-shadow: 0 10px 25px rgba(0, 0, 0, 0.1);
#         }
#
#         .recipe-content {
#             background: white;
#             padding: 40px;
#             border-radius: 15px;
#             box-shadow: 0 5px 20px rgba(0, 0, 0, 0.05);
#         }
#
#         .ingredients, .instructions {
#             margin-bottom: 40px;
#         }
#
#         .ingredients h2, .instructions h2 {
#             color: #8b4513;
#             border-bottom: 2px solid #f0e6d6;
#             padding-bottom: 10px;
#             margin-bottom: 20px;
#         }
#
#         .ingredients ul {
#             list-style: none;
#             padding: 0;
#         }
#
#         .ingredients li {
#             padding: 8px 0;
#             padding-left: 30px;
#             position: relative;
#             border-bottom: 1px solid #f0e6d6;
#         }
#
#         .ingredients li:before {
#             content: "•";
#             position: absolute;
#             left: 0;
#         }
#
#         .instructions ol {
#             padding-left: 20px;
#         }
#
#         .instructions li {
#             margin-bottom: 15px;
#             line-height: 1.6;
#         }
#
#         .note {
#             background: #f9f3ec;
#             padding: 20px;
#             border-radius: 10px;
#             border-left: 4px solid #d4a574;
#             margin-top: 30px;
#         }
#     </style>
# </head>
# <body>
#     <header class="main-header">
#         <div class="header-top">
#             <h1>Кулинарные заметки</h1>
#         </div>
#     </header>
#
#     <main class="recipe-page">
#         <a href="../index.html" class="back-link">
#             <i class="fas fa-arrow-left"></i>
#             Вернуться к рецептам
#         </a>
#
#         <div class="recipe-header">
#             <h1>Заварной крем</h1>
#             <div class="recipe-meta">
#                 <span><i class="far fa-clock"></i> 80 мин</span>
#                 <span><i class="fas fa-user-friends"></i> 850 - 900 г</span>
#
#             </div>
#         </div>
#
#         <img src="../site-photos/sauce_custard.jpg"
#              alt="Заварной крем" class="recipe-image-main">
#
#         <div class="recipe-content">
#             <div class="ingredients">
#                 <h2><i class="fas fa-shopping-basket"></i> Ингредиенты</h2>
#                 <ul>
#                     <li>500 мл молока</li>
# <li>150 г сахара</li>
# <li>2 яйца</li>
# <li>40 г муки</li>
# <li>10 г ванильного сахара</li>
# <li>100 сливочного масла</li>
#
#
#
#                 </ul>
#             </div>
#
#             <div class="instructions">
#                 <h2><i class="fas fa-list-ol"></i> Способ приготовления</h2>
#                 <ol>
#                     <li>Достаньте из холодильника сливочное масло, чтобы оно размягчилось.</li>
# <li>В небольшой кастрюле венчиком взбейте муку, сахар, ванильный сахар и яйца до получения однородной массы.</li>
# <li>Постепенно влейте небольшое количество молока, тщательно взбивая, чтобы не было комочков.</li>
# <li>Продолжая взбивать, добавьте оставшееся молоко и перемешайте до полной однородности.</li>
# <li>Поставьте кастрюлю на медленный огонь. Варите, постоянно помешивая (особенно тщательно по дну), чтобы не образовались комочки.</li>
# <li>Когда заварной крем загустеет и вот-вот начнет закипать, снимите его с огня.</li>
# <li>Добавьте в горячий крем размягченное сливочное масло и перемешивайте, пока оно полностью не растает и не вмешается.</li>
# <li>Перелейте крем в широкую миску для более быстрого остывания. Накройте пищевой пленкой так, чтобы она касалась поверхности крема (это предотвратит образование корочки). Оставьте остывать на 2–3 часа.</li>
#
#                 </ol>
#             </div>
#
#
#                 <div class="note">
#                 <p><strong>Совет:</strong> Отличная основа для <a href='dessert_napoleon_cake.html' class='elegant-link keep-link'>наполеона</a> или <a href='dessert_profiterol.html' class='elegant-link keep-link'>профитролей</a>. </p>
#                 </div>
#
#         </div>
#     </main>
#
#     <footer class="main-footer">
#         <div class="footer-content">
#             <div class="footer-lang-switcher">
#                 <button class="footer-lang-btn active" data-lang="ru">RU</button>
#                 <button class="footer-lang-btn" data-lang="en">EN</button>
#             </div>
#             <p>2026 Кулинарные заметки</p>
#             <p class="footer-note">С любовью к вкусной еде ❤️</p>
#         </div>
#     </footer>
#
#     <script src="../translations.js" defer></script>
#     <script src="../script.js" defer></script>
# </body>
# </html>

# %% [markdown]
# ### 4. В файл translations.js добавляем в раздел с названиями блюд:

# %%
print(meal_name_translation)
# Out:
#         "Заварной крем": {
#             ru: "Заварной крем",
#             en: "Сustard Sauce"
#             },

# %% [markdown]
# ### 5. Затем в этом же файле вставляем в конце в разделе recipeDetails:

# %%
print(recipedetail_new_text)
# Out:
#         "sauce_custard":  {
#             ru: {
#                 title: "Заварной крем",
#                 meta:  {
#                     time: "80 мин",
#                     servings: "850 - 900 г"
#                   },
#                 ingredients: [
#                 "500 мл молока",
# "150 г сахара",
# "2 яйца",
# "40 г муки",
# "10 г ванильного сахара",
# "100 сливочного масла",
#
#                 ],
#                 instructions: [
#                 "Достаньте из холодильника сливочное масло, чтобы оно размягчилось.",
# "В небольшой кастрюле венчиком взбейте муку, сахар, ванильный сахар и яйца до получения однородной массы.",
# "Постепенно влейте небольшое количество молока, тщательно взбивая, чтобы не было комочков.",
# "Продолжая взбивать, добавьте оставшееся молоко и перемешайте до полной однородности.",
# "Поставьте кастрюлю на медленный огонь. Варите, постоянно помешивая (особенно тщательно по дну), чтобы не образовались комочки.",
# "Когда заварной крем загустеет и вот-вот начнет закипать, снимите его с огня.",
# "Добавьте в горячий крем размягченное сливочное масло и перемешивайте, пока оно полностью не растает и не вмешается.",
# "Перелейте крем в широкую миску для более быстрого остывания. Накройте пищевой пленкой так, чтобы она касалась поверхности крема (это предотвратит образование корочки). Оставьте остывать на 2–3 часа.",
#
#                 ],
#                 note: "Отличная основа для <a href='dessert_napoleon_cake.html' class='elegant-link keep-link'>наполеона</a> или <a href='dessert_profiterol.html' class='elegant-link keep-link'>профитролей</a>."
#              },
#             en: {
#                 title: "Сustard Sauce",
#                 meta:  {
#                     time: "80 minutes",
#                     servings: "850 - 900 g"
#                   },
#                 ingredients: [
#                 "500 ml milk",
# "150 g sugar",
# "2 eggs",
# "40 g flour",
# "10 g vanilla sugar",
# "100 g butter",
#
#                 ],
#                 instructions: [
#                 "Take the butter out of the refrigerator so it can soften.",
# "In a small saucepan, whisk together the flour, sugar, vanilla sugar, and eggs until smooth.",
# "Gradually pour in a small amount of milk, whisking thoroughly to prevent lumps.",
# "While continuing to whisk, add the remaining milk and mix until completely smooth.",
# "Place the saucepan over low heat. Cook while stirring constantly (especially along the bottom) to prevent lumps from forming.",
# "When the custard thickens and is just about to boil, remove it from the heat.",
# "Add the softened butter to the hot custard and stir until it has completely melted and incorporated.",
# "Transfer the cream to a wide bowl so it cools faster. Cover with plastic wrap touching the surface of the cream (this prevents a skin from forming) and let it cool for 2–3 hours.",
#
#                 ],
#                 note: "An excellent base for <a href='dessert_napoleon_cake.html' class='elegant-link keep-link'>Napoleon cake</a> or <a href='dessert_profiterol.html' class='elegant-link keep-link'>profiteroles</a>."
#              }
#         },

# %% [markdown]
# ### 6. На последнем этапе в файл script.js d поискать много else if и в конце добавить следующее:

# %%
print(sript_js_add)
# Out:
#  else if (path.includes('sauce_custard')) {
# recipeKey = 'sauce_custard';
# }
