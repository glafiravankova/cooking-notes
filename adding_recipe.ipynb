# %%
recipe_id_name = "dessert_panna_cotta"

recipe_ru_name = "Панна-котта c клубничным джемом"
recipe_time_ru = "240 мин"
recipe_portion_ru = "4 порций"
ingredients_ru = [
    "Для панна-котты:",
    "300 г 20% сливок",
    "100 г молока",
    "50 г сахара",
    "50 г воды",
    "10 г желатина", 
    "Для джема:"
    "250 г замороженной клубники",
    "30 г сахарной пудры",
    "5 г крахмала"
]

instruction_ru = [
    "Замочите желатин в холодной воде.Замочите желатин в холодной воде.",
    "В кастрюле смешайте сливки, молоко, сахар и ванильный сахар и доведите до 70°С. Снимите кастрюлю с плиты.",
    "Добавьте размягченный желатин в горячую смесь и перемешайте до полного растворения.",
    "Разлейте кремовую смесь по порционным формочкам. Удобно сначала взвесить смесь и разделить ее на количество порций, исходя из размера используемой посуды.",
    "Дайте ей немного остыть при комнатной температуре, затем поставьте в холодильник на 2 часа.",
    "Добавьте размягченное сливочное масло в горячий заварной крем и перемешивайте, пока оно полностью не растает.",
    "Затем измельчите клубнику, процедите ее через сито в кастрюлю и добавьте сахарную пудру.",
    "Взвесьте клубничную массу, разделите ее на равные порции и вылейте поверх слоя крема.",
    "Поставьте в холодильник еще на 2 часа до полного застывания. "
]

note_ru = ""

recipe_eng_name = "Panna Cotta with Strawberry Jam"
recipe_time_eng = "240 minutes"
recipe_portion_eng = "Serves 4"

ingredients_eng = [
    "For the panna cotta:",
    "300 g 20% cream",
    "100 g milk",
    "50 g sugar",
    "50 g water",
    "10 g gelatin",
    " ",
    "For the jam:",
    "250 g frozen strawberries",
    "30 g icing sugar",
    "5 g starch"
]

instruction_eng = [
    "Soak the gelatin in cold water and leave it to bloom.",
    "In a saucepan, combine the cream, milk, sugar, and (optionally) vanilla sugar, then heat gently to about 70°C. Remove from the heat.",
    "Add the softened gelatin to the hot mixture and stir until completely dissolved.",
    "Pour the mixture into serving moulds. For precision, you may weigh the mixture and divide it evenly according to the number of portions.",
    "Allow it to cool slightly at room temperature, then refrigerate for about 2 hours.",
    "Prepare the jam by blending the strawberries and straining the purée into a saucepan. Add the icing sugar.",
    "Heat the mixture gently until slightly thickened, then cool to room temperature.",
    "Divide the strawberry layer evenly and pour it over the chilled panna cotta.",
    "Return to the refrigerator for a further 2 hours, or until fully set."
]

note_eng = "Other berries may be used in place of strawberries if desired."

# %% [markdown]
# # Организационные вопросики

# %%
index_html_output = f'''
                    <!-- Рецепт {recipe_ru_name} -->
                    <a href="recipes/{recipe_id_name}.html" class="recipe-card"> 
                        <div class="recipe-image">
                            <img src="site-photos/{recipe_id_name}.jpg" alt="{recipe_ru_name}"> 
                            <div class="recipe-overlay">
                                <i class="fas fa-external-link-alt"></i>
                            </div>
                        </div>
                        <div class="recipe-info">
                            <h3>{recipe_ru_name}</h3> 
                            <p class="recipe-time"><i class="far fa-clock"></i> {recipe_time_ru} </p> 
                        </div>
                    </a>
                    <!-- Рецепт {recipe_ru_name} конец -->
                    
                    '''

# %%
ingredients_spin_new_html = ''
for ing_list_length in ingredients_ru:
    ingredients_spin_new_html += "<li>" + ing_list_length + "</li> \n"

instruction_spin_new_html = ''
for inst_list_length in instruction_ru:
    instruction_spin_new_html += "<li>" + inst_list_length + "</li> \n"

# %%
if note_ru != '':
    notes_new_html = f'''
                <div class="note">
                <p><strong>Совет:</strong> {note_ru} </p>
                </div>'''
else:
    notes_new_html = ''

# %%
print(ingredients_spin_new_html)
print(instruction_spin_new_html)
# Out:
# <li>400 г слоеного теста</li>
# <li>Для заварного крема:</li>
# <li>500 мл молока</li>
# <li>150 г сахара</li>
# <li>100 г масла</li>
# <li>2 яйца</li>
# <li>40 г муки</li>
# <li>10 г ванильного сахара</li>
# <li>Для джема:100 г замороженной малины</li>
# <li>10 г сахара</li>
# <li>5 г крахмала</li>
#
# <li>Начните с крема, так как ему потребуется больше всего времени для остывания. В маленькой кастрюльке взбейте вместе муку, сахар, ванильный сахар и яйца до получения однородной массы.</li>
# <li>Постепенно влейте небольшое количество молока, тщательно взбивая, чтобы удалить комочки.</li>
# <li>Продолжайте добавлять оставшееся молоко, взбивая, пока смесь не станет полностью однородной.</li>
# <li>Поставьте кастрюлю на слабый огонь. Готовьте, постоянно помешивая, особенно по дну, чтобы не образовались комочки.</li>
# <li>Как только заварной крем загустеет и начнет закипать, снимите его с огня.</li>
# <li>Добавьте размягченное сливочное масло в горячий заварной крем и перемешивайте, пока оно полностью не растает.</li>
# <li>Переложите заварной крем в широкую миску, чтобы он быстрее остыл. Накройте пищевой пленкой в контакт.</li>
# <li>Перейдите к приготовлению джема. Разморозьте малину, пробейте в блендере и протрите через сито.</li>
# <li>Переложите малиновое пюре в сотейник, добавьте сахар и начните нагревать массу на среднем огне.</li>
# <li>Когда масса загустеет, перелейте соус в широкую тарелку, накройте пленкой в контакт и оставьте остывать при комнатной температуре.</li>
# <li>Перейдите к приготовлению коржей. Разогрейте духовку до 210°C. Разрежьте готовое слоеное тесто на несколько частей, чуть меньше высоты вашего блендера.</li>
# <li>Выложите слоеное тесто на противень, застеленный бумагой для выпечки.</li>
# <li>Поместите коржи в духовку на 10-12 минут, в зависимости от вашей духовки. Они будут готовы, когда появится золотистая корочка.</li>
# <li>Выньте коржи и положите их на решетку, чтобы они остыли.</li>
# <li>Когда коржи остынут, перебейте их в блендере в крошку.</li>
# <li>Когда крем и джем остынут, можете приступать к сборке десерта.</li>
# <li>На дно стакана выложите немного крема, затем крошку, немного прижмите крошку ложкой, чтобы ее уплотнить.</li>
# <li>Затем крем, джем, крем и снова крошка. Важно выкладывать крем сначала у стенок стаканчика, затем в середине, чтобы джем не мог протечь на нижние слои. Малиновый джем сам по себе имеет яркий вкус, поэтому его нужно значительно меньше, чем заварного крема.</li>
# <li>Повторяйте, пока не останется 1-1,5 см до края стаканчика.</li>
# <li>Последний слой должен быть крошкой от слоеного теста.</li>
# <li>Можете подавать сразу, если любите, чтобы крошка хрустела, либо если любите пропитанный наполеон, подождите не меньше 5 часов.</li>

# %%
styler_text = '''<style>
        .recipe-page {
            max-width: 800px;
            margin: 40px auto;
            padding: 0 20px;
        }
        
        .back-link {
            display: inline-flex;
            align-items: center;
            gap: 8px;
            color: #8b4513;
            text-decoration: none;
            margin-bottom: 20px;
            font-weight: 500;
        }
        
        .back-link:hover {
            text-decoration: underline;
        }
        
        .recipe-header {
            text-align: center;
            margin-bottom: 40px;
        }
        
        .recipe-header h1 {
            color: #8b4513;
            font-size: 2.5rem;
            margin-bottom: 10px;
        }
        
        .recipe-meta {
            display: flex;
            justify-content: center;
            gap: 30px;
            color: #666;
            margin-bottom: 30px;
        }
        
        .recipe-image-main {
            width: 100%;
            height: 400px;
            object-fit: cover;
            border-radius: 15px;
            margin-bottom: 30px;
            box-shadow: 0 10px 25px rgba(0, 0, 0, 0.1);
        }
        
        .recipe-content {
            background: white;
            padding: 40px;
            border-radius: 15px;
            box-shadow: 0 5px 20px rgba(0, 0, 0, 0.05);
        }
        
        .ingredients, .instructions {
            margin-bottom: 40px;
        }
        
        .ingredients h2, .instructions h2 {
            color: #8b4513;
            border-bottom: 2px solid #f0e6d6;
            padding-bottom: 10px;
            margin-bottom: 20px;
        }
        
        .ingredients ul {
            list-style: none;
            padding: 0;
        }
        
        .ingredients li {
            padding: 8px 0;
            padding-left: 30px;
            position: relative;
            border-bottom: 1px solid #f0e6d6;
        }
        
        .ingredients li:before {
            content: "•";
            position: absolute;
            left: 0;
        }
        
        .instructions ol {
            padding-left: 20px;
        }
        
        .instructions li {
            margin-bottom: 15px;
            line-height: 1.6;
        }
        
        .note {
            background: #f9f3ec;
            padding: 20px;
            border-radius: 10px;
            border-left: 4px solid #d4a574;
            margin-top: 30px;
        }
    </style>'''

# %%
new_html_page_output = f'''
<!DOCTYPE html>
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>{recipe_ru_name} - Кулинарные заметки</title>
    <!-- Favicon (иконка вкладки) -->
    <link rel="icon" href="../assets/icons/icons8-girl-64.png" type="image/png">
    <link rel="stylesheet" href="../style.css">
    <script src="../script.js" defer></script>
    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css">
    {styler_text}
</head>
<body>
    <header class="main-header">
        <div class="header-top"> 
            <h1>Кулинарные заметки</h1>
        </div>
    </header>

    <main class="recipe-page">
        <a href="../index.html" class="back-link">
            <i class="fas fa-arrow-left"></i>
            Вернуться к рецептам
        </a>
        
        <div class="recipe-header">
            <h1>{recipe_ru_name}</h1>
            <div class="recipe-meta">
                <span><i class="far fa-clock"></i> {recipe_time_ru}</span>
                <span><i class="fas fa-user-friends"></i> {recipe_portion_ru}</span>
                
            </div>
        </div>
        
        <img src="../site-photos/{recipe_id_name}.jpg" 
             alt="{recipe_ru_name}" class="recipe-image-main">
        
        <div class="recipe-content">
            <div class="ingredients">
                <h2><i class="fas fa-shopping-basket"></i> Ингредиенты</h2>
                <ul>
                    {ingredients_spin_new_html}
                    

                </ul>
            </div>
            
            <div class="instructions">
                <h2><i class="fas fa-list-ol"></i> Способ приготовления</h2>
                <ol>
                    {instruction_spin_new_html}
                </ol>
            </div>
            
            {notes_new_html}
            
        </div>
    </main>

    <footer class="main-footer">
        <div class="footer-content">
            <div class="footer-lang-switcher">
                <button class="footer-lang-btn active" data-lang="ru">RU</button>
                <button class="footer-lang-btn" data-lang="en">EN</button>
            </div>
            <p>2026 Кулинарные заметки</p>
            <p class="footer-note">С любовью к вкусной еде ❤️</p>
        </div>
    </footer>

    <script src="../translations.js" defer></script>
    <script src="../script.js" defer></script>
</body>
</html>'''

# %%
meal_name_translation = f'''
        "{recipe_ru_name}": '''
meal_name_translation += '''{ '''
meal_name_translation += f''' 
            ru: "{recipe_ru_name}",
            en: "{recipe_eng_name}"'''
meal_name_translation += '''
            },'''

# %%
ingredient_shift_ru = ''
for ingredient_list in ingredients_ru:
    ingredient_shift_ru += '"' + ingredient_list + '", \n'

instruction_shift_ru = ''
for instruction_list in instruction_ru:
    instruction_shift_ru += '"' + instruction_list + '", \n'

ingredient_shift_eng = ''
for ingredient_list in ingredients_eng:
    ingredient_shift_eng += '"' + ingredient_list + '", \n'

instruction_shift_eng = ''
for instruction_list in instruction_eng:
    instruction_shift_eng += '"' + instruction_list + '", \n'

# %%
recipedetail_new_text = f'''
        "{recipe_id_name}": '''

recipedetail_new_text += ''' {
            ru: {
                title:'''
recipedetail_new_text += f''' "{recipe_ru_name}",
                meta: '''
recipedetail_new_text += ''' {
                    time: '''
recipedetail_new_text += f'''"{recipe_time_ru}",
                    servings: "{recipe_portion_ru}"
                 '''       
recipedetail_new_text += ''' },
                ingredients: [
                '''    
recipedetail_new_text += f'''{ingredient_shift_ru}
                ],
                instructions: [
                {instruction_shift_ru}
                ],
                note: "{note_ru}"
            '''     
recipedetail_new_text += ''' },
            en: {
                title:'''
recipedetail_new_text += f''' "{recipe_eng_name}",
                meta: '''
recipedetail_new_text += ''' {
                    time: '''
recipedetail_new_text += f'''"{recipe_time_eng}",
                    servings: "{recipe_portion_eng}"
                 '''       
recipedetail_new_text += ''' },
                ingredients: [
                '''    
recipedetail_new_text += f'''{ingredient_shift_eng}
                ],
                instructions: [
                {instruction_shift_eng}
                ],
                note: "{note_eng}"
            '''     
recipedetail_new_text += ''' }
        },'''

# %%
sript_js_add = f""" else if (path.includes('{recipe_id_name}')) """
sript_js_add += '''{
'''
sript_js_add += f"""recipeKey = '{recipe_id_name}';
"""
sript_js_add += '''}'''

# %% [markdown]
# # Добавление рецепта

# %% [markdown]
# ### 1. Добавляем в соответствующем месте в index.html следующее:

# %%
print(index_html_output)
# Out:
#                     <!-- Рецепт Наполеон с малиновым джемом в стаканчике -->
#                     <a href="recipes/dessert_napoleon_individual.html" class="recipe-card">
#                         <div class="recipe-image">
#                             <img src="site-photos/dessert_napoleon_individual.jpg" alt="Наполеон с малиновым джемом в стаканчике">
#                             <div class="recipe-overlay">
#                                 <i class="fas fa-external-link-alt"></i>
#                             </div>
#                         </div>
#                         <div class="recipe-info">
#                             <h3>Наполеон с малиновым джемом в стаканчике</h3>
#                             <p class="recipe-time"><i class="far fa-clock"></i> 180 мин </p>
#                         </div>
#                     </a>
#                     <!-- Рецепт Наполеон с малиновым джемом в стаканчике конец -->

# %% [markdown]
# ### 2.Далее создаем файл с названием:

# %%
print(recipe_id_name+'.html')
# Out:
# dessert_napoleon_individual.html

# %% [markdown]
# ### 3. В новый файл вставляем следующее:

# %%
print(new_html_page_output)
# Out:
# <!DOCTYPE html>
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Наполеон с малиновым джемом в стаканчике - Кулинарные заметки</title>
#     <!-- Favicon (иконка вкладки) -->
#     <link rel="icon" href="../assets/icons/icons8-girl-64.png" type="image/png">
#     <link rel="stylesheet" href="../style.css">
#     <script src="../script.js" defer></script>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css">
#     <style>
#         .recipe-page {
#             max-width: 800px;
#             margin: 40px auto;
#             padding: 0 20px;
#         }
#
#         .back-link {
#             display: inline-flex;
#             align-items: center;
#             gap: 8px;
#             color: #8b4513;
#             text-decoration: none;
#             margin-bottom: 20px;
#             font-weight: 500;
#         }
#
#         .back-link:hover {
#             text-decoration: underline;
#         }
#
#         .recipe-header {
#             text-align: center;
#             margin-bottom: 40px;
#         }
#
#         .recipe-header h1 {
#             color: #8b4513;
#             font-size: 2.5rem;
#             margin-bottom: 10px;
#         }
#
#         .recipe-meta {
#             display: flex;
#             justify-content: center;
#             gap: 30px;
#             color: #666;
#             margin-bottom: 30px;
#         }
#
#         .recipe-image-main {
#             width: 100%;
#             height: 400px;
#             object-fit: cover;
#             border-radius: 15px;
#             margin-bottom: 30px;
#             box-shadow: 0 10px 25px rgba(0, 0, 0, 0.1);
#         }
#
#         .recipe-content {
#             background: white;
#             padding: 40px;
#             border-radius: 15px;
#             box-shadow: 0 5px 20px rgba(0, 0, 0, 0.05);
#         }
#
#         .ingredients, .instructions {
#             margin-bottom: 40px;
#         }
#
#         .ingredients h2, .instructions h2 {
#             color: #8b4513;
#             border-bottom: 2px solid #f0e6d6;
#             padding-bottom: 10px;
#             margin-bottom: 20px;
#         }
#
#         .ingredients ul {
#             list-style: none;
#             padding: 0;
#         }
#
#         .ingredients li {
#             padding: 8px 0;
#             padding-left: 30px;
#             position: relative;
#             border-bottom: 1px solid #f0e6d6;
#         }
#
#         .ingredients li:before {
#             content: "•";
#             position: absolute;
#             left: 0;
#         }
#
#         .instructions ol {
#             padding-left: 20px;
#         }
#
#         .instructions li {
#             margin-bottom: 15px;
#             line-height: 1.6;
#         }
#
#         .note {
#             background: #f9f3ec;
#             padding: 20px;
#             border-radius: 10px;
#             border-left: 4px solid #d4a574;
#             margin-top: 30px;
#         }
#     </style>
# </head>
# <body>
#     <header class="main-header">
#         <div class="header-top">
#             <h1>Кулинарные заметки</h1>
#         </div>
#     </header>
#
#     <main class="recipe-page">
#         <a href="../index.html" class="back-link">
#             <i class="fas fa-arrow-left"></i>
#             Вернуться к рецептам
#         </a>
#
#         <div class="recipe-header">
#             <h1>Наполеон с малиновым джемом в стаканчике</h1>
#             <div class="recipe-meta">
#                 <span><i class="far fa-clock"></i> 180 мин</span>
#                 <span><i class="fas fa-user-friends"></i> 9 порций</span>
#
#             </div>
#         </div>
#
#         <img src="../site-photos/dessert_napoleon_individual.jpg"
#              alt="Наполеон с малиновым джемом в стаканчике" class="recipe-image-main">
#
#         <div class="recipe-content">
#             <div class="ingredients">
#                 <h2><i class="fas fa-shopping-basket"></i> Ингредиенты</h2>
#                 <ul>
#                     <li>400 г слоеного теста</li>
# <li>Для заварного крема:</li>
# <li>500 мл молока</li>
# <li>150 г сахара</li>
# <li>100 г масла</li>
# <li>2 яйца</li>
# <li>40 г муки</li>
# <li>10 г ванильного сахара</li>
# <li>Для джема:100 г замороженной малины</li>
# <li>10 г сахара</li>
# <li>5 г крахмала</li>
#
#
#
#                 </ul>
#             </div>
#
#             <div class="instructions">
#                 <h2><i class="fas fa-list-ol"></i> Способ приготовления</h2>
#                 <ol>
#                     <li>Начните с крема, так как ему потребуется больше всего времени для остывания. В маленькой кастрюльке взбейте вместе муку, сахар, ванильный сахар и яйца до получения однородной массы.</li>
# <li>Постепенно влейте небольшое количество молока, тщательно взбивая, чтобы удалить комочки.</li>
# <li>Продолжайте добавлять оставшееся молоко, взбивая, пока смесь не станет полностью однородной.</li>
# <li>Поставьте кастрюлю на слабый огонь. Готовьте, постоянно помешивая, особенно по дну, чтобы не образовались комочки.</li>
# <li>Как только заварной крем загустеет и начнет закипать, снимите его с огня.</li>
# <li>Добавьте размягченное сливочное масло в горячий заварной крем и перемешивайте, пока оно полностью не растает.</li>
# <li>Переложите заварной крем в широкую миску, чтобы он быстрее остыл. Накройте пищевой пленкой в контакт.</li>
# <li>Перейдите к приготовлению джема. Разморозьте малину, пробейте в блендере и протрите через сито.</li>
# <li>Переложите малиновое пюре в сотейник, добавьте сахар и начните нагревать массу на среднем огне.</li>
# <li>Когда масса загустеет, перелейте соус в широкую тарелку, накройте пленкой в контакт и оставьте остывать при комнатной температуре.</li>
# <li>Перейдите к приготовлению коржей. Разогрейте духовку до 210°C. Разрежьте готовое слоеное тесто на несколько частей, чуть меньше высоты вашего блендера.</li>
# <li>Выложите слоеное тесто на противень, застеленный бумагой для выпечки.</li>
# <li>Поместите коржи в духовку на 10-12 минут, в зависимости от вашей духовки. Они будут готовы, когда появится золотистая корочка.</li>
# <li>Выньте коржи и положите их на решетку, чтобы они остыли.</li>
# <li>Когда коржи остынут, перебейте их в блендере в крошку.</li>
# <li>Когда крем и джем остынут, можете приступать к сборке десерта.</li>
# <li>На дно стакана выложите немного крема, затем крошку, немного прижмите крошку ложкой, чтобы ее уплотнить.</li>
# <li>Затем крем, джем, крем и снова крошка. Важно выкладывать крем сначала у стенок стаканчика, затем в середине, чтобы джем не мог протечь на нижние слои. Малиновый джем сам по себе имеет яркий вкус, поэтому его нужно значительно меньше, чем заварного крема.</li>
# <li>Повторяйте, пока не останется 1-1,5 см до края стаканчика.</li>
# <li>Последний слой должен быть крошкой от слоеного теста.</li>
# <li>Можете подавать сразу, если любите, чтобы крошка хрустела, либо если любите пропитанный наполеон, подождите не меньше 5 часов.</li>
#
#                 </ol>
#             </div>
#
#
#                 <div class="note">
#                 <p><strong>Совет:</strong> Для джема подойдут и другие ягоды или можно вообще не использовать начинку. </p>
#                 </div>
#
#         </div>
#     </main>
#
#     <footer class="main-footer">
#         <div class="footer-content">
#             <div class="footer-lang-switcher">
#                 <button class="footer-lang-btn active" data-lang="ru">RU</button>
#                 <button class="footer-lang-btn" data-lang="en">EN</button>
#             </div>
#             <p>2026 Кулинарные заметки</p>
#             <p class="footer-note">С любовью к вкусной еде ❤️</p>
#         </div>
#     </footer>
#
#     <script src="../translations.js" defer></script>
#     <script src="../script.js" defer></script>
# </body>
# </html>

# %% [markdown]
# ### 4. В файл translations.js добавляем в раздел с названиями блюд:

# %%
print(meal_name_translation)
# Out:
#         "Наполеон с малиновым джемом в стаканчике": {
#             ru: "Наполеон с малиновым джемом в стаканчике",
#             en: "Napoleon with Raspberry Jam in a Glass"
#             },

# %% [markdown]
# ### 5. Затем в этом же файле вставляем в конце в разделе recipeDetails:

# %%
print(recipedetail_new_text)
# Out:
#         "dessert_napoleon_individual":  {
#             ru: {
#                 title: "Наполеон с малиновым джемом в стаканчике",
#                 meta:  {
#                     time: "180 мин",
#                     servings: "9 порций"
#                   },
#                 ingredients: [
#                 "400 г слоеного теста",
# "Для заварного крема:",
# "500 мл молока",
# "150 г сахара",
# "100 г масла",
# "2 яйца",
# "40 г муки",
# "10 г ванильного сахара",
# "Для джема:100 г замороженной малины",
# "10 г сахара",
# "5 г крахмала",
#
#                 ],
#                 instructions: [
#                 "Начните с крема, так как ему потребуется больше всего времени для остывания. В маленькой кастрюльке взбейте вместе муку, сахар, ванильный сахар и яйца до получения однородной массы.",
# "Постепенно влейте небольшое количество молока, тщательно взбивая, чтобы удалить комочки.",
# "Продолжайте добавлять оставшееся молоко, взбивая, пока смесь не станет полностью однородной.",
# "Поставьте кастрюлю на слабый огонь. Готовьте, постоянно помешивая, особенно по дну, чтобы не образовались комочки.",
# "Как только заварной крем загустеет и начнет закипать, снимите его с огня.",
# "Добавьте размягченное сливочное масло в горячий заварной крем и перемешивайте, пока оно полностью не растает.",
# "Переложите заварной крем в широкую миску, чтобы он быстрее остыл. Накройте пищевой пленкой в контакт.",
# "Перейдите к приготовлению джема. Разморозьте малину, пробейте в блендере и протрите через сито.",
# "Переложите малиновое пюре в сотейник, добавьте сахар и начните нагревать массу на среднем огне.",
# "Когда масса загустеет, перелейте соус в широкую тарелку, накройте пленкой в контакт и оставьте остывать при комнатной температуре.",
# "Перейдите к приготовлению коржей. Разогрейте духовку до 210°C. Разрежьте готовое слоеное тесто на несколько частей, чуть меньше высоты вашего блендера.",
# "Выложите слоеное тесто на противень, застеленный бумагой для выпечки.",
# "Поместите коржи в духовку на 10-12 минут, в зависимости от вашей духовки. Они будут готовы, когда появится золотистая корочка.",
# "Выньте коржи и положите их на решетку, чтобы они остыли.",
# "Когда коржи остынут, перебейте их в блендере в крошку.",
# "Когда крем и джем остынут, можете приступать к сборке десерта.",
# "На дно стакана выложите немного крема, затем крошку, немного прижмите крошку ложкой, чтобы ее уплотнить.",
# "Затем крем, джем, крем и снова крошка. Важно выкладывать крем сначала у стенок стаканчика, затем в середине, чтобы джем не мог протечь на нижние слои. Малиновый джем сам по себе имеет яркий вкус, поэтому его нужно значительно меньше, чем заварного крема.",
# "Повторяйте, пока не останется 1-1,5 см до края стаканчика.",
# "Последний слой должен быть крошкой от слоеного теста.",
# "Можете подавать сразу, если любите, чтобы крошка хрустела, либо если любите пропитанный наполеон, подождите не меньше 5 часов.",
#
#                 ],
#                 note: "Для джема подойдут и другие ягоды или можно вообще не использовать начинку."
#              },
#             en: {
#                 title: "Napoleon with Raspberry Jam in a Glass",
#                 meta:  {
#                     time: "180 minutes",
#                     servings: "Serves 9"
#                   },
#                 ingredients: [
#                 "400 g puff pastry",
# "For the custard cream:",
# "500 ml milk",
# "150 g sugar",
# "100 g butter",
# "2 eggs",
# "40 g flour",
# "10 g vanilla sugar",
# "For the jam:",
# "100 g frozen raspberries",
# "10 g sugar",
# "5 g corn starch",
#
#                 ],
#                 instructions: [
#                 "Begin with the custard cream, as it requires the most time to cool. In a small saucepan, whisk together the flour, sugar, vanilla sugar, and eggs until smooth.",
# "Gradually pour in a small amount of the milk, whisking thoroughly to remove any lumps.",
# "Add the remaining milk, whisking until the mixture is completely smooth.",
# "Place the saucepan over low heat. Cook, stirring constantly, especially along the bottom, to prevent lumps.",
# "As soon as the custard thickens and begins to boil, remove it from the heat.",
# "Add the softened butter to the hot custard and stir until fully melted and incorporated.",
# "Transfer the custard to a wide bowl to cool more quickly. Cover with cling film in direct contact.",
# "Prepare the jam. Thaw the raspberries, blend until smooth, then strain through a sieve.",
# "Transfer the raspberry purée to a saucepan, add the sugar, and heat over medium.",
# "Once thickened, pour the jam onto a wide plate, cover with cling film in contact, and leave to cool at room temperature.",
# "Prepare the pastry layers. Preheat the oven to 210°C. Cut the puff pastry into several pieces slightly smaller than the height of your blender.",
# "Place the pastry on a baking tray lined with parchment paper.",
# "Bake for 10-12 minutes, depending on your oven, until golden.",
# "Remove and allow the pastry to cool on a rack.",
# "Once cooled, pulse the pastry in a blender into coarse crumbs.",
# "When the custard and jam have cooled, assemble the dessert.",
# "Spoon a layer of custard into the bottom of each glass, followed by a layer of crumbs. Lightly press the crumbs with a spoon.",
# "Continue layering: custard, jam, custard, and crumbs. Spread the custard along the sides of the glass first, then add the jam in the centre to prevent it from seeping downward. As raspberry jam has a pronounced flavour, use less jam than custard.",
# "Repeat until 1-1.5 cm remains to the rim.",
# "Finish with a layer of puff pastry crumbs.",
# "Serve immediately for a crisp texture, or chill for at least 5 hours for a softened, infused dessert.",
#
#                 ],
#                 note: "Other berries may be used for the jam, or the filling may be omitted entirely."
#              }
#         },

# %% [markdown]
# ### 6. На последнем этапе в файл script.js d поискать много else if и в конце добавить следующее:

# %%
print(sript_js_add)
# Out:
#  else if (path.includes('dessert_napoleon_individual')) {
# recipeKey = 'dessert_napoleon_individual';
# }
