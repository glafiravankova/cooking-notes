# %%
recipe_id_name = "soup_chicken_broth"

recipe_ru_name = "Бульон куриный"
recipe_time_ru = "90 мин"
recipe_portion_ru = "12 порций"
ingredients_ru = [
    "700-1000 г курицы (желательно с костью)",
    "1 луковица",
    "1 морковь",
    "1 пучок укропа",
    "5 горошков перца",
    "Соль по вкусу"
]

instruction_ru = [
    "Положите курицу в большую кастрюлю и залейте холодной водой.",
    "Поставьте кастрюлю на максимальный огонь и доведите до кипения.",
    "Снимите образовавшуюся пену шумовкой.",
    "Добавьте соль, перец горошком, укроп, очищенную морковь и луковицу. Убавьте огонь так, чтобы суп слегка побулькивал.",
    "Накройте кастрюлю крышкой и варите бульон 1–1,5 часа.",
    "Когда бульон будет готов, выньте из него лук, морковь и зелень (если добавляли).",
    "Достаньте курицу, дайте ей немного остыть и отделите мясо от костей. Нарежьте или разберите на волокна и верните в бульон (или храните отдельно, если суп варите впрок).",
    "Если планируете добавить вермишель или картофель, отлейте нужное количество бульона в отдельную кастрюлю - столько, сколько планируете съесть сейчас.",
    "Доведите бульон до кипения. Добавьте вермишель (примерно 20 г на порцию) или нарезанный картофель (1 средняя картофелина на порцию).",
    "Варите до готовности: вермишель - столько, сколько указано на упаковке, картофель - пока не станет мягким и легко протыкаться вилкой."]

note_ru = "Готовый куриный бульон можно разлить по порциям (примерно по 500 мл) и заморозить. Так у вас всегда будет основа для быстрых супов или соусов."

recipe_eng_name = "Chicken Broth"
recipe_time_eng = "90 minutes"
recipe_portion_eng = "Serves 12"

ingredients_eng = [
    "700-1000 g chicken (preferably bone-in)",
    "1 onion",
    "1 carrot",
    "1 bunch of dill",
    "5 peppercorns",
    "Salt to taste"
]

instruction_eng = [
    "Place the chicken in a big pot and cover with cold water.",
    "Set over high heat and bring to a boil.",
    "Skim off any foam that rises to the surface.",
    "Add the salt, peppercorns, dill, peeled carrot, and onion. Reduce the heat so the broth simmers gently.",
    "Cover with a lid and cook for 1-1.5 hours.",
    "Once the broth is ready, remove the onion, carrot, and herbs (if used).",
    "Lift out the chicken, allow it to cool slightly, then separate the meat from the bones. Slice or shred and return the meat to the broth (or store separately if preparing ahead).",
    "If you plan to add vermicelli or potatoes, pour the required amount of broth into a separate saucepan — only as much as you intend to serve now.",
    "Bring the broth to a boil. Add vermicelli (about 20 g per serving) or diced potatoes (1 medium potato per serving).",
    "Cook until done: vermicelli according to the package instructions; potatoes until tender and easily pierced with a fork."
]

note_eng = "The finished chicken broth can be divided into portions (approximately 500 ml each) and frozen. This way, you will always have a convenient base for quick soups or sauces."

# %% [markdown]
# # Организационные вопросики

# %%
index_html_output = f'''
                    <!-- Рецепт {recipe_ru_name} -->
                    <a href="recipes/{recipe_id_name}.html" class="recipe-card"> 
                        <div class="recipe-image">
                            <img src="site-photos/{recipe_id_name}.jpg" alt="{recipe_ru_name}"> 
                            <div class="recipe-overlay">
                                <i class="fas fa-external-link-alt"></i>
                            </div>
                        </div>
                        <div class="recipe-info">
                            <h3>{recipe_ru_name}</h3> 
                            <p class="recipe-time"><i class="far fa-clock"></i> {recipe_time_ru} </p> 
                        </div>
                    </a>
                    <!-- Рецепт {recipe_ru_name} конец -->
                    
                    '''

# %%
ingredients_spin_new_html = ''
for ing_list_length in ingredients_ru:
    ingredients_spin_new_html += "<li>" + ing_list_length + "</li> \n"

instruction_spin_new_html = ''
for inst_list_length in instruction_ru:
    instruction_spin_new_html += "<li>" + inst_list_length + "</li> \n"

# %%
if note_ru != '':
    notes_new_html = f'''
                <div class="note">
                <p><strong>Совет:</strong> {note_ru} </p>
                </div>'''
else:
    notes_new_html = ''

# %%
print(ingredients_spin_new_html)
print(instruction_spin_new_html)
# Out:
# <li>700-1000 г курицы (желательно с костью)</li>
# <li>1 луковица</li>
# <li>1 морковь</li>
# <li>1 пучок укропа</li>
# <li>5 горошков перца</li>
# <li>Соль по вкусу</li>
#
# <li>Положите курицу в большую кастрюлю и залейте холодной водой.</li>
# <li>Поставьте кастрюлю на максимальный огонь и доведите до кипения.</li>
# <li>Снимите образовавшуюся пену шумовкой.</li>
# <li>Добавьте соль, перец горошком, укроп, очищенную морковь и луковицу. Убавьте огонь так, чтобы суп слегка побулькивал.</li>
# <li>Накройте кастрюлю крышкой и варите бульон 1–1,5 часа.</li>
# <li>Когда бульон будет готов, выньте из него лук, морковь и зелень (если добавляли).</li>
# <li>Достаньте курицу, дайте ей немного остыть и отделите мясо от костей. Нарежьте или разберите на волокна и верните в бульон (или храните отдельно, если суп варите впрок).</li>
# <li>Если планируете добавить вермишель или картофель, отлейте нужное количество бульона в отдельную кастрюлю - столько, сколько планируете съесть сейчас.</li>
# ...

# %%
styler_text = '''<style>
        .recipe-page {
            max-width: 800px;
            margin: 40px auto;
            padding: 0 20px;
        }
        
        .back-link {
            display: inline-flex;
            align-items: center;
            gap: 8px;
            color: #8b4513;
            text-decoration: none;
            margin-bottom: 20px;
            font-weight: 500;
        }
        
        .back-link:hover {
            text-decoration: underline;
        }
        
        .recipe-header {
            text-align: center;
            margin-bottom: 40px;
        }
        
        .recipe-header h1 {
            color: #8b4513;
            font-size: 2.5rem;
            margin-bottom: 10px;
        }
        
        .recipe-meta {
            display: flex;
            justify-content: center;
            gap: 30px;
            color: #666;
            margin-bottom: 30px;
        }
        
        .recipe-image-main {
            width: 100%;
            height: 400px;
            object-fit: cover;
            border-radius: 15px;
            margin-bottom: 30px;
            box-shadow: 0 10px 25px rgba(0, 0, 0, 0.1);
        }
        
        .recipe-content {
            background: white;
            padding: 40px;
            border-radius: 15px;
            box-shadow: 0 5px 20px rgba(0, 0, 0, 0.05);
        }
        
        .ingredients, .instructions {
            margin-bottom: 40px;
        }
        
        .ingredients h2, .instructions h2 {
            color: #8b4513;
            border-bottom: 2px solid #f0e6d6;
            padding-bottom: 10px;
            margin-bottom: 20px;
        }
        
        .ingredients ul {
            list-style: none;
            padding: 0;
        }
        
        .ingredients li {
            padding: 8px 0;
            padding-left: 30px;
            position: relative;
            border-bottom: 1px solid #f0e6d6;
        }
        
        .ingredients li:before {
            content: "•";
            position: absolute;
            left: 0;
        }
        
        .instructions ol {
            padding-left: 20px;
        }
        
        .instructions li {
            margin-bottom: 15px;
            line-height: 1.6;
        }
        
        .note {
            background: #f9f3ec;
            padding: 20px;
            border-radius: 10px;
            border-left: 4px solid #d4a574;
            margin-top: 30px;
        }
    </style>'''

# %%
new_html_page_output = f'''
<!DOCTYPE html>
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>{recipe_ru_name} - Кулинарные заметки</title>
    <!-- Favicon (иконка вкладки) -->
    <link rel="icon" href="../assets/icons/icons8-girl-64.png" type="image/png">
    <link rel="stylesheet" href="../style.css">
    <script src="../script.js" defer></script>
    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css">
    {styler_text}
</head>
<body>
    <header class="main-header">
        <div class="header-top"> 
            <h1>Кулинарные заметки</h1>
        </div>
    </header>

    <main class="recipe-page">
        <a href="../index.html" class="back-link">
            <i class="fas fa-arrow-left"></i>
            Вернуться к рецептам
        </a>
        
        <div class="recipe-header">
            <h1>{recipe_ru_name}</h1>
            <div class="recipe-meta">
                <span><i class="far fa-clock"></i> {recipe_time_ru}</span>
                <span><i class="fas fa-user-friends"></i> {recipe_portion_ru}</span>
                
            </div>
        </div>
        
        <img src="../site-photos/{recipe_id_name}.jpg" 
             alt="{recipe_ru_name}" class="recipe-image-main">
        
        <div class="recipe-content">
            <div class="ingredients">
                <h2><i class="fas fa-shopping-basket"></i> Ингредиенты</h2>
                <ul>
                    {ingredients_spin_new_html}
                    

                </ul>
            </div>
            
            <div class="instructions">
                <h2><i class="fas fa-list-ol"></i> Способ приготовления</h2>
                <ol>
                    {instruction_spin_new_html}
                </ol>
            </div>
            
            {notes_new_html}
            
        </div>
    </main>

    <footer class="main-footer">
        <div class="footer-content">
            <div class="footer-lang-switcher">
                <button class="footer-lang-btn active" data-lang="ru">RU</button>
                <button class="footer-lang-btn" data-lang="en">EN</button>
            </div>
            <p>2026 Кулинарные заметки</p>
            <p class="footer-note">С любовью к вкусной еде ❤️</p>
        </div>
    </footer>

    <script src="../translations.js" defer></script>
    <script src="../script.js" defer></script>
</body>
</html>'''

# %%
meal_name_translation = f'''
        "{recipe_ru_name}": '''
meal_name_translation += '''{ '''
meal_name_translation += f''' 
            ru: "{recipe_ru_name}",
            en: "{recipe_eng_name}"'''
meal_name_translation += '''
            },'''

# %%
ingredient_shift_ru = ''
for ingredient_list in ingredients_ru:
    ingredient_shift_ru += '"' + ingredient_list + '", \n'

instruction_shift_ru = ''
for instruction_list in instruction_ru:
    instruction_shift_ru += '"' + instruction_list + '", \n'

ingredient_shift_eng = ''
for ingredient_list in ingredients_eng:
    ingredient_shift_eng += '"' + ingredient_list + '", \n'

instruction_shift_eng = ''
for instruction_list in instruction_eng:
    instruction_shift_eng += '"' + instruction_list + '", \n'

# %%
recipedetail_new_text = f'''
        "{recipe_id_name}": '''

recipedetail_new_text += ''' {
            ru: {
                title:'''
recipedetail_new_text += f''' "{recipe_ru_name}",
                meta: '''
recipedetail_new_text += ''' {
                    time: '''
recipedetail_new_text += f'''"{recipe_time_ru}",
                    servings: "{recipe_portion_ru}"
                 '''       
recipedetail_new_text += ''' },
                ingredients: [
                '''    
recipedetail_new_text += f'''{ingredient_shift_ru}
                ],
                instructions: [
                {instruction_shift_ru}
                ],
                note: "{note_ru}"
            '''     
recipedetail_new_text += ''' },
            en: {
                title:'''
recipedetail_new_text += f''' "{recipe_eng_name}",
                meta: '''
recipedetail_new_text += ''' {
                    time: '''
recipedetail_new_text += f'''"{recipe_time_eng}",
                    servings: "{recipe_portion_eng}"
                 '''       
recipedetail_new_text += ''' },
                ingredients: [
                '''    
recipedetail_new_text += f'''{ingredient_shift_eng}
                ],
                instructions: [
                {instruction_shift_eng}
                ],
                note: "{note_eng}"
            '''     
recipedetail_new_text += ''' }
        },'''

# %%
sript_js_add = f""" else if (path.includes('{recipe_id_name}')) """
sript_js_add += '''{
'''
sript_js_add += f"""recipeKey = '{recipe_id_name}';
"""
sript_js_add += '''}'''

# %% [markdown]
# # Добавление рецепта

# %% [markdown]
# ### 1. Добавляем в соответствующем месте в index.html следующее:

# %%
print(index_html_output)
# Out:
#                     <!-- Рецепт Бульон куриный -->
#                     <a href="recipes/soup_chicken_broth.html" class="recipe-card">
#                         <div class="recipe-image">
#                             <img src="site-photos/soup_chicken_broth.jpg" alt="Бульон куриный">
#                             <div class="recipe-overlay">
#                                 <i class="fas fa-external-link-alt"></i>
#                             </div>
#                         </div>
#                         <div class="recipe-info">
#                             <h3>Бульон куриный</h3>
#                             <p class="recipe-time"><i class="far fa-clock"></i> 90 мин </p>
#                         </div>
#                     </a>
#                     <!-- Рецепт Бульон куриный конец -->

# %% [markdown]
# ### 2.Далее создаем файл с названием:

# %%
print(recipe_id_name+'.html')
# Out:
# soup_chicken_broth.html

# %% [markdown]
# ### 3. В новый файл вставляем следующее:

# %%
print(new_html_page_output)
# Out:
# <!DOCTYPE html>
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Бульон куриный - Кулинарные заметки</title>
#     <!-- Favicon (иконка вкладки) -->
#     <link rel="icon" href="../assets/icons/icons8-girl-64.png" type="image/png">
#     <link rel="stylesheet" href="../style.css">
#     <script src="../script.js" defer></script>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css">
#     <style>
#         .recipe-page {
#             max-width: 800px;
#             margin: 40px auto;
#             padding: 0 20px;
#         }
#
#         .back-link {
#             display: inline-flex;
#             align-items: center;
#             gap: 8px;
#             color: #8b4513;
#             text-decoration: none;
#             margin-bottom: 20px;
#             font-weight: 500;
#         }
#
#         .back-link:hover {
# ...

# %% [markdown]
# ### 4. В файл translations.js добавляем в раздел с названиями блюд:

# %%
print(meal_name_translation)
# Out:
#         "Бульон куриный": {
#             ru: "Бульон куриный",
#             en: "Chicken Broth"
#             },

# %% [markdown]
# ### 5. Затем в этом же файле вставляем в конце в разделе recipeDetails:

# %%
print(recipedetail_new_text)
# Out:
#         "soup_chicken_broth":  {
#             ru: {
#                 title: "Бульон куриный",
#                 meta:  {
#                     time: "90 мин",
#                     servings: "12 порций"
#                   },
#                 ingredients: [
#                 "700-1000 г курицы (желательно с костью)",
# "1 луковица",
# "1 морковь",
# "1 пучок укропа",
# "5 горошков перца",
# "Соль по вкусу",
#
#                 ],
#                 instructions: [
#                 "Положите курицу в большую кастрюлю и залейте холодной водой.",
# "Поставьте кастрюлю на максимальный огонь и доведите до кипения.",
# "Снимите образовавшуюся пену шумовкой.",
# "Добавьте соль, перец горошком, укроп, очищенную морковь и луковицу. Убавьте огонь так, чтобы суп слегка побулькивал.",
# "Накройте кастрюлю крышкой и варите бульон 1–1,5 часа.",
# "Когда бульон будет готов, выньте из него лук, морковь и зелень (если добавляли).",
# ...

# %% [markdown]
# ### 6. На последнем этапе в файл script.js d поискать много else if и в конце добавить следующее:

# %%
print(sript_js_add)
# Out:
#  else if (path.includes('soup_chicken_broth')) {
# recipeKey = 'soup_chicken_broth';
# }
