# %%
recipe_id_name = "main_dish_pasta_carbonara"

recipe_ru_name = "Паста карбонара"
recipe_time_ru = "15 мин"
recipe_portion_ru = "2 порций"
ingredients_ru = [
  "200 мл сливок (15–20%)",
  "180 г спагетти",
  "150 г копченого бекона",
  "2 зубчика чеснока",
  "1 яичный желток",
  "Соль, перец",
  "Пармиджано для посыпания"]
instruction_ru = [
  "Сварите спагетти в слегка подсоленной воде согласно инструкции на упаковке.",
  "Тем временем обжарьте бекон на сильном огне и добавьте чеснок.",
  "В небольшой миске смешайте сливки с яичным желтком, солью и перцем.",
  "Когда паста сварится, слейте почти всю воду, оставив немного воды, в которой варились спагетти.",
  "Верните спагетти в кастрюлю и убавьте огонь до очень слабого.",
  "Влейте сливочно-яичную смесь в бекон, постоянно помешивая, около 30 секунд. Затем добавьте всё к спагетти и готовьте на слабом огне около 5 минут, аккуратно перемешивая.",
  "Подавайте, слегка посыпав сыром пармезан.",
  ]
note_ru = ''

recipe_eng_name = "Pasta Carbonara"
recipe_time_eng = "15 min"
recipe_portion_eng = "Serves 2"
ingredients_eng = [
  "200 ml cream (15–20%)",
  "180 g spaghetti",
  "150 g smoked bacon",
  "2 cloves of garlic",
  "1 egg yolk",
  "Salt, pepper",
  "Parmigiano for sprinkling"
]

instruction_eng = [
  "Cook the spaghetti in lightly salted water according to the package instructions.",
  "Meanwhile, fry the bacon over high heat and add the garlic.",
  "In a small bowl, mix the cream with the egg yolk, salt, and pepper.",
  "When the pasta is cooked, drain almost all the water, leaving a little of the spaghetti cooking water.",
  "Return the spaghetti to the pot and reduce the heat to very low.",
  "Pour the cream and egg mixture into the bacon, stirring constantly for about 30 seconds. Then add everything to the spaghetti and cook over low heat for about 5 minutes, stirring gently.",
  "Serve lightly sprinkled with Parmesan cheese."
]

note_eng = ""

# %% [markdown]
# # Организационные вопросики

# %%
index_html_output = f'''
                    <!-- Рецепт {recipe_ru_name} -->
                    <a href="recipes/{recipe_id_name}.html" class="recipe-card"> 
                        <div class="recipe-image">
                            <img src="site-photos/{recipe_id_name}.jpg" alt="{recipe_ru_name}"> 
                            <div class="recipe-overlay">
                                <i class="fas fa-external-link-alt"></i>
                            </div>
                        </div>
                        <div class="recipe-info">
                            <h3>{recipe_ru_name}</h3> 
                            <p class="recipe-time"><i class="far fa-clock"></i> {recipe_time_ru} </p> 
                        </div>
                    </a>
                    <!-- Рецепт {recipe_ru_name} конец -->
                    
                    '''

# %%
ingredients_spin_new_html = ''
for ing_list_length in ingredients_ru:
    ingredients_spin_new_html += "<li>" + ing_list_length + "</li> \n"

instruction_spin_new_html = ''
for inst_list_length in instruction_ru:
    instruction_spin_new_html += "<li>" + inst_list_length + "</li> \n"

# %%
if note_ru != '':
    notes_new_html = f'''
                <div class="note">
                <p><strong>Совет:</strong> {note_ru} </p>
                </div>'''
else:
    notes_new_html = ''

# %%
print(ingredients_spin_new_html)
print(instruction_spin_new_html)
# Out:
# <li>200 мл сливок (15–20%)</li>
# <li>180 г спагетти</li>
# <li>150 г копченого бекона</li>
# <li>2 зубчика чеснока</li>
# <li>1 яичный желток</li>
# <li>Соль, перец</li>
# <li>Пармиджано для посыпания</li>
#
# <li>Сварите спагетти в слегка подсоленной воде согласно инструкции на упаковке.</li>
# <li>Тем временем обжарьте бекон на сильном огне и добавьте чеснок.</li>
# <li>В небольшой миске смешайте сливки с яичным желтком, солью и перцем.</li>
# <li>Когда паста сварится, слейте почти всю воду, оставив немного воды, в которой варились спагетти.</li>
# <li>Верните спагетти в кастрюлю и убавьте огонь до очень слабого.</li>
# <li>Влейте сливочно-яичную смесь в бекон, постоянно помешивая, около 30 секунд. Затем добавьте всё к спагетти и готовьте на слабом огне около 5 минут, аккуратно перемешивая.</li>
# <li>Подавайте, слегка посыпав сыром пармезан.</li>

# %%
styler_text = '''<style>
        .recipe-page {
            max-width: 800px;
            margin: 40px auto;
            padding: 0 20px;
        }
        
        .back-link {
            display: inline-flex;
            align-items: center;
            gap: 8px;
            color: #8b4513;
            text-decoration: none;
            margin-bottom: 20px;
            font-weight: 500;
        }
        
        .back-link:hover {
            text-decoration: underline;
        }
        
        .recipe-header {
            text-align: center;
            margin-bottom: 40px;
        }
        
        .recipe-header h1 {
            color: #8b4513;
            font-size: 2.5rem;
            margin-bottom: 10px;
        }
        
        .recipe-meta {
            display: flex;
            justify-content: center;
            gap: 30px;
            color: #666;
            margin-bottom: 30px;
        }
        
        .recipe-image-main {
            width: 100%;
            height: 400px;
            object-fit: cover;
            border-radius: 15px;
            margin-bottom: 30px;
            box-shadow: 0 10px 25px rgba(0, 0, 0, 0.1);
        }
        
        .recipe-content {
            background: white;
            padding: 40px;
            border-radius: 15px;
            box-shadow: 0 5px 20px rgba(0, 0, 0, 0.05);
        }
        
        .ingredients, .instructions {
            margin-bottom: 40px;
        }
        
        .ingredients h2, .instructions h2 {
            color: #8b4513;
            border-bottom: 2px solid #f0e6d6;
            padding-bottom: 10px;
            margin-bottom: 20px;
        }
        
        .ingredients ul {
            list-style: none;
            padding: 0;
        }
        
        .ingredients li {
            padding: 8px 0;
            padding-left: 30px;
            position: relative;
            border-bottom: 1px solid #f0e6d6;
        }
        
        .ingredients li:before {
            content: "•";
            position: absolute;
            left: 0;
        }
        
        .instructions ol {
            padding-left: 20px;
        }
        
        .instructions li {
            margin-bottom: 15px;
            line-height: 1.6;
        }
        
        .note {
            background: #f9f3ec;
            padding: 20px;
            border-radius: 10px;
            border-left: 4px solid #d4a574;
            margin-top: 30px;
        }
    </style>'''

# %%
new_html_page_output = f'''
<!DOCTYPE html>
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>{recipe_ru_name} - Кулинарные заметки</title>
    <!-- Favicon (иконка вкладки) -->
    <link rel="icon" href="../assets/icons/icons8-girl-64.png" type="image/png">
    <link rel="stylesheet" href="../style.css">
    <script src="../script.js" defer></script>
    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css">
    {styler_text}
</head>
<body>
    <header class="main-header">
        <div class="header-top"> 
            <h1>Кулинарные заметки</h1>
        </div>
    </header>

    <main class="recipe-page">
        <a href="../index.html" class="back-link">
            <i class="fas fa-arrow-left"></i>
            Вернуться к рецептам
        </a>
        
        <div class="recipe-header">
            <h1>{recipe_ru_name}</h1>
            <div class="recipe-meta">
                <span><i class="far fa-clock"></i> {recipe_time_ru}</span>
                <span><i class="fas fa-user-friends"></i> {recipe_portion_ru}</span>
                
            </div>
        </div>
        
        <img src="../site-photos/{recipe_id_name}.jpg" 
             alt="{recipe_ru_name}" class="recipe-image-main">
        
        <div class="recipe-content">
            <div class="ingredients">
                <h2><i class="fas fa-shopping-basket"></i> Ингредиенты</h2>
                <ul>
                    {ingredients_spin_new_html}
                    

                </ul>
            </div>
            
            <div class="instructions">
                <h2><i class="fas fa-list-ol"></i> Способ приготовления</h2>
                <ol>
                    {instruction_spin_new_html}
                </ol>
            </div>
            
            {notes_new_html}
            
        </div>
    </main>

    <footer class="main-footer">
        <div class="footer-content">
            <div class="footer-lang-switcher">
                <button class="footer-lang-btn active" data-lang="ru">RU</button>
                <button class="footer-lang-btn" data-lang="en">EN</button>
            </div>
            <p>2026 Кулинарные заметки</p>
            <p class="footer-note">С любовью к вкусной еде ❤️</p>
        </div>
    </footer>

    <script src="../translations.js" defer></script>
    <script src="../script.js" defer></script>
</body>
</html>'''

# %%
meal_name_translation = f'''
        "{recipe_ru_name}": '''
meal_name_translation += '''{ '''
meal_name_translation += f''' 
            ru: "{recipe_ru_name}",
            en: "{recipe_eng_name}"'''
meal_name_translation += '''
            },'''

# %%
ingredient_shift_ru = ''
for ingredient_list in ingredients_ru:
    ingredient_shift_ru += '"' + ingredient_list + '", \n'

instruction_shift_ru = ''
for instruction_list in instruction_ru:
    instruction_shift_ru += '"' + instruction_list + '", \n'

ingredient_shift_eng = ''
for ingredient_list in ingredients_eng:
    ingredient_shift_eng += '"' + ingredient_list + '", \n'

instruction_shift_eng = ''
for instruction_list in instruction_eng:
    instruction_shift_eng += '"' + instruction_list + '", \n'

# %%
recipedetail_new_text = f'''
        "{recipe_id_name}": '''

recipedetail_new_text += ''' {
            ru: {
                title:'''
recipedetail_new_text += f''' "{recipe_ru_name}",
                meta: '''
recipedetail_new_text += ''' {
                    time: '''
recipedetail_new_text += f'''"{recipe_time_ru}",
                    servings: "{recipe_portion_ru}"
                 '''       
recipedetail_new_text += ''' },
                ingredients: [
                '''    
recipedetail_new_text += f'''{ingredient_shift_ru}
                ],
                instructions: [
                {instruction_shift_ru}
                ],
                note: "{note_ru}"
            '''     
recipedetail_new_text += ''' },
            en: {
                title:'''
recipedetail_new_text += f''' "{recipe_eng_name}",
                meta: '''
recipedetail_new_text += ''' {
                    time: '''
recipedetail_new_text += f'''"{recipe_time_eng}",
                    servings: "{recipe_portion_eng}"
                 '''       
recipedetail_new_text += ''' },
                ingredients: [
                '''    
recipedetail_new_text += f'''{ingredient_shift_eng}
                ],
                instructions: [
                {instruction_shift_eng}
                ],
                note: "{note_eng}"
            '''     
recipedetail_new_text += ''' }
        },'''

# %%
sript_js_add = f""" else if (path.includes('{recipe_id_name}')) """
sript_js_add += '''{
'''
sript_js_add += f"""recipeKey = '{recipe_id_name}';
"""
sript_js_add += '''}'''

# %% [markdown]
# # Добавление рецепта

# %% [markdown]
# ### 1. Добавляем в соответствующем месте в index.html следующее:

# %%
print(index_html_output)
# Out:
#                     <!-- Рецепт Паста карбонара -->
#                     <a href="recipes/main_dish_pasta_carbonara.html" class="recipe-card">
#                         <div class="recipe-image">
#                             <img src="site-photos/main_dish_pasta_carbonara.jpg" alt="Паста карбонара">
#                             <div class="recipe-overlay">
#                                 <i class="fas fa-external-link-alt"></i>
#                             </div>
#                         </div>
#                         <div class="recipe-info">
#                             <h3>Паста карбонара</h3>
#                             <p class="recipe-time"><i class="far fa-clock"></i> 15 мин </p>
#                         </div>
#                     </a>
#                     <!-- Рецепт Паста карбонара конец -->

# %% [markdown]
# ### 2.Далее создаем файл с названием:

# %%
print(recipe_id_name+'.html')
# Out:
# main_dish_pasta_carbonara.html

# %% [markdown]
# ### 3. В новый файл вставляем следующее:

# %%
print(new_html_page_output)
# Out:
# <!DOCTYPE html>
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Паста карбонара - Кулинарные заметки</title>
#     <!-- Favicon (иконка вкладки) -->
#     <link rel="icon" href="../assets/icons/icons8-girl-64.png" type="image/png">
#     <link rel="stylesheet" href="../style.css">
#     <script src="../script.js" defer></script>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css">
#     <style>
#         .recipe-page {
#             max-width: 800px;
#             margin: 40px auto;
#             padding: 0 20px;
#         }
#
#         .back-link {
#             display: inline-flex;
#             align-items: center;
#             gap: 8px;
#             color: #8b4513;
#             text-decoration: none;
#             margin-bottom: 20px;
#             font-weight: 500;
#         }
#
#         .back-link:hover {
#             text-decoration: underline;
#         }
#
#         .recipe-header {
#             text-align: center;
#             margin-bottom: 40px;
#         }
#
#         .recipe-header h1 {
#             color: #8b4513;
#             font-size: 2.5rem;
#             margin-bottom: 10px;
#         }
#
#         .recipe-meta {
#             display: flex;
#             justify-content: center;
#             gap: 30px;
#             color: #666;
#             margin-bottom: 30px;
#         }
#
#         .recipe-image-main {
#             width: 100%;
#             height: 400px;
#             object-fit: cover;
#             border-radius: 15px;
#             margin-bottom: 30px;
#             box-shadow: 0 10px 25px rgba(0, 0, 0, 0.1);
#         }
#
#         .recipe-content {
#             background: white;
#             padding: 40px;
#             border-radius: 15px;
#             box-shadow: 0 5px 20px rgba(0, 0, 0, 0.05);
#         }
#
#         .ingredients, .instructions {
#             margin-bottom: 40px;
#         }
#
#         .ingredients h2, .instructions h2 {
#             color: #8b4513;
#             border-bottom: 2px solid #f0e6d6;
#             padding-bottom: 10px;
#             margin-bottom: 20px;
#         }
#
#         .ingredients ul {
#             list-style: none;
#             padding: 0;
#         }
#
#         .ingredients li {
#             padding: 8px 0;
#             padding-left: 30px;
#             position: relative;
#             border-bottom: 1px solid #f0e6d6;
#         }
#
#         .ingredients li:before {
#             content: "•";
#             position: absolute;
#             left: 0;
#         }
#
#         .instructions ol {
#             padding-left: 20px;
#         }
#
#         .instructions li {
#             margin-bottom: 15px;
#             line-height: 1.6;
#         }
#
#         .note {
#             background: #f9f3ec;
#             padding: 20px;
#             border-radius: 10px;
#             border-left: 4px solid #d4a574;
#             margin-top: 30px;
#         }
#     </style>
# </head>
# <body>
#     <header class="main-header">
#         <div class="header-top">
#             <h1>Кулинарные заметки</h1>
#         </div>
#     </header>
#
#     <main class="recipe-page">
#         <a href="../index.html" class="back-link">
#             <i class="fas fa-arrow-left"></i>
#             Вернуться к рецептам
#         </a>
#
#         <div class="recipe-header">
#             <h1>Паста карбонара</h1>
#             <div class="recipe-meta">
#                 <span><i class="far fa-clock"></i> 15 мин</span>
#                 <span><i class="fas fa-user-friends"></i> 2 порций</span>
#
#             </div>
#         </div>
#
#         <img src="../site-photos/main_dish_pasta_carbonara.jpg"
#              alt="Паста карбонара" class="recipe-image-main">
#
#         <div class="recipe-content">
#             <div class="ingredients">
#                 <h2><i class="fas fa-shopping-basket"></i> Ингредиенты</h2>
#                 <ul>
#                     <li>200 мл сливок (15–20%)</li>
# <li>180 г спагетти</li>
# <li>150 г копченого бекона</li>
# <li>2 зубчика чеснока</li>
# <li>1 яичный желток</li>
# <li>Соль, перец</li>
# <li>Пармиджано для посыпания</li>
#
#
#
#                 </ul>
#             </div>
#
#             <div class="instructions">
#                 <h2><i class="fas fa-list-ol"></i> Способ приготовления</h2>
#                 <ol>
#                     <li>Сварите спагетти в слегка подсоленной воде согласно инструкции на упаковке.</li>
# <li>Тем временем обжарьте бекон на сильном огне и добавьте чеснок.</li>
# <li>В небольшой миске смешайте сливки с яичным желтком, солью и перцем.</li>
# <li>Когда паста сварится, слейте почти всю воду, оставив немного воды, в которой варились спагетти.</li>
# <li>Верните спагетти в кастрюлю и убавьте огонь до очень слабого.</li>
# <li>Влейте сливочно-яичную смесь в бекон, постоянно помешивая, около 30 секунд. Затем добавьте всё к спагетти и готовьте на слабом огне около 5 минут, аккуратно перемешивая.</li>
# <li>Подавайте, слегка посыпав сыром пармезан.</li>
#
#                 </ol>
#             </div>
#
#
#
#         </div>
#     </main>
#
#     <footer class="main-footer">
#         <div class="footer-content">
#             <div class="footer-lang-switcher">
#                 <button class="footer-lang-btn active" data-lang="ru">RU</button>
#                 <button class="footer-lang-btn" data-lang="en">EN</button>
#             </div>
#             <p>2026 Кулинарные заметки</p>
#             <p class="footer-note">С любовью к вкусной еде ❤️</p>
#         </div>
#     </footer>
#
#     <script src="../translations.js" defer></script>
#     <script src="../script.js" defer></script>
# </body>
# </html>

# %% [markdown]
# ### 4. В файл translations.js добавляем в раздел с названиями блюд:

# %%
print(meal_name_translation)
# Out:
#         "Паста карбонара": {
#             ru: "Паста карбонара",
#             en: "Pasta Carbonara"
#             },

# %% [markdown]
# ### 5. Затем в этом же файле вставляем в конце в разделе recipeDetails:

# %%
print(recipedetail_new_text)
# Out:
#         "main_dish_pasta_carbonara":  {
#             ru: {
#                 title: "Паста карбонара",
#                 meta:  {
#                     time: "15 мин",
#                     servings: "2 порций"
#                   },
#                 ingredients: [
#                 "200 мл сливок (15–20%)",
# "180 г спагетти",
# "150 г копченого бекона",
# "2 зубчика чеснока",
# "1 яичный желток",
# "Соль, перец",
# "Пармиджано для посыпания",
#
#                 ],
#                 instructions: [
#                 "Сварите спагетти в слегка подсоленной воде согласно инструкции на упаковке.",
# "Тем временем обжарьте бекон на сильном огне и добавьте чеснок.",
# "В небольшой миске смешайте сливки с яичным желтком, солью и перцем.",
# "Когда паста сварится, слейте почти всю воду, оставив немного воды, в которой варились спагетти.",
# "Верните спагетти в кастрюлю и убавьте огонь до очень слабого.",
# "Влейте сливочно-яичную смесь в бекон, постоянно помешивая, около 30 секунд. Затем добавьте всё к спагетти и готовьте на слабом огне около 5 минут, аккуратно перемешивая.",
# "Подавайте, слегка посыпав сыром пармезан.",
#
#                 ],
#                 note: ""
#              },
#             en: {
#                 title: "Pasta Carbonara",
#                 meta:  {
#                     time: "15 min",
#                     servings: "Serves 2"
#                   },
#                 ingredients: [
#                 "200 ml cream (15–20%)",
# "180 g spaghetti",
# "150 g smoked bacon",
# "2 cloves of garlic",
# "1 egg yolk",
# "Salt, pepper",
# "Parmigiano for sprinkling",
#
#                 ],
#                 instructions: [
#                 "Cook the spaghetti in lightly salted water according to the package instructions.",
# "Meanwhile, fry the bacon over high heat and add the garlic.",
# "In a small bowl, mix the cream with the egg yolk, salt, and pepper.",
# "When the pasta is cooked, drain almost all the water, leaving a little of the spaghetti cooking water.",
# "Return the spaghetti to the pot and reduce the heat to very low.",
# "Pour the cream and egg mixture into the bacon, stirring constantly for about 30 seconds. Then add everything to the spaghetti and cook over low heat for about 5 minutes, stirring gently.",
# "Serve lightly sprinkled with Parmesan cheese.",
#
#                 ],
#                 note: ""
#              }
#         },

# %% [markdown]
# ### 6. На последнем этапе в файл script.js d поискать много else if и в конце добавить следующее:

# %%
print(sript_js_add)
# Out:
#  else if (path.includes('main_dish_pasta_carbonara')) {
# recipeKey = 'main_dish_pasta_carbonara';
# }
