# %%
recipe_id_name = "main_dish_orzo"

recipe_ru_name = "Орзо с греческой колбаской"
recipe_time_ru = "25 мин"
recipe_portion_ru = "6 порций"
ingredients_ru = [
  "500 г орзо",
  "500 г концентрированного томатного сока",
  "200 г греческой колбасы",
  "50 г феты",
  "1 луковица",
  "4 зубчика чеснока",
  "1 бульонный кубик",
  "Соль, перец, паприка, чили"]
instruction_ru = [
  "Сварите орзо в подсоленной воде согласно инструкции на упаковке.",
  "Тем временем обжарьте колбасу на сильном огне. Добавьте лук и выдавите чеснок.",
  "Когда орзо сварится, слейте почти всю воду, оставив небольшое количество воды, в которой варились макароны.",
  "Убавьте огонь до минимума, добавьте томатный сок, обжаренную колбасу с луком и чесноком, раскрошенную фету и приправы.",
  "Хорошо перемешайте, доведите до слабого кипения, затем снимите с огня и дайте постоять 5–10 минут перед подачей.",
  ]
note_ru = ''

recipe_eng_name = "Orzo with Greek Sausage"
recipe_time_eng = "25 min"
recipe_portion_eng = "6 servings"

ingredients_eng = [
  "500 g orzo",
  "500 g concentrated tomato juice",
  "200 g Greek sausage",
  "50 g feta",
  "1 onion",
  "4 cloves of garlic",
  "1 bouillon cube",
  "Salt, pepper, paprika, chili"
]

instruction_eng = [
  "Cook the orzo in salted water according to the package instructions.",
  "Meanwhile, fry the sausage over high heat. Add the onion and press in the garlic.",
  "When the orzo is cooked, drain almost all the water, leaving a small amount of the pasta cooking water.",
  "Reduce the heat to low, add the tomato juice, the fried sausage with onion and garlic, crumbled feta, and the seasonings.",
  "Mix well, bring to a gentle simmer, then remove from the heat and let it rest for 5–10 minutes before serving."
]

note_eng = ""

# %% [markdown]
# # Организационные вопросики

# %%
index_html_output = f'''
                    <!-- Рецепт {recipe_ru_name} -->
                    <a href="recipes/{recipe_id_name}.html" class="recipe-card"> 
                        <div class="recipe-image">
                            <img src="site-photos/{recipe_id_name}.jpg" alt="{recipe_ru_name}"> 
                            <div class="recipe-overlay">
                                <i class="fas fa-external-link-alt"></i>
                            </div>
                        </div>
                        <div class="recipe-info">
                            <h3>{recipe_ru_name}</h3> 
                            <p class="recipe-time"><i class="far fa-clock"></i> {recipe_time_ru} </p> 
                        </div>
                    </a>
                    <!-- Рецепт {recipe_ru_name} конец -->
                    
                    '''

# %%
ingredients_spin_new_html = ''
for ing_list_length in ingredients_ru:
    ingredients_spin_new_html += "<li>" + ing_list_length + "</li> \n"

instruction_spin_new_html = ''
for inst_list_length in instruction_ru:
    instruction_spin_new_html += "<li>" + inst_list_length + "</li> \n"

# %%
if note_ru != '':
    notes_new_html = f'''
                <div class="note">
                <p><strong>Совет:</strong> {note_ru} </p>
                </div>'''
else:
    notes_new_html = ''

# %%
print(ingredients_spin_new_html)
print(instruction_spin_new_html)
# Out:
# <li>600 г фарша</li>
# <li>500 г муки</li>
# <li>200 г ледяной воды</li>
# <li>1 луковица</li>
# <li>1/2 бульонного кубика</li>
# <li>Соль, перец</li>
#
# <li>Добавьте щепотку соли в ледяную воду и влейте ее в муку.</li>
# <li>Замешивайте тесто в течение 8–12 минут. Оно должно получиться мягким, тянуться, не рваться и не липнуть к рукам.</li>
# <li>Дайте тесту отдохнуть 30 минут.</li>
# <li>Измельчите лук в блендере и добавьте его в фарш.</li>
# <li>Растворите половину бульонного кубика в 50 мл воды и добавьте к фаршу. Приправьте солью и перцем, а также добавьте дополнительные специи по вкусу, например, паприки и чили, если хотите.</li>
# <li>Слегка припылите рабочую поверхность мукой и раскатайте тесто.</li>
# <li>Вырежьте кружочки диаметром 5–7 см. Отложите обрезки отдельно, не вмешивая их обратно в основное тесто.</li>
# <li>Выложите примерно по 1 чайной ложке фарша на каждый кружок.</li>
# <li>Смочите одну половину внешнего края водой, сложите в форме полумесяца, защипните края и сверните в пельмень.</li>
# <li>Если пельмени планируете есть сразу, отварите в кипящей подсоленной воде после всплытия минут 6-7</li>
# <li>Если пельмени замораживаете, то выложите готовые пельмени на припыленный мукой противень так, чтобы они не соприкасались.</li>
# <li>Охладите пельмени в холодильнике в течение 20–30 минут, затем уберите в морозилку.</li>
# <li>Через 4–6 часов переложите их в пакет или контейнер, где их можно хранить слоями.</li>
# <li>Чтобы сварить замороженные или свежие пельмени, бросьте их в кипящую воду и варите 6–7 минут после того, как они всплывут на поверхность.</li>

# %%
styler_text = '''<style>
        .recipe-page {
            max-width: 800px;
            margin: 40px auto;
            padding: 0 20px;
        }
        
        .back-link {
            display: inline-flex;
            align-items: center;
            gap: 8px;
            color: #8b4513;
            text-decoration: none;
            margin-bottom: 20px;
            font-weight: 500;
        }
        
        .back-link:hover {
            text-decoration: underline;
        }
        
        .recipe-header {
            text-align: center;
            margin-bottom: 40px;
        }
        
        .recipe-header h1 {
            color: #8b4513;
            font-size: 2.5rem;
            margin-bottom: 10px;
        }
        
        .recipe-meta {
            display: flex;
            justify-content: center;
            gap: 30px;
            color: #666;
            margin-bottom: 30px;
        }
        
        .recipe-image-main {
            width: 100%;
            height: 400px;
            object-fit: cover;
            border-radius: 15px;
            margin-bottom: 30px;
            box-shadow: 0 10px 25px rgba(0, 0, 0, 0.1);
        }
        
        .recipe-content {
            background: white;
            padding: 40px;
            border-radius: 15px;
            box-shadow: 0 5px 20px rgba(0, 0, 0, 0.05);
        }
        
        .ingredients, .instructions {
            margin-bottom: 40px;
        }
        
        .ingredients h2, .instructions h2 {
            color: #8b4513;
            border-bottom: 2px solid #f0e6d6;
            padding-bottom: 10px;
            margin-bottom: 20px;
        }
        
        .ingredients ul {
            list-style: none;
            padding: 0;
        }
        
        .ingredients li {
            padding: 8px 0;
            padding-left: 30px;
            position: relative;
            border-bottom: 1px solid #f0e6d6;
        }
        
        .ingredients li:before {
            content: "•";
            position: absolute;
            left: 0;
        }
        
        .instructions ol {
            padding-left: 20px;
        }
        
        .instructions li {
            margin-bottom: 15px;
            line-height: 1.6;
        }
        
        .note {
            background: #f9f3ec;
            padding: 20px;
            border-radius: 10px;
            border-left: 4px solid #d4a574;
            margin-top: 30px;
        }
    </style>'''

# %%
new_html_page_output = f'''
<!DOCTYPE html>
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>{recipe_ru_name} - Кулинарные заметки</title>
    <!-- Favicon (иконка вкладки) -->
    <link rel="icon" href="../assets/icons/icons8-girl-64.png" type="image/png">
    <link rel="stylesheet" href="../style.css">
    <script src="../script.js" defer></script>
    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css">
    {styler_text}
</head>
<body>
    <header class="main-header">
        <div class="header-top"> 
            <h1>Кулинарные заметки</h1>
        </div>
    </header>

    <main class="recipe-page">
        <a href="../index.html" class="back-link">
            <i class="fas fa-arrow-left"></i>
            Вернуться к рецептам
        </a>
        
        <div class="recipe-header">
            <h1>{recipe_ru_name}</h1>
            <div class="recipe-meta">
                <span><i class="far fa-clock"></i> {recipe_time_ru}</span>
                <span><i class="fas fa-user-friends"></i> {recipe_portion_ru}</span>
                
            </div>
        </div>
        
        <img src="../site-photos/{recipe_id_name}.jpg" 
             alt="{recipe_ru_name}" class="recipe-image-main">
        
        <div class="recipe-content">
            <div class="ingredients">
                <h2><i class="fas fa-shopping-basket"></i> Ингредиенты</h2>
                <ul>
                    {ingredients_spin_new_html}
                    

                </ul>
            </div>
            
            <div class="instructions">
                <h2><i class="fas fa-list-ol"></i> Способ приготовления</h2>
                <ol>
                    {instruction_spin_new_html}
                </ol>
            </div>
            
            {notes_new_html}
            
        </div>
    </main>

    <footer class="main-footer">
        <div class="footer-content">
            <div class="footer-lang-switcher">
                <button class="footer-lang-btn active" data-lang="ru">RU</button>
                <button class="footer-lang-btn" data-lang="en">EN</button>
            </div>
            <p>2026 Кулинарные заметки</p>
            <p class="footer-note">С любовью к вкусной еде ❤️</p>
        </div>
    </footer>

    <script src="../translations.js" defer></script>
    <script src="../script.js" defer></script>
</body>
</html>'''

# %%
meal_name_translation = f'''
        "{recipe_ru_name}": '''
meal_name_translation += '''{ '''
meal_name_translation += f''' 
            ru: "{recipe_ru_name}",
            en: "{recipe_eng_name}"'''
meal_name_translation += '''
            },'''

# %%
ingredient_shift_ru = ''
for ingredient_list in ingredients_ru:
    ingredient_shift_ru += '"' + ingredient_list + '", \n'

instruction_shift_ru = ''
for instruction_list in instruction_ru:
    instruction_shift_ru += '"' + instruction_list + '", \n'

ingredient_shift_eng = ''
for ingredient_list in ingredients_eng:
    ingredient_shift_eng += '"' + ingredient_list + '", \n'

instruction_shift_eng = ''
for instruction_list in instruction_eng:
    instruction_shift_eng += '"' + instruction_list + '", \n'

# %%
recipedetail_new_text = f'''
        "{recipe_id_name}": '''

recipedetail_new_text += ''' {
            ru: {
                title:'''
recipedetail_new_text += f''' "{recipe_ru_name}",
                meta: '''
recipedetail_new_text += ''' {
                    time: '''
recipedetail_new_text += f'''"{recipe_time_ru}",
                    servings: "{recipe_portion_ru}"
                 '''       
recipedetail_new_text += ''' },
                ingredients: [
                '''    
recipedetail_new_text += f'''{ingredient_shift_ru}
                ],
                instructions: [
                {instruction_shift_ru}
                ],
                note: "{note_ru}"
            '''     
recipedetail_new_text += ''' },
            en: {
                title:'''
recipedetail_new_text += f''' "{recipe_eng_name}",
                meta: '''
recipedetail_new_text += ''' {
                    time: '''
recipedetail_new_text += f'''"{recipe_time_eng}",
                    servings: "{recipe_portion_eng}"
                 '''       
recipedetail_new_text += ''' },
                ingredients: [
                '''    
recipedetail_new_text += f'''{ingredient_shift_eng}
                ],
                instructions: [
                {instruction_shift_eng}
                ],
                note: "{note_eng}"
            '''     
recipedetail_new_text += ''' }
        },'''

# %%
sript_js_add = f""" else if (path.includes('{recipe_id_name}')) """
sript_js_add += '''{
'''
sript_js_add += f"""recipeKey = '{recipe_id_name}';
"""
sript_js_add += '''}'''

# %% [markdown]
# # Добавление рецепта

# %% [markdown]
# ### 1. Добавляем в соответствующем месте в index.html следующее:

# %%
print(index_html_output)
# Out:
#                     <!-- Рецепт Пельмени -->
#                     <a href="recipes/main_dish_pelmeni.html" class="recipe-card">
#                         <div class="recipe-image">
#                             <img src="site-photos/main_dish_pelmeni.jpg" alt="Пельмени">
#                             <div class="recipe-overlay">
#                                 <i class="fas fa-external-link-alt"></i>
#                             </div>
#                         </div>
#                         <div class="recipe-info">
#                             <h3>Пельмени</h3>
#                             <p class="recipe-time"><i class="far fa-clock"></i> 180 мин </p>
#                         </div>
#                     </a>
#                     <!-- Рецепт Пельмени конец -->

# %% [markdown]
# ### 2.Далее создаем файл с названием:

# %%
print(recipe_id_name+'.html')
# Out:
# main_dish_pelmeni.html

# %% [markdown]
# ### 3. В новый файл вставляем следующее:

# %%
print(new_html_page_output)
# Out:
# <!DOCTYPE html>
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Пельмени - Кулинарные заметки</title>
#     <!-- Favicon (иконка вкладки) -->
#     <link rel="icon" href="../assets/icons/icons8-girl-64.png" type="image/png">
#     <link rel="stylesheet" href="../style.css">
#     <script src="../script.js" defer></script>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css">
#     <style>
#         .recipe-page {
#             max-width: 800px;
#             margin: 40px auto;
#             padding: 0 20px;
#         }
#
#         .back-link {
#             display: inline-flex;
#             align-items: center;
#             gap: 8px;
#             color: #8b4513;
#             text-decoration: none;
#             margin-bottom: 20px;
#             font-weight: 500;
#         }
#
#         .back-link:hover {
#             text-decoration: underline;
#         }
#
#         .recipe-header {
#             text-align: center;
#             margin-bottom: 40px;
#         }
#
#         .recipe-header h1 {
#             color: #8b4513;
#             font-size: 2.5rem;
#             margin-bottom: 10px;
#         }
#
#         .recipe-meta {
#             display: flex;
#             justify-content: center;
#             gap: 30px;
#             color: #666;
#             margin-bottom: 30px;
#         }
#
#         .recipe-image-main {
#             width: 100%;
#             height: 400px;
#             object-fit: cover;
#             border-radius: 15px;
#             margin-bottom: 30px;
#             box-shadow: 0 10px 25px rgba(0, 0, 0, 0.1);
#         }
#
#         .recipe-content {
#             background: white;
#             padding: 40px;
#             border-radius: 15px;
#             box-shadow: 0 5px 20px rgba(0, 0, 0, 0.05);
#         }
#
#         .ingredients, .instructions {
#             margin-bottom: 40px;
#         }
#
#         .ingredients h2, .instructions h2 {
#             color: #8b4513;
#             border-bottom: 2px solid #f0e6d6;
#             padding-bottom: 10px;
#             margin-bottom: 20px;
#         }
#
#         .ingredients ul {
#             list-style: none;
#             padding: 0;
#         }
#
#         .ingredients li {
#             padding: 8px 0;
#             padding-left: 30px;
#             position: relative;
#             border-bottom: 1px solid #f0e6d6;
#         }
#
#         .ingredients li:before {
#             content: "•";
#             position: absolute;
#             left: 0;
#         }
#
#         .instructions ol {
#             padding-left: 20px;
#         }
#
#         .instructions li {
#             margin-bottom: 15px;
#             line-height: 1.6;
#         }
#
#         .note {
#             background: #f9f3ec;
#             padding: 20px;
#             border-radius: 10px;
#             border-left: 4px solid #d4a574;
#             margin-top: 30px;
#         }
#     </style>
# </head>
# <body>
#     <header class="main-header">
#         <div class="header-top">
#             <h1>Кулинарные заметки</h1>
#         </div>
#     </header>
#
#     <main class="recipe-page">
#         <a href="../index.html" class="back-link">
#             <i class="fas fa-arrow-left"></i>
#             Вернуться к рецептам
#         </a>
#
#         <div class="recipe-header">
#             <h1>Пельмени</h1>
#             <div class="recipe-meta">
#                 <span><i class="far fa-clock"></i> 180 мин</span>
#                 <span><i class="fas fa-user-friends"></i> 6 порций</span>
#
#             </div>
#         </div>
#
#         <img src="../site-photos/main_dish_pelmeni.jpg"
#              alt="Пельмени" class="recipe-image-main">
#
#         <div class="recipe-content">
#             <div class="ingredients">
#                 <h2><i class="fas fa-shopping-basket"></i> Ингредиенты</h2>
#                 <ul>
#                     <li>600 г фарша</li>
# <li>500 г муки</li>
# <li>200 г ледяной воды</li>
# <li>1 луковица</li>
# <li>1/2 бульонного кубика</li>
# <li>Соль, перец</li>
#
#
#
#                 </ul>
#             </div>
#
#             <div class="instructions">
#                 <h2><i class="fas fa-list-ol"></i> Способ приготовления</h2>
#                 <ol>
#                     <li>Добавьте щепотку соли в ледяную воду и влейте ее в муку.</li>
# <li>Замешивайте тесто в течение 8–12 минут. Оно должно получиться мягким, тянуться, не рваться и не липнуть к рукам.</li>
# <li>Дайте тесту отдохнуть 30 минут.</li>
# <li>Измельчите лук в блендере и добавьте его в фарш.</li>
# <li>Растворите половину бульонного кубика в 50 мл воды и добавьте к фаршу. Приправьте солью и перцем, а также добавьте дополнительные специи по вкусу, например, паприки и чили, если хотите.</li>
# <li>Слегка припылите рабочую поверхность мукой и раскатайте тесто.</li>
# <li>Вырежьте кружочки диаметром 5–7 см. Отложите обрезки отдельно, не вмешивая их обратно в основное тесто.</li>
# <li>Выложите примерно по 1 чайной ложке фарша на каждый кружок.</li>
# <li>Смочите одну половину внешнего края водой, сложите в форме полумесяца, защипните края и сверните в пельмень.</li>
# <li>Если пельмени планируете есть сразу, отварите в кипящей подсоленной воде после всплытия минут 6-7</li>
# <li>Если пельмени замораживаете, то выложите готовые пельмени на припыленный мукой противень так, чтобы они не соприкасались.</li>
# <li>Охладите пельмени в холодильнике в течение 20–30 минут, затем уберите в морозилку.</li>
# <li>Через 4–6 часов переложите их в пакет или контейнер, где их можно хранить слоями.</li>
# <li>Чтобы сварить замороженные или свежие пельмени, бросьте их в кипящую воду и варите 6–7 минут после того, как они всплывут на поверхность.</li>
#
#                 </ol>
#             </div>
#
#
#                 <div class="note">
#                 <p><strong>Совет:</strong> Лучше не раскатывать все тесто сразу, а разделить на несколько частей и сделать несколько раскаток. Остатки теста можно использовать для последней порции пельменей. </p>
#                 </div>
#
#         </div>
#     </main>
#
#     <footer class="main-footer">
#         <div class="footer-content">
#             <div class="footer-lang-switcher">
#                 <button class="footer-lang-btn active" data-lang="ru">RU</button>
#                 <button class="footer-lang-btn" data-lang="en">EN</button>
#             </div>
#             <p>2026 Кулинарные заметки</p>
#             <p class="footer-note">С любовью к вкусной еде ❤️</p>
#         </div>
#     </footer>
#
#     <script src="../translations.js" defer></script>
#     <script src="../script.js" defer></script>
# </body>
# </html>

# %% [markdown]
# ### 4. В файл translations.js добавляем в раздел с названиями блюд:

# %%
print(meal_name_translation)
# Out:
#         "Пельмени": {
#             ru: "Пельмени",
#             en: "Pelmeni"
#             },

# %% [markdown]
# ### 5. Затем в этом же файле вставляем в конце в разделе recipeDetails:

# %%
print(recipedetail_new_text)
# Out:
#         "main_dish_pelmeni":  {
#             ru: {
#                 title: "Пельмени",
#                 meta:  {
#                     time: "180 мин",
#                     servings: "6 порций"
#                   },
#                 ingredients: [
#                 "600 г фарша",
# "500 г муки",
# "200 г ледяной воды",
# "1 луковица",
# "1/2 бульонного кубика",
# "Соль, перец",
#
#                 ],
#                 instructions: [
#                 "Добавьте щепотку соли в ледяную воду и влейте ее в муку.",
# "Замешивайте тесто в течение 8–12 минут. Оно должно получиться мягким, тянуться, не рваться и не липнуть к рукам.",
# "Дайте тесту отдохнуть 30 минут.",
# "Измельчите лук в блендере и добавьте его в фарш.",
# "Растворите половину бульонного кубика в 50 мл воды и добавьте к фаршу. Приправьте солью и перцем, а также добавьте дополнительные специи по вкусу, например, паприки и чили, если хотите.",
# "Слегка припылите рабочую поверхность мукой и раскатайте тесто.",
# "Вырежьте кружочки диаметром 5–7 см. Отложите обрезки отдельно, не вмешивая их обратно в основное тесто.",
# "Выложите примерно по 1 чайной ложке фарша на каждый кружок.",
# "Смочите одну половину внешнего края водой, сложите в форме полумесяца, защипните края и сверните в пельмень.",
# "Если пельмени планируете есть сразу, отварите в кипящей подсоленной воде после всплытия минут 6-7",
# "Если пельмени замораживаете, то выложите готовые пельмени на припыленный мукой противень так, чтобы они не соприкасались.",
# "Охладите пельмени в холодильнике в течение 20–30 минут, затем уберите в морозилку.",
# "Через 4–6 часов переложите их в пакет или контейнер, где их можно хранить слоями.",
# "Чтобы сварить замороженные или свежие пельмени, бросьте их в кипящую воду и варите 6–7 минут после того, как они всплывут на поверхность.",
#
#                 ],
#                 note: "Лучше не раскатывать все тесто сразу, а разделить на несколько частей и сделать несколько раскаток. Остатки теста можно использовать для последней порции пельменей."
#              },
#             en: {
#                 title: "Pelmeni",
#                 meta:  {
#                     time: "180 min",
#                     servings: "6 servings"
#                   },
#                 ingredients: [
#                 "600 g ground meat",
# "500 g flour",
# "200 g ice-cold water",
# "1 onion",
# "1/2 bouillon cube",
# "Salt, pepper",
#
#                 ],
#                 instructions: [
#                 "Add a pinch of salt to the ice-cold water and pour it into the flour.",
# "Knead the dough for 8–12 minutes. It should become soft, elastic, not tear, and not stick to your hands.",
# "Let the dough rest for 30 minutes.",
# "Blend the onion and add it to the ground meat.",
# "Dissolve half of the bouillon cube in 50 ml of water and add it to the meat. Season with salt and pepper, and add additional spices to taste, such as paprika and chili if desired.",
# "Lightly dust the work surface with flour and roll out the dough.",
# "Cut out circles 5–7 cm in diameter. Set the scraps aside without kneading them back into the main dough.",
# "Place about 1 teaspoon of filling onto each circle.",
# "Moisten one half of the outer edge with water, fold into a half-moon shape, pinch the edges together, and shape into a dumpling.",
# "If you plan to eat the dumplings right away, boil them in salted water for 6–7 minutes after they float to the surface.",
# "If you are freezing the dumplings, place them on a flour-dusted tray so that they do not touch each other.",
# "Chill the dumplings in the refrigerator for 20–30 minutes, then transfer them to the freezer.",
# "After 4–6 hours, move them to a bag or container where they can be stored in layers.",
# "To cook frozen or fresh dumplings, drop them into boiling water and cook for 6–7 minutes after they float to the surface.",
#
#                 ],
#                 note: "It is better not to roll out all the dough at once, but to divide it into several parts and do several rollouts. The remaining dough can be used for the final batch of dumplings."
#              }
#         },

# %% [markdown]
# ### 6. На последнем этапе в файл script.js d поискать много else if и в конце добавить следующее:

# %%
print(sript_js_add)
# Out:
#  else if (path.includes('main_dish_pelmeni')) {
# recipeKey = 'main_dish_pelmeni';
# }
