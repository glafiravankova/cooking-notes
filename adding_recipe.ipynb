# %%
recipe_id_name = "snaks_garlic_croutons"

recipe_ru_name = "Чесночные сухарики"
recipe_time_ru = "15 мин"
recipe_portion_ru = "2 порции"
ingredients_ru = [
    "40 г белого хлеба (4 ломтика)",
    "4 головки чеснока",
    "5 мл растительного масла",
    "Щепотка соли",
]

instruction_ru = [
    "Разогрейте духовку до 180°C.",
    "Нарежьте хлеб небольшими кубиками. Я предпочитаю срезать корочки. Переложите нарезанный хлеб в миску.",
    "В отдельной миске смешайте растопленное сливочное масло, измельченный чеснок и соль.",
    "Залейте полученной смесью хлеб, накройте миску тарелкой и энергично встряхните, чтобы масло равномерно распределилось по всем кубикам.",
    "Выложите хлеб на противень в один слой и запекайте 10–15 минут до золотистого цвета."
    ]

note_ru = "В масло можете добавить все, с чем любите сухарики, например, сушеный орегано, базилик и даже тертый пармезан."

recipe_eng_name = "Garlic croutons"
recipe_time_eng = "15 minutes"
recipe_portion_eng = "Serves 2"

ingredients_eng = [
    "40 g white bread (4 slices)",
    "4 cloves of garlic",
    "5 ml vegetable oil",
    "A pinch of salt"
]

instruction_eng = [
    "Preheat the oven to 180°C.",
    "Cut the bread into small cubes. If desired, remove the crusts. Transfer to a bowl.",
    "In a separate bowl, combine the oil, finely grated garlic, and salt.",
    "Pour the seasoned oil over the bread, cover the bowl with a plate, and shake gently to distribute evenly.",
    "Spread the bread cubes in a single layer and bake for 10–15 minutes, until golden and crisp."
]

note_eng = "You may enrich the oil with your preferred seasonings, such as dried oregano, basil, or even finely grated Parmesan."

# %% [markdown]
# # Организационные вопросики

# %%
index_html_output = f'''
                    <!-- Рецепт {recipe_ru_name} -->
                    <a href="recipes/{recipe_id_name}.html" class="recipe-card"> 
                        <div class="recipe-image">
                            <img src="site-photos/{recipe_id_name}.jpg" alt="{recipe_ru_name}"> 
                            <div class="recipe-overlay">
                                <i class="fas fa-external-link-alt"></i>
                            </div>
                        </div>
                        <div class="recipe-info">
                            <h3>{recipe_ru_name}</h3> 
                            <p class="recipe-time"><i class="far fa-clock"></i> {recipe_time_ru} </p> 
                        </div>
                    </a>
                    <!-- Рецепт {recipe_ru_name} конец -->
                    
                    '''

# %%
ingredients_spin_new_html = ''
for ing_list_length in ingredients_ru:
    ingredients_spin_new_html += "<li>" + ing_list_length + "</li> \n"

instruction_spin_new_html = ''
for inst_list_length in instruction_ru:
    instruction_spin_new_html += "<li>" + inst_list_length + "</li> \n"

# %%
if note_ru != '':
    notes_new_html = f'''
                <div class="note">
                <p><strong>Совет:</strong> {note_ru} </p>
                </div>'''
else:
    notes_new_html = ''

# %%
print(ingredients_spin_new_html)
print(instruction_spin_new_html)
# Out:
# <li>40 г белого хлеба (4 ломтика)</li>
# <li>4 головки чеснока</li>
# <li>5 мл растительного масла</li>
# <li>Щепотка соли</li>
#
# <li>Разогрейте духовку до 180°C.</li>
# <li>Нарежьте хлеб на маленький кубик. Я люблю срезать корочки от хлеба. Переложите в миску.</li>
# <li>В отдельной мисочке добавьте масло, натертый чеснок, соль и перемешайте.</li>
# <li>Добавьте масло к хлебу, закройте миску тарелкой и взболтайте так, чтобы масло распределилось по кубикам хлеба.</li>
# <li>Затем выложите в один слой хлеб и отправьте в духовку на 10-15 минут до образования золотистой корочки.</li>

# %%
styler_text = '''<style>
        .recipe-page {
            max-width: 800px;
            margin: 40px auto;
            padding: 0 20px;
        }
        
        .back-link {
            display: inline-flex;
            align-items: center;
            gap: 8px;
            color: #8b4513;
            text-decoration: none;
            margin-bottom: 20px;
            font-weight: 500;
        }
        
        .back-link:hover {
            text-decoration: underline;
        }
        
        .recipe-header {
            text-align: center;
            margin-bottom: 40px;
        }
        
        .recipe-header h1 {
            color: #8b4513;
            font-size: 2.5rem;
            margin-bottom: 10px;
        }
        
        .recipe-meta {
            display: flex;
            justify-content: center;
            gap: 30px;
            color: #666;
            margin-bottom: 30px;
        }
        
        .recipe-image-main {
            width: 100%;
            height: 400px;
            object-fit: cover;
            border-radius: 15px;
            margin-bottom: 30px;
            box-shadow: 0 10px 25px rgba(0, 0, 0, 0.1);
        }
        
        .recipe-content {
            background: white;
            padding: 40px;
            border-radius: 15px;
            box-shadow: 0 5px 20px rgba(0, 0, 0, 0.05);
        }
        
        .ingredients, .instructions {
            margin-bottom: 40px;
        }
        
        .ingredients h2, .instructions h2 {
            color: #8b4513;
            border-bottom: 2px solid #f0e6d6;
            padding-bottom: 10px;
            margin-bottom: 20px;
        }
        
        .ingredients ul {
            list-style: none;
            padding: 0;
        }
        
        .ingredients li {
            padding: 8px 0;
            padding-left: 30px;
            position: relative;
            border-bottom: 1px solid #f0e6d6;
        }
        
        .ingredients li:before {
            content: "•";
            position: absolute;
            left: 0;
        }
        
        .instructions ol {
            padding-left: 20px;
        }
        
        .instructions li {
            margin-bottom: 15px;
            line-height: 1.6;
        }
        
        .note {
            background: #f9f3ec;
            padding: 20px;
            border-radius: 10px;
            border-left: 4px solid #d4a574;
            margin-top: 30px;
        }
    </style>'''

# %%
new_html_page_output = f'''
<!DOCTYPE html>
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>{recipe_ru_name} - Кулинарные заметки</title>
    <!-- Favicon (иконка вкладки) -->
    <link rel="icon" href="../assets/icons/icons8-girl-64.png" type="image/png">
    <link rel="stylesheet" href="../style.css">
    <script src="../script.js" defer></script>
    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css">
    {styler_text}
</head>
<body>
    <header class="main-header">
        <div class="header-top"> 
            <h1>Кулинарные заметки</h1>
        </div>
    </header>

    <main class="recipe-page">
        <a href="../index.html" class="back-link">
            <i class="fas fa-arrow-left"></i>
            Вернуться к рецептам
        </a>
        
        <div class="recipe-header">
            <h1>{recipe_ru_name}</h1>
            <div class="recipe-meta">
                <span><i class="far fa-clock"></i> {recipe_time_ru}</span>
                <span><i class="fas fa-user-friends"></i> {recipe_portion_ru}</span>
                
            </div>
        </div>
        
        <img src="../site-photos/{recipe_id_name}.jpg" 
             alt="{recipe_ru_name}" class="recipe-image-main">
        
        <div class="recipe-content">
            <div class="ingredients">
                <h2><i class="fas fa-shopping-basket"></i> Ингредиенты</h2>
                <ul>
                    {ingredients_spin_new_html}
                    

                </ul>
            </div>
            
            <div class="instructions">
                <h2><i class="fas fa-list-ol"></i> Способ приготовления</h2>
                <ol>
                    {instruction_spin_new_html}
                </ol>
            </div>
            
            {notes_new_html}
            
        </div>
    </main>

    <footer class="main-footer">
        <div class="footer-content">
            <div class="footer-lang-switcher">
                <button class="footer-lang-btn active" data-lang="ru">RU</button>
                <button class="footer-lang-btn" data-lang="en">EN</button>
            </div>
            <p>2026 Кулинарные заметки</p>
            <p class="footer-note">С любовью к вкусной еде ❤️</p>
        </div>
    </footer>

    <script src="../translations.js" defer></script>
    <script src="../script.js" defer></script>
</body>
</html>'''

# %%
meal_name_translation = f'''
        "{recipe_ru_name}": '''
meal_name_translation += '''{ '''
meal_name_translation += f''' 
            ru: "{recipe_ru_name}",
            en: "{recipe_eng_name}"'''
meal_name_translation += '''
            },'''

# %%
ingredient_shift_ru = ''
for ingredient_list in ingredients_ru:
    ingredient_shift_ru += '"' + ingredient_list + '", \n'

instruction_shift_ru = ''
for instruction_list in instruction_ru:
    instruction_shift_ru += '"' + instruction_list + '", \n'

ingredient_shift_eng = ''
for ingredient_list in ingredients_eng:
    ingredient_shift_eng += '"' + ingredient_list + '", \n'

instruction_shift_eng = ''
for instruction_list in instruction_eng:
    instruction_shift_eng += '"' + instruction_list + '", \n'

# %%
recipedetail_new_text = f'''
        "{recipe_id_name}": '''

recipedetail_new_text += ''' {
            ru: {
                title:'''
recipedetail_new_text += f''' "{recipe_ru_name}",
                meta: '''
recipedetail_new_text += ''' {
                    time: '''
recipedetail_new_text += f'''"{recipe_time_ru}",
                    servings: "{recipe_portion_ru}"
                 '''       
recipedetail_new_text += ''' },
                ingredients: [
                '''    
recipedetail_new_text += f'''{ingredient_shift_ru}
                ],
                instructions: [
                {instruction_shift_ru}
                ],
                note: "{note_ru}"
            '''     
recipedetail_new_text += ''' },
            en: {
                title:'''
recipedetail_new_text += f''' "{recipe_eng_name}",
                meta: '''
recipedetail_new_text += ''' {
                    time: '''
recipedetail_new_text += f'''"{recipe_time_eng}",
                    servings: "{recipe_portion_eng}"
                 '''       
recipedetail_new_text += ''' },
                ingredients: [
                '''    
recipedetail_new_text += f'''{ingredient_shift_eng}
                ],
                instructions: [
                {instruction_shift_eng}
                ],
                note: "{note_eng}"
            '''     
recipedetail_new_text += ''' }
        },'''

# %%
sript_js_add = f""" else if (path.includes('{recipe_id_name}')) """
sript_js_add += '''{
'''
sript_js_add += f"""recipeKey = '{recipe_id_name}';
"""
sript_js_add += '''}'''

# %% [markdown]
# # Добавление рецепта

# %% [markdown]
# ### 1. Добавляем в соответствующем месте в index.html следующее:

# %%
print(index_html_output)
# Out:
#                     <!-- Рецепт Чесночные сухарики -->
#                     <a href="recipes/snaks_garlic_croutons.html" class="recipe-card">
#                         <div class="recipe-image">
#                             <img src="site-photos/snaks_garlic_croutons.jpg" alt="Чесночные сухарики">
#                             <div class="recipe-overlay">
#                                 <i class="fas fa-external-link-alt"></i>
#                             </div>
#                         </div>
#                         <div class="recipe-info">
#                             <h3>Чесночные сухарики</h3>
#                             <p class="recipe-time"><i class="far fa-clock"></i> 15 мин </p>
#                         </div>
#                     </a>
#                     <!-- Рецепт Чесночные сухарики конец -->

# %% [markdown]
# ### 2.Далее создаем файл с названием:

# %%
print(recipe_id_name+'.html')
# Out:
# snaks_garlic_croutons.html

# %% [markdown]
# ### 3. В новый файл вставляем следующее:

# %%
print(new_html_page_output)
# Out:
# <!DOCTYPE html>
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Чесночные сухарики - Кулинарные заметки</title>
#     <!-- Favicon (иконка вкладки) -->
#     <link rel="icon" href="../assets/icons/icons8-girl-64.png" type="image/png">
#     <link rel="stylesheet" href="../style.css">
#     <script src="../script.js" defer></script>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css">
#     <style>
#         .recipe-page {
#             max-width: 800px;
#             margin: 40px auto;
#             padding: 0 20px;
#         }
#
#         .back-link {
#             display: inline-flex;
#             align-items: center;
#             gap: 8px;
#             color: #8b4513;
#             text-decoration: none;
#             margin-bottom: 20px;
#             font-weight: 500;
#         }
#
#         .back-link:hover {
#             text-decoration: underline;
#         }
#
#         .recipe-header {
#             text-align: center;
#             margin-bottom: 40px;
#         }
#
#         .recipe-header h1 {
#             color: #8b4513;
#             font-size: 2.5rem;
#             margin-bottom: 10px;
#         }
#
#         .recipe-meta {
#             display: flex;
#             justify-content: center;
#             gap: 30px;
#             color: #666;
#             margin-bottom: 30px;
#         }
#
#         .recipe-image-main {
#             width: 100%;
#             height: 400px;
#             object-fit: cover;
#             border-radius: 15px;
#             margin-bottom: 30px;
#             box-shadow: 0 10px 25px rgba(0, 0, 0, 0.1);
#         }
#
#         .recipe-content {
#             background: white;
#             padding: 40px;
#             border-radius: 15px;
#             box-shadow: 0 5px 20px rgba(0, 0, 0, 0.05);
#         }
#
#         .ingredients, .instructions {
#             margin-bottom: 40px;
#         }
#
#         .ingredients h2, .instructions h2 {
#             color: #8b4513;
#             border-bottom: 2px solid #f0e6d6;
#             padding-bottom: 10px;
#             margin-bottom: 20px;
#         }
#
#         .ingredients ul {
#             list-style: none;
#             padding: 0;
#         }
#
#         .ingredients li {
#             padding: 8px 0;
#             padding-left: 30px;
#             position: relative;
#             border-bottom: 1px solid #f0e6d6;
#         }
#
#         .ingredients li:before {
#             content: "•";
#             position: absolute;
#             left: 0;
#         }
#
#         .instructions ol {
#             padding-left: 20px;
#         }
#
#         .instructions li {
#             margin-bottom: 15px;
#             line-height: 1.6;
#         }
#
#         .note {
#             background: #f9f3ec;
#             padding: 20px;
#             border-radius: 10px;
#             border-left: 4px solid #d4a574;
#             margin-top: 30px;
#         }
#     </style>
# </head>
# <body>
#     <header class="main-header">
#         <div class="header-top">
#             <h1>Кулинарные заметки</h1>
#         </div>
#     </header>
#
#     <main class="recipe-page">
#         <a href="../index.html" class="back-link">
#             <i class="fas fa-arrow-left"></i>
#             Вернуться к рецептам
#         </a>
#
#         <div class="recipe-header">
#             <h1>Чесночные сухарики</h1>
#             <div class="recipe-meta">
#                 <span><i class="far fa-clock"></i> 15 мин</span>
#                 <span><i class="fas fa-user-friends"></i> 2 порции</span>
#
#             </div>
#         </div>
#
#         <img src="../site-photos/snaks_garlic_croutons.jpg"
#              alt="Чесночные сухарики" class="recipe-image-main">
#
#         <div class="recipe-content">
#             <div class="ingredients">
#                 <h2><i class="fas fa-shopping-basket"></i> Ингредиенты</h2>
#                 <ul>
#                     <li>40 г белого хлеба (4 ломтика)</li>
# <li>4 головки чеснока</li>
# <li>5 мл растительного масла</li>
# <li>Щепотка соли</li>
#
#
#
#                 </ul>
#             </div>
#
#             <div class="instructions">
#                 <h2><i class="fas fa-list-ol"></i> Способ приготовления</h2>
#                 <ol>
#                     <li>Разогрейте духовку до 180°C.</li>
# <li>Нарежьте хлеб на маленький кубик. Я люблю срезать корочки от хлеба. Переложите в миску.</li>
# <li>В отдельной мисочке добавьте масло, натертый чеснок, соль и перемешайте.</li>
# <li>Добавьте масло к хлебу, закройте миску тарелкой и взболтайте так, чтобы масло распределилось по кубикам хлеба.</li>
# <li>Затем выложите в один слой хлеб и отправьте в духовку на 10-15 минут до образования золотистой корочки.</li>
#
#                 </ol>
#             </div>
#
#
#                 <div class="note">
#                 <p><strong>Совет:</strong> В масло можете добавить все, с чем любите сухарики, например, сушеный орегано, базилик и даже тертый пармезан. </p>
#                 </div>
#
#         </div>
#     </main>
#
#     <footer class="main-footer">
#         <div class="footer-content">
#             <div class="footer-lang-switcher">
#                 <button class="footer-lang-btn active" data-lang="ru">RU</button>
#                 <button class="footer-lang-btn" data-lang="en">EN</button>
#             </div>
#             <p>2026 Кулинарные заметки</p>
#             <p class="footer-note">С любовью к вкусной еде ❤️</p>
#         </div>
#     </footer>
#
#     <script src="../translations.js" defer></script>
#     <script src="../script.js" defer></script>
# </body>
# </html>

# %% [markdown]
# ### 4. В файл translations.js добавляем в раздел с названиями блюд:

# %%
print(meal_name_translation)
# Out:
#         "Чесночные сухарики": {
#             ru: "Чесночные сухарики",
#             en: "Garlic croutons"
#             },

# %% [markdown]
# ### 5. Затем в этом же файле вставляем в конце в разделе recipeDetails:

# %%
print(recipedetail_new_text)
# Out:
#         "snaks_garlic_croutons":  {
#             ru: {
#                 title: "Чесночные сухарики",
#                 meta:  {
#                     time: "15 мин",
#                     servings: "2 порции"
#                   },
#                 ingredients: [
#                 "40 г белого хлеба (4 ломтика)",
# "4 головки чеснока",
# "5 мл растительного масла",
# "Щепотка соли",
#
#                 ],
#                 instructions: [
#                 "Разогрейте духовку до 180°C.",
# "Нарежьте хлеб на маленький кубик. Я люблю срезать корочки от хлеба. Переложите в миску.",
# "В отдельной мисочке добавьте масло, натертый чеснок, соль и перемешайте.",
# "Добавьте масло к хлебу, закройте миску тарелкой и взболтайте так, чтобы масло распределилось по кубикам хлеба.",
# "Затем выложите в один слой хлеб и отправьте в духовку на 10-15 минут до образования золотистой корочки.",
#
#                 ],
#                 note: "В масло можете добавить все, с чем любите сухарики, например, сушеный орегано, базилик и даже тертый пармезан."
#              },
#             en: {
#                 title: "Garlic croutons",
#                 meta:  {
#                     time: "15 minutes",
#                     servings: "Serves 2"
#                   },
#                 ingredients: [
#                 "40 g white bread (4 slices)",
# "4 cloves of garlic",
# "5 ml vegetable oil",
# "A pinch of salt",
#
#                 ],
#                 instructions: [
#                 "Preheat the oven to 180°C.",
# "Cut the bread into small cubes. If desired, remove the crusts. Transfer to a bowl.",
# "In a separate bowl, combine the oil, finely grated garlic, and salt.",
# "Pour the seasoned oil over the bread, cover the bowl with a plate, and shake gently to distribute evenly.",
# "Spread the bread cubes in a single layer and bake for 10–15 minutes, until golden and crisp.",
#
#                 ],
#                 note: "You may enrich the oil with your preferred seasonings, such as dried oregano, basil, or even finely grated Parmesan."
#              }
#         },

# %% [markdown]
# ### 6. На последнем этапе в файл script.js d поискать много else if и в конце добавить следующее:

# %%
print(sript_js_add)
# Out:
#  else if (path.includes('snaks_garlic_croutons')) {
# recipeKey = 'snaks_garlic_croutons';
# }
