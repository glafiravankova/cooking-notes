# %%
recipe_id_name = "soup_creamy_pumpkin_soup"

recipe_ru_name = "Крем-суп из тыквы"
recipe_time_ru = "180 мин"
recipe_portion_ru = "6 порций"
ingredients_ru = [
    "1 кг очищенной тыквы",
    "2 средние моркови",
    "2 средних лука",
    "3 зубчика чеснока",
    "1 ч.л. сухого имбиря",
    "800-900 мл бульона (можно заменить на воду)",
    "200 мл 20% сливок",
    "Соль, перец"
]

instruction_ru = [
"Тыкву нарежьте кубиками со стороной 2-3 см. Морковь нарежьте тонкими кружочками или полукружьями. Лук нарежьте мелким кубиком.",
"Сначала обжарьте лук до прозрачности. Добавьте морковь, жарьте еще 5 минут. Добавьте свежий чеснок и имбирь, жарьте 1 минуту.",
"Перемешайте и прогревайте специи вместе с овощами буквально 30-60 секунд.",
"Высыпьте всю тыкву в кастрюлю. Перемешайте и готовьте все вместе 5-7 минут. Тыква должна немного поджариться.",
"Залейте овощи горячей водой или бульоном. Жидкость должна почти полностью покрывать овощи.",
"Добавьте соль, перец. Доведите до кипения, убавьте огонь до минимума, накройте крышкой и варите до мягкости овощей.",
"Снимите кастрюлю с плиты. Дайте супу постоять 2-3 минуты, чтобы он немного остыл.",
"Возьмите погружной блендер и тщательно измельчите содержимое кастрюли до состояния абсолютно гладкого пюре. Движения лучше делать круговыми, чтобы захватить все кусочки. Для идеальной текстуры пропустите суп через сито.",
"Влейте в суп-пюре сливки и тщательно перемешайте ложкой. Поставьте кастрюлю на самый маленький огонь. Если суп получился слишком густой, добавьте еще бульона (или воды).",
"Прогревайте суп, постоянно помешивая. Как только появятся первые пузырьки воздуха, сразу выключайте."
]

note_ru = "К крем-супу отлично подойдут <a href='snaks_garlic_croutons.html' class='elegant-link keep-link'>чесночные сухарики. Или используйте</a>."

recipe_eng_name = "Сreamy pumpkin soup"
recipe_time_eng = "180 minutes"
recipe_portion_eng = "Serves 6"

ingredients_eng = [
    "1 kg peeled pumpkin",
    "2 medium carrots",
    "2 medium onions",
    "3 garlic cloves",
    "1 tsp ground ginger",
    "800–900 ml broth (can be replaced with water)",
    "200 ml 20% cream",
    "Salt, black pepper"
]

instruction_eng = [
    "Cut the pumpkin into 2–3 cm cubes. Slice the carrots into thin rounds or half-moons. Dice the onions finely.",
    "First, sauté the onions for 3–4 minutes. Add the carrots and cook for another 5 minutes. Add fresh garlic and ginger, cooking for 1 minute.",
    "Stir and heat the spices with the vegetables for 30–60 seconds.",
    "Add all the pumpkin to the pot, mix, and cook together for 5–7 minutes until the pumpkin starts to brown slightly.",
    "Pour in hot water or broth so that the liquid almost fully covers the vegetables.",
    "Season with salt and pepper. Bring to a boil, then reduce heat to a minimum, cover, and simmer until the vegetables are tender.",
    "Remove the pot from the heat and let the soup rest for 2–3 minutes to cool slightly.",
    "Use an immersion blender to puree the soup until completely smooth. Move the blender in circular motions to capture all pieces. For an ideal texture, strain the soup through a fine sieve.",
    "Stir in the cream thoroughly and place the pot over the lowest heat. If the soup is too thick, add more broth (or water).",
    "Heat the soup while stirring constantly. As soon as the first bubbles appear, immediately remove from heat."
]

note_eng = "<a href='snaks_garlic_croutons.html' class='elegant-link keep-link'>Garlic croutons</a> fit here perfectly."

# %% [markdown]
# # Организационные вопросики

# %%
index_html_output = f'''
                    <!-- Рецепт {recipe_ru_name} -->
                    <a href="recipes/{recipe_id_name}.html" class="recipe-card"> 
                        <div class="recipe-image">
                            <img src="site-photos/{recipe_id_name}.jpg" alt="{recipe_ru_name}"> 
                            <div class="recipe-overlay">
                                <i class="fas fa-external-link-alt"></i>
                            </div>
                        </div>
                        <div class="recipe-info">
                            <h3>{recipe_ru_name}</h3> 
                            <p class="recipe-time"><i class="far fa-clock"></i> {recipe_time_ru} </p> 
                        </div>
                    </a>
                    <!-- Рецепт {recipe_ru_name} конец -->
                    
                    '''

# %%
ingredients_spin_new_html = ''
for ing_list_length in ingredients_ru:
    ingredients_spin_new_html += "<li>" + ing_list_length + "</li> \n"

instruction_spin_new_html = ''
for inst_list_length in instruction_ru:
    instruction_spin_new_html += "<li>" + inst_list_length + "</li> \n"

# %%
if note_ru != '':
    notes_new_html = f'''
                <div class="note">
                <p><strong>Совет:</strong> {note_ru} </p>
                </div>'''
else:
    notes_new_html = ''

# %%
print(ingredients_spin_new_html)
print(instruction_spin_new_html)
# Out:
# <li>1 кг очищенной тыквы</li>
# <li>2 средние моркови</li>
# <li>2 средних лука</li>
# <li>3 зубчика чеснока</li>
# <li>1 ч.л. сухого имбиря</li>
# <li>800-900 мл бульона (можно заменить на воду)</li>
# <li>200 мл 20% сливок</li>
# <li>Соль, перец</li>
#
# <li>Тыкву нарежьте кубиками со стороной 2-3 см. Морковь нарежьте тонкими кружочками или полукружьями. Лук нарежьте мелким кубиком.</li>
# <li>Сначала обжарьте лук до прозрачности. Добавьте морковь, жарьте еще 5 минут. Добавьте свежий чеснок и имбирь, жарьте 1 минуту.</li>
# <li>Перемешайте и прогревайте специи вместе с овощами буквально 30-60 секунд.</li>
# <li>Высыпьте всю тыкву в кастрюлю. Перемешайте и готовьте все вместе 5-7 минут. Тыква должна немного поджариться.</li>
# <li>Залейте овощи горячей водой или бульоном. Жидкость должна почти полностью покрывать овощи.</li>
# <li>Добавьте соль, перец. Доведите до кипения, убавьте огонь до минимума, накройте крышкой и варите до мягкости овощей.</li>
# <li>Снимите кастрюлю с плиты. Дайте супу постоять 2-3 минуты, чтобы он немного остыл.</li>
# <li>Возьмите погружной блендер и тщательно измельчите содержимое кастрюли до состояния абсолютно гладкого пюре. Движения лучше делать круговыми, чтобы захватить все кусочки. Для идеальной текстуры пропустите суп через сито.</li>
# <li>Влейте в суп-пюре сливки и тщательно перемешайте ложкой. Поставьте кастрюлю на самый маленький огонь.</li>
# <li>Прогревайте суп, постоянно помешивая. Как только появятся первые пузырьки воздуха, сразу выключайте.</li>

# %%
styler_text = '''<style>
        .recipe-page {
            max-width: 800px;
            margin: 40px auto;
            padding: 0 20px;
        }
        
        .back-link {
            display: inline-flex;
            align-items: center;
            gap: 8px;
            color: #8b4513;
            text-decoration: none;
            margin-bottom: 20px;
            font-weight: 500;
        }
        
        .back-link:hover {
            text-decoration: underline;
        }
        
        .recipe-header {
            text-align: center;
            margin-bottom: 40px;
        }
        
        .recipe-header h1 {
            color: #8b4513;
            font-size: 2.5rem;
            margin-bottom: 10px;
        }
        
        .recipe-meta {
            display: flex;
            justify-content: center;
            gap: 30px;
            color: #666;
            margin-bottom: 30px;
        }
        
        .recipe-image-main {
            width: 100%;
            height: 400px;
            object-fit: cover;
            border-radius: 15px;
            margin-bottom: 30px;
            box-shadow: 0 10px 25px rgba(0, 0, 0, 0.1);
        }
        
        .recipe-content {
            background: white;
            padding: 40px;
            border-radius: 15px;
            box-shadow: 0 5px 20px rgba(0, 0, 0, 0.05);
        }
        
        .ingredients, .instructions {
            margin-bottom: 40px;
        }
        
        .ingredients h2, .instructions h2 {
            color: #8b4513;
            border-bottom: 2px solid #f0e6d6;
            padding-bottom: 10px;
            margin-bottom: 20px;
        }
        
        .ingredients ul {
            list-style: none;
            padding: 0;
        }
        
        .ingredients li {
            padding: 8px 0;
            padding-left: 30px;
            position: relative;
            border-bottom: 1px solid #f0e6d6;
        }
        
        .ingredients li:before {
            content: "•";
            position: absolute;
            left: 0;
        }
        
        .instructions ol {
            padding-left: 20px;
        }
        
        .instructions li {
            margin-bottom: 15px;
            line-height: 1.6;
        }
        
        .note {
            background: #f9f3ec;
            padding: 20px;
            border-radius: 10px;
            border-left: 4px solid #d4a574;
            margin-top: 30px;
        }
    </style>'''

# %%
new_html_page_output = f'''
<!DOCTYPE html>
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>{recipe_ru_name} - Кулинарные заметки</title>
    <!-- Favicon (иконка вкладки) -->
    <link rel="icon" href="../assets/icons/icons8-girl-64.png" type="image/png">
    <link rel="stylesheet" href="../style.css">
    <script src="../script.js" defer></script>
    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css">
    {styler_text}
</head>
<body>
    <header class="main-header">
        <div class="header-top"> 
            <h1>Кулинарные заметки</h1>
        </div>
    </header>

    <main class="recipe-page">
        <a href="../index.html" class="back-link">
            <i class="fas fa-arrow-left"></i>
            Вернуться к рецептам
        </a>
        
        <div class="recipe-header">
            <h1>{recipe_ru_name}</h1>
            <div class="recipe-meta">
                <span><i class="far fa-clock"></i> {recipe_time_ru}</span>
                <span><i class="fas fa-user-friends"></i> {recipe_portion_ru}</span>
                
            </div>
        </div>
        
        <img src="../site-photos/{recipe_id_name}.jpg" 
             alt="{recipe_ru_name}" class="recipe-image-main">
        
        <div class="recipe-content">
            <div class="ingredients">
                <h2><i class="fas fa-shopping-basket"></i> Ингредиенты</h2>
                <ul>
                    {ingredients_spin_new_html}
                    

                </ul>
            </div>
            
            <div class="instructions">
                <h2><i class="fas fa-list-ol"></i> Способ приготовления</h2>
                <ol>
                    {instruction_spin_new_html}
                </ol>
            </div>
            
            {notes_new_html}
            
        </div>
    </main>

    <footer class="main-footer">
        <div class="footer-content">
            <div class="footer-lang-switcher">
                <button class="footer-lang-btn active" data-lang="ru">RU</button>
                <button class="footer-lang-btn" data-lang="en">EN</button>
            </div>
            <p>2026 Кулинарные заметки</p>
            <p class="footer-note">С любовью к вкусной еде ❤️</p>
        </div>
    </footer>

    <script src="../translations.js" defer></script>
    <script src="../script.js" defer></script>
</body>
</html>'''

# %%
meal_name_translation = f'''
        "{recipe_ru_name}": '''
meal_name_translation += '''{ '''
meal_name_translation += f''' 
            ru: "{recipe_ru_name}",
            en: "{recipe_eng_name}"'''
meal_name_translation += '''
            },'''

# %%
ingredient_shift_ru = ''
for ingredient_list in ingredients_ru:
    ingredient_shift_ru += '"' + ingredient_list + '", \n'

instruction_shift_ru = ''
for instruction_list in instruction_ru:
    instruction_shift_ru += '"' + instruction_list + '", \n'

ingredient_shift_eng = ''
for ingredient_list in ingredients_eng:
    ingredient_shift_eng += '"' + ingredient_list + '", \n'

instruction_shift_eng = ''
for instruction_list in instruction_eng:
    instruction_shift_eng += '"' + instruction_list + '", \n'

# %%
recipedetail_new_text = f'''
        "{recipe_id_name}": '''

recipedetail_new_text += ''' {
            ru: {
                title:'''
recipedetail_new_text += f''' "{recipe_ru_name}",
                meta: '''
recipedetail_new_text += ''' {
                    time: '''
recipedetail_new_text += f'''"{recipe_time_ru}",
                    servings: "{recipe_portion_ru}"
                 '''       
recipedetail_new_text += ''' },
                ingredients: [
                '''    
recipedetail_new_text += f'''{ingredient_shift_ru}
                ],
                instructions: [
                {instruction_shift_ru}
                ],
                note: "{note_ru}"
            '''     
recipedetail_new_text += ''' },
            en: {
                title:'''
recipedetail_new_text += f''' "{recipe_eng_name}",
                meta: '''
recipedetail_new_text += ''' {
                    time: '''
recipedetail_new_text += f'''"{recipe_time_eng}",
                    servings: "{recipe_portion_eng}"
                 '''       
recipedetail_new_text += ''' },
                ingredients: [
                '''    
recipedetail_new_text += f'''{ingredient_shift_eng}
                ],
                instructions: [
                {instruction_shift_eng}
                ],
                note: "{note_eng}"
            '''     
recipedetail_new_text += ''' }
        },'''

# %%
sript_js_add = f""" else if (path.includes('{recipe_id_name}')) """
sript_js_add += '''{
'''
sript_js_add += f"""recipeKey = '{recipe_id_name}';
"""
sript_js_add += '''}'''

# %% [markdown]
# # Добавление рецепта

# %% [markdown]
# ### 1. Добавляем в соответствующем месте в index.html следующее:

# %%
print(index_html_output)
# Out:
#                     <!-- Рецепт Крем-суп из тыквы -->
#                     <a href="recipes/soup_creamy_pumpkin_soup.html" class="recipe-card">
#                         <div class="recipe-image">
#                             <img src="site-photos/soup_creamy_pumpkin_soup.jpg" alt="Крем-суп из тыквы">
#                             <div class="recipe-overlay">
#                                 <i class="fas fa-external-link-alt"></i>
#                             </div>
#                         </div>
#                         <div class="recipe-info">
#                             <h3>Крем-суп из тыквы</h3>
#                             <p class="recipe-time"><i class="far fa-clock"></i> 180 мин </p>
#                         </div>
#                     </a>
#                     <!-- Рецепт Крем-суп из тыквы конец -->

# %% [markdown]
# ### 2.Далее создаем файл с названием:

# %%
print(recipe_id_name+'.html')
# Out:
# soup_creamy_pumpkin_soup.html

# %% [markdown]
# ### 3. В новый файл вставляем следующее:

# %%
print(new_html_page_output)
# Out:
# <!DOCTYPE html>
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Крем-суп из тыквы - Кулинарные заметки</title>
#     <!-- Favicon (иконка вкладки) -->
#     <link rel="icon" href="../assets/icons/icons8-girl-64.png" type="image/png">
#     <link rel="stylesheet" href="../style.css">
#     <script src="../script.js" defer></script>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css">
#     <style>
#         .recipe-page {
#             max-width: 800px;
#             margin: 40px auto;
#             padding: 0 20px;
#         }
#
#         .back-link {
#             display: inline-flex;
#             align-items: center;
#             gap: 8px;
#             color: #8b4513;
#             text-decoration: none;
#             margin-bottom: 20px;
#             font-weight: 500;
#         }
#
#         .back-link:hover {
#             text-decoration: underline;
#         }
#
#         .recipe-header {
#             text-align: center;
#             margin-bottom: 40px;
#         }
#
#         .recipe-header h1 {
#             color: #8b4513;
#             font-size: 2.5rem;
#             margin-bottom: 10px;
#         }
#
#         .recipe-meta {
#             display: flex;
#             justify-content: center;
#             gap: 30px;
#             color: #666;
#             margin-bottom: 30px;
#         }
#
#         .recipe-image-main {
#             width: 100%;
#             height: 400px;
#             object-fit: cover;
#             border-radius: 15px;
#             margin-bottom: 30px;
#             box-shadow: 0 10px 25px rgba(0, 0, 0, 0.1);
#         }
#
#         .recipe-content {
#             background: white;
#             padding: 40px;
#             border-radius: 15px;
#             box-shadow: 0 5px 20px rgba(0, 0, 0, 0.05);
#         }
#
#         .ingredients, .instructions {
#             margin-bottom: 40px;
#         }
#
#         .ingredients h2, .instructions h2 {
#             color: #8b4513;
#             border-bottom: 2px solid #f0e6d6;
#             padding-bottom: 10px;
#             margin-bottom: 20px;
#         }
#
#         .ingredients ul {
#             list-style: none;
#             padding: 0;
#         }
#
#         .ingredients li {
#             padding: 8px 0;
#             padding-left: 30px;
#             position: relative;
#             border-bottom: 1px solid #f0e6d6;
#         }
#
#         .ingredients li:before {
#             content: "•";
#             position: absolute;
#             left: 0;
#         }
#
#         .instructions ol {
#             padding-left: 20px;
#         }
#
#         .instructions li {
#             margin-bottom: 15px;
#             line-height: 1.6;
#         }
#
#         .note {
#             background: #f9f3ec;
#             padding: 20px;
#             border-radius: 10px;
#             border-left: 4px solid #d4a574;
#             margin-top: 30px;
#         }
#     </style>
# </head>
# <body>
#     <header class="main-header">
#         <div class="header-top">
#             <h1>Кулинарные заметки</h1>
#         </div>
#     </header>
#
#     <main class="recipe-page">
#         <a href="../index.html" class="back-link">
#             <i class="fas fa-arrow-left"></i>
#             Вернуться к рецептам
#         </a>
#
#         <div class="recipe-header">
#             <h1>Крем-суп из тыквы</h1>
#             <div class="recipe-meta">
#                 <span><i class="far fa-clock"></i> 180 мин</span>
#                 <span><i class="fas fa-user-friends"></i> 6 порций</span>
#
#             </div>
#         </div>
#
#         <img src="../site-photos/soup_creamy_pumpkin_soup.jpg"
#              alt="Крем-суп из тыквы" class="recipe-image-main">
#
#         <div class="recipe-content">
#             <div class="ingredients">
#                 <h2><i class="fas fa-shopping-basket"></i> Ингредиенты</h2>
#                 <ul>
#                     <li>1 кг очищенной тыквы</li>
# <li>2 средние моркови</li>
# <li>2 средних лука</li>
# <li>3 зубчика чеснока</li>
# <li>1 ч.л. сухого имбиря</li>
# <li>800-900 мл бульона (можно заменить на воду)</li>
# <li>200 мл 20% сливок</li>
# <li>Соль, перец</li>
#
#
#
#                 </ul>
#             </div>
#
#             <div class="instructions">
#                 <h2><i class="fas fa-list-ol"></i> Способ приготовления</h2>
#                 <ol>
#                     <li>Тыкву нарежьте кубиками со стороной 2-3 см. Морковь нарежьте тонкими кружочками или полукружьями. Лук нарежьте мелким кубиком.</li>
# <li>Сначала обжарьте лук до прозрачности. Добавьте морковь, жарьте еще 5 минут. Добавьте свежий чеснок и имбирь, жарьте 1 минуту.</li>
# <li>Перемешайте и прогревайте специи вместе с овощами буквально 30-60 секунд.</li>
# <li>Высыпьте всю тыкву в кастрюлю. Перемешайте и готовьте все вместе 5-7 минут. Тыква должна немного поджариться.</li>
# <li>Залейте овощи горячей водой или бульоном. Жидкость должна почти полностью покрывать овощи.</li>
# <li>Добавьте соль, перец. Доведите до кипения, убавьте огонь до минимума, накройте крышкой и варите до мягкости овощей.</li>
# <li>Снимите кастрюлю с плиты. Дайте супу постоять 2-3 минуты, чтобы он немного остыл.</li>
# <li>Возьмите погружной блендер и тщательно измельчите содержимое кастрюли до состояния абсолютно гладкого пюре. Движения лучше делать круговыми, чтобы захватить все кусочки. Для идеальной текстуры пропустите суп через сито.</li>
# <li>Влейте в суп-пюре сливки и тщательно перемешайте ложкой. Поставьте кастрюлю на самый маленький огонь.</li>
# <li>Прогревайте суп, постоянно помешивая. Как только появятся первые пузырьки воздуха, сразу выключайте.</li>
#
#                 </ol>
#             </div>
#
#
#                 <div class="note">
#                 <p><strong>Совет:</strong> К крем-супу отлично подойдут <a href='snaks_garlic_croutons.html' class='elegant-link keep-link'>чесночные сухарики</a>. </p>
#                 </div>
#
#         </div>
#     </main>
#
#     <footer class="main-footer">
#         <div class="footer-content">
#             <div class="footer-lang-switcher">
#                 <button class="footer-lang-btn active" data-lang="ru">RU</button>
#                 <button class="footer-lang-btn" data-lang="en">EN</button>
#             </div>
#             <p>2026 Кулинарные заметки</p>
#             <p class="footer-note">С любовью к вкусной еде ❤️</p>
#         </div>
#     </footer>
#
#     <script src="../translations.js" defer></script>
#     <script src="../script.js" defer></script>
# </body>
# </html>

# %% [markdown]
# ### 4. В файл translations.js добавляем в раздел с названиями блюд:

# %%
print(meal_name_translation)
# Out:
#         "Крем-суп из тыквы": {
#             ru: "Крем-суп из тыквы",
#             en: "Сreamy pumpkin soup"
#             },

# %% [markdown]
# ### 5. Затем в этом же файле вставляем в конце в разделе recipeDetails:

# %%
print(recipedetail_new_text)
# Out:
#         "soup_creamy_pumpkin_soup":  {
#             ru: {
#                 title: "Крем-суп из тыквы",
#                 meta:  {
#                     time: "180 мин",
#                     servings: "6 порций"
#                   },
#                 ingredients: [
#                 "1 кг очищенной тыквы",
# "2 средние моркови",
# "2 средних лука",
# "3 зубчика чеснока",
# "1 ч.л. сухого имбиря",
# "800-900 мл бульона (можно заменить на воду)",
# "200 мл 20% сливок",
# "Соль, перец",
#
#                 ],
#                 instructions: [
#                 "Тыкву нарежьте кубиками со стороной 2-3 см. Морковь нарежьте тонкими кружочками или полукружьями. Лук нарежьте мелким кубиком.",
# "Сначала обжарьте лук до прозрачности. Добавьте морковь, жарьте еще 5 минут. Добавьте свежий чеснок и имбирь, жарьте 1 минуту.",
# "Перемешайте и прогревайте специи вместе с овощами буквально 30-60 секунд.",
# "Высыпьте всю тыкву в кастрюлю. Перемешайте и готовьте все вместе 5-7 минут. Тыква должна немного поджариться.",
# "Залейте овощи горячей водой или бульоном. Жидкость должна почти полностью покрывать овощи.",
# "Добавьте соль, перец. Доведите до кипения, убавьте огонь до минимума, накройте крышкой и варите до мягкости овощей.",
# "Снимите кастрюлю с плиты. Дайте супу постоять 2-3 минуты, чтобы он немного остыл.",
# "Возьмите погружной блендер и тщательно измельчите содержимое кастрюли до состояния абсолютно гладкого пюре. Движения лучше делать круговыми, чтобы захватить все кусочки. Для идеальной текстуры пропустите суп через сито.",
# "Влейте в суп-пюре сливки и тщательно перемешайте ложкой. Поставьте кастрюлю на самый маленький огонь.",
# "Прогревайте суп, постоянно помешивая. Как только появятся первые пузырьки воздуха, сразу выключайте.",
#
#                 ],
#                 note: "К крем-супу отлично подойдут <a href='snaks_garlic_croutons.html' class='elegant-link keep-link'>чесночные сухарики</a>."
#              },
#             en: {
#                 title: "Сreamy pumpkin soup",
#                 meta:  {
#                     time: "180 minutes",
#                     servings: "Serves 6"
#                   },
#                 ingredients: [
#                 "1 kg peeled pumpkin",
# "2 medium carrots",
# "2 medium onions",
# "3 garlic cloves",
# "1 tsp ground ginger",
# "800–900 ml broth (can be replaced with water)",
# "200 ml 20% cream",
# "Salt, black pepper",
#
#                 ],
#                 instructions: [
#                 "Cut the pumpkin into 2–3 cm cubes. Slice the carrots into thin rounds or half-moons. Dice the onions finely.",
# "First, sauté the onions for 3–4 minutes. Add the carrots and cook for another 5 minutes. Add fresh garlic and ginger, cooking for 1 minute.",
# "Stir and heat the spices with the vegetables for 30–60 seconds.",
# "Add all the pumpkin to the pot, mix, and cook together for 5–7 minutes until the pumpkin starts to brown slightly.",
# "Pour in hot water or broth so that the liquid almost fully covers the vegetables.",
# "Season with salt and pepper. Bring to a boil, then reduce heat to a minimum, cover, and simmer until the vegetables are tender.",
# "Remove the pot from the heat and let the soup rest for 2–3 minutes to cool slightly.",
# "Use an immersion blender to puree the soup until completely smooth. Move the blender in circular motions to capture all pieces. For an ideal texture, strain the soup through a fine sieve.",
# "Stir in the cream thoroughly and place the pot over the lowest heat.",
# "Heat the soup while stirring constantly. As soon as the first bubbles appear, immediately remove from heat.",
#
#                 ],
#                 note: "<a href='snaks_garlic_croutons.html' class='elegant-link keep-link'>Garlic croutons</a> fit here perfectly."
#              }
#         },

# %% [markdown]
# ### 6. На последнем этапе в файл script.js d поискать много else if и в конце добавить следующее:

# %%
print(sript_js_add)
# Out:
#  else if (path.includes('soup_creamy_pumpkin_soup')) {
# recipeKey = 'soup_creamy_pumpkin_soup';
# }
