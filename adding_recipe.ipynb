# %%
recipe_id_name = "dessert_brioche"

recipe_ru_name = "Булочка бриош"
recipe_time_ru = "80+780 мин"
recipe_portion_ru = "8-10 порций"
ingredients_ru = [
    "500 г сильной муки (не менее 12 г белка на 100 г)",
    "245 мл молока",
    "7 г сухих дрожжей (или 21 г свежих)",
    "100 г сахара",
    "2 яйца",
    "1 желток для смазывания",
    "1 ст.л. 15-20% сливок",
    "1/2 ч.л. соли",
    "1-2 г ванилина",
    "80 г сливочного масла (мягкого, комнатной температуры)",
]

instruction_ru = [
    "Приготовьте заварку. В кастрюльке смешайте 125 мл молока и 25 г муки. На медленном огне доведите до загущения, постоянно помешивая. Полностью остудите.",
    "Приготовьте опару. Соедините 120 мл теплого молока, дрожжи и 80 г муки. Добавьте всю остывшую заварку. Перемешайте и оставьте до вспучивания. Опара должна получиться очень густой, как тесто на оладьи.",
    "В отдельной миске размешайте яйца с сахаром и ванилью. Добавьте подошедшую опару и перемешайте.",
    "Просейте 300 г муки вместе с солью. Постепенно введите эту смесь в жидкую основу, замешивая тесто. Если тесто слишком жидкое, добавьте еще муки.",
    "Когда тесто начнет собираться в ком, начинайте добавлять мягкое сливочное масло (не растопленное, а именно мягкое). Продолжайте вымешивать тесто 12-15 минут до гладкости и эластичности.",
    "Накройте тесто и дайте ему отдохнуть 20-30 минут в тепле без сквозняков. Затем переложите тесто в холодильник на 8 часов.",
    "Достаньте тесто из холодильника и оставьте его на 1,5-2 часа согреваться."
    "Затем обомните тесто и разделите его на 8-10 частей. Скатайте шарики, поместите их в форму для запекания и накройте пленкой. Дайте отдохнуть еще 1,5-2 часа.",
    "Смажьте верх булочек желтком, смешанным со сливками. Выпекайте при температуре 180 градусов до золотистого цвета и сухой деревянной шпажки. Время выпекания зависит от размера форм, обычно 20-25 минут."
]

note_ru = "Если верхушки уже достигли желаемого цвета, но внутри они еще не готовы - накройте булочки фольгой."

recipe_eng_name = "Brioche"
recipe_time_eng = "80+780 minutes"
recipe_portion_eng = "Serves 8-10"

ingredients_eng = [
    "500 g strong flour (at least 12g protein per 100g)",
    "245 ml milk",
    "7 g instant dry yeast (or 21 g fresh yeast)",
    "100 g sugar",
    "2 eggs",
    "1 egg yolk for brushing",
    "1 tbsp 15–20% cream",
    "1/2 tsp salt",
    "1–2 g vanillin (or 1 tsp vanilla extract)",
    "80 g unsalted butter (softened, room temperature)"
]

instruction_eng = [
    "Make the tangzhong (flour roux). In a small saucepan, mix 125 ml of milk with 25 g of flour. Cook over low heat, stirring constantly, until thickened. Let it cool completely.",
    "Make the preferment. Combine 120 ml of warm milk, the yeast, and 80 g of flour. Add the cooled tangzhong. Mix and let it sit until bubbly and puffed. The preferment should be very thick — like a pancake batter consistency.",
    "In a separate bowl, whisk the eggs with the sugar and vanillin. Add the risen preferment and mix.",
    "Sift 300 g of flour together with the salt. Gradually add this mixture to the wet ingredients while mixing the dough. If the dough is too wet, add a little more flour.",
    "Once the dough starts coming together, begin adding the softened butter (not melted — just soft). Keep kneading the dough for 12–15 minutes until smooth and elastic.",
    "Cover the dough and let it rest for 20–30 minutes in a warm place away from drafts. Then transfer the dough to the fridge for 8 hours.",
    "Take the dough out of the fridge and let it sit for 1.5–2 hours to warm up.",
    "Punch down the dough and divide it into 8–10 pieces. Roll them into balls, place them into a baking dish, and cover with plastic wrap. Let them rest for another 1.5–2 hours.",
    "Brush the tops of the buns with the egg yolk mixed with cream. Bake at 180°C (350°F) until golden brown and a wooden skewer comes out clean. Baking time depends on the size of the pan — usually 20–25 minutes."
]

note_eng = "If the tops have reached the desired color but the insides aren't fully baked yet — cover the buns with foil."

# %% [markdown]
# # Организационные вопросики

# %%
index_html_output = f'''
                    <!-- Рецепт {recipe_ru_name} -->
                    <a href="recipes/{recipe_id_name}.html" class="recipe-card"> 
                        <div class="recipe-image">
                            <img src="site-photos/{recipe_id_name}.jpg" alt="{recipe_ru_name}"> 
                            <div class="recipe-overlay">
                                <i class="fas fa-external-link-alt"></i>
                            </div>
                        </div>
                        <div class="recipe-info">
                            <h3>{recipe_ru_name}</h3> 
                            <p class="recipe-time"><i class="far fa-clock"></i> {recipe_time_ru} </p> 
                        </div>
                    </a>
                    <!-- Рецепт {recipe_ru_name} конец -->
                    
                    '''

# %%
ingredients_spin_new_html = ''
for ing_list_length in ingredients_ru:
    ingredients_spin_new_html += "<li>" + ing_list_length + "</li> \n"

instruction_spin_new_html = ''
for inst_list_length in instruction_ru:
    instruction_spin_new_html += "<li>" + inst_list_length + "</li> \n"

# %%
if note_ru != '':
    notes_new_html = f'''
                <div class="note">
                <p><strong>Совет:</strong> {note_ru} </p>
                </div>'''
else:
    notes_new_html = ''

# %%
print(ingredients_spin_new_html)
print(instruction_spin_new_html)
# Out:
# <li>450 г творога сухого 9%</li>
# <li>130 г сливочного масла 82% (мягкого, комнатной температуры)</li>
# <li>80 г греческого йогурта без добавок</li>
# <li>70 г сахара (или чуть меньше, если не любите сладко)</li>
# <li>10 г ванильного сахара</li>
# <li>1 ч.л. без горки цедры апельсина</li>
#
# <li>Протрите творог через сито дважды. Это критично для нерассыпчатой текстуры.</li>
# <li>Взбейте сливочное масло с сахаром и ванильным сахаром до кремообразного состояния.</li>
# <li>Добавьте греческий йогурт и перемешайте.</li>
# <li>Добавьте апельсиновую цедру. Берите только желтый слой, без белой горькой части.</li>
# <li>Соедините масляную смесь с творогом и вымешивайте 3-4 минуты до полной однородности и блеска. Масса должна стать похожей на густой крем.</li>
# <li>Выложите массу в марлю, помещенную в пасочницу. Сверху поставьте груз весом 0.7-1 кг.</li>
# <li>Уберите в холодильник на 12 часов. Не держите дольше, иначе пасха станет суше.</li>
# <li>Переверните пасху на тарелку и снимите марлю.</li>

# %%
styler_text = '''<style>
        .recipe-page {
            max-width: 800px;
            margin: 40px auto;
            padding: 0 20px;
        }
        
        .back-link {
            display: inline-flex;
            align-items: center;
            gap: 8px;
            color: #8b4513;
            text-decoration: none;
            margin-bottom: 20px;
            font-weight: 500;
        }
        
        .back-link:hover {
            text-decoration: underline;
        }
        
        .recipe-header {
            text-align: center;
            margin-bottom: 40px;
        }
        
        .recipe-header h1 {
            color: #8b4513;
            font-size: 2.5rem;
            margin-bottom: 10px;
        }
        
        .recipe-meta {
            display: flex;
            justify-content: center;
            gap: 30px;
            color: #666;
            margin-bottom: 30px;
        }
        
        .recipe-image-main {
            width: 100%;
            height: 400px;
            object-fit: cover;
            border-radius: 15px;
            margin-bottom: 30px;
            box-shadow: 0 10px 25px rgba(0, 0, 0, 0.1);
        }
        
        .recipe-content {
            background: white;
            padding: 40px;
            border-radius: 15px;
            box-shadow: 0 5px 20px rgba(0, 0, 0, 0.05);
        }
        
        .ingredients, .instructions {
            margin-bottom: 40px;
        }
        
        .ingredients h2, .instructions h2 {
            color: #8b4513;
            border-bottom: 2px solid #f0e6d6;
            padding-bottom: 10px;
            margin-bottom: 20px;
        }
        
        .ingredients ul {
            list-style: none;
            padding: 0;
        }
        
        .ingredients li {
            padding: 8px 0;
            padding-left: 30px;
            position: relative;
            border-bottom: 1px solid #f0e6d6;
        }
        
        .ingredients li:before {
            content: "•";
            position: absolute;
            left: 0;
        }
        
        .instructions ol {
            padding-left: 20px;
        }
        
        .instructions li {
            margin-bottom: 15px;
            line-height: 1.6;
        }
        
        .note {
            background: #f9f3ec;
            padding: 20px;
            border-radius: 10px;
            border-left: 4px solid #d4a574;
            margin-top: 30px;
        }
    </style>'''

# %%
new_html_page_output = f'''
<!DOCTYPE html>
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>{recipe_ru_name} - Кулинарные заметки</title>
    <!-- Favicon (иконка вкладки) -->
    <link rel="icon" href="../assets/icons/icons8-girl-64.png" type="image/png">
    <link rel="stylesheet" href="../style.css">
    <script src="../script.js" defer></script>
    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css">
    {styler_text}
</head>
<body>
    <header class="main-header">
        <div class="header-top"> 
            <h1>Кулинарные заметки</h1>
        </div>
    </header>

    <main class="recipe-page">
        <a href="../index.html" class="back-link">
            <i class="fas fa-arrow-left"></i>
            Вернуться к рецептам
        </a>
        
        <div class="recipe-header">
            <h1>{recipe_ru_name}</h1>
            <div class="recipe-meta">
                <span><i class="far fa-clock"></i> {recipe_time_ru}</span>
                <span><i class="fas fa-user-friends"></i> {recipe_portion_ru}</span>
                
            </div>
        </div>
        
        <img src="../site-photos/{recipe_id_name}.jpg" 
             alt="{recipe_ru_name}" class="recipe-image-main">
        
        <div class="recipe-content">
            <div class="ingredients">
                <h2><i class="fas fa-shopping-basket"></i> Ингредиенты</h2>
                <ul>
                    {ingredients_spin_new_html}
                    

                </ul>
            </div>
            
            <div class="instructions">
                <h2><i class="fas fa-list-ol"></i> Способ приготовления</h2>
                <ol>
                    {instruction_spin_new_html}
                </ol>
            </div>
            
            {notes_new_html}
            
        </div>
    </main>

    <footer class="main-footer">
        <div class="footer-content">
            <div class="footer-lang-switcher">
                <button class="footer-lang-btn active" data-lang="ru">RU</button>
                <button class="footer-lang-btn" data-lang="en">EN</button>
            </div>
            <p>2026 Кулинарные заметки</p>
            <p class="footer-note">С любовью к вкусной еде ❤️</p>
        </div>
    </footer>

    <script src="../translations.js" defer></script>
    <script src="../script.js" defer></script>
</body>
</html>'''

# %%
meal_name_translation = f'''
        "{recipe_ru_name}": '''
meal_name_translation += '''{ '''
meal_name_translation += f''' 
            ru: "{recipe_ru_name}",
            en: "{recipe_eng_name}"'''
meal_name_translation += '''
            },'''

# %%
ingredient_shift_ru = ''
for ingredient_list in ingredients_ru:
    ingredient_shift_ru += '"' + ingredient_list + '", \n'

instruction_shift_ru = ''
for instruction_list in instruction_ru:
    instruction_shift_ru += '"' + instruction_list + '", \n'

ingredient_shift_eng = ''
for ingredient_list in ingredients_eng:
    ingredient_shift_eng += '"' + ingredient_list + '", \n'

instruction_shift_eng = ''
for instruction_list in instruction_eng:
    instruction_shift_eng += '"' + instruction_list + '", \n'

# %%
recipedetail_new_text = f'''
        "{recipe_id_name}": '''

recipedetail_new_text += ''' {
            ru: {
                title:'''
recipedetail_new_text += f''' "{recipe_ru_name}",
                meta: '''
recipedetail_new_text += ''' {
                    time: '''
recipedetail_new_text += f'''"{recipe_time_ru}",
                    servings: "{recipe_portion_ru}"
                 '''       
recipedetail_new_text += ''' },
                ingredients: [
                '''    
recipedetail_new_text += f'''{ingredient_shift_ru}
                ],
                instructions: [
                {instruction_shift_ru}
                ],
                note: "{note_ru}"
            '''     
recipedetail_new_text += ''' },
            en: {
                title:'''
recipedetail_new_text += f''' "{recipe_eng_name}",
                meta: '''
recipedetail_new_text += ''' {
                    time: '''
recipedetail_new_text += f'''"{recipe_time_eng}",
                    servings: "{recipe_portion_eng}"
                 '''       
recipedetail_new_text += ''' },
                ingredients: [
                '''    
recipedetail_new_text += f'''{ingredient_shift_eng}
                ],
                instructions: [
                {instruction_shift_eng}
                ],
                note: "{note_eng}"
            '''     
recipedetail_new_text += ''' }
        },'''

# %%
sript_js_add = f""" else if (path.includes('{recipe_id_name}')) """
sript_js_add += '''{
'''
sript_js_add += f"""recipeKey = '{recipe_id_name}';
"""
sript_js_add += '''}'''

# %% [markdown]
# # Добавление рецепта

# %% [markdown]
# ### 1. Добавляем в соответствующем месте в index.html следующее:

# %%
print(index_html_output)
# Out:
#                     <!-- Рецепт Пасха -->
#                     <a href="recipes/dessert_paskha.html" class="recipe-card">
#                         <div class="recipe-image">
#                             <img src="site-photos/dessert_paskha.jpg" alt="Пасха">
#                             <div class="recipe-overlay">
#                                 <i class="fas fa-external-link-alt"></i>
#                             </div>
#                         </div>
#                         <div class="recipe-info">
#                             <h3>Пасха</h3>
#                             <p class="recipe-time"><i class="far fa-clock"></i> 45+720 мин </p>
#                         </div>
#                     </a>
#                     <!-- Рецепт Пасха конец -->

# %% [markdown]
# ### 2.Далее создаем файл с названием:

# %%
print(recipe_id_name+'.html')
# Out:
# dessert_paskha.html

# %% [markdown]
# ### 3. В новый файл вставляем следующее:

# %%
print(new_html_page_output)
# Out:
# <!DOCTYPE html>
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Пасха - Кулинарные заметки</title>
#     <!-- Favicon (иконка вкладки) -->
#     <link rel="icon" href="../assets/icons/icons8-girl-64.png" type="image/png">
#     <link rel="stylesheet" href="../style.css">
#     <script src="../script.js" defer></script>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css">
#     <style>
#         .recipe-page {
#             max-width: 800px;
#             margin: 40px auto;
#             padding: 0 20px;
#         }
#
#         .back-link {
#             display: inline-flex;
#             align-items: center;
#             gap: 8px;
#             color: #8b4513;
#             text-decoration: none;
#             margin-bottom: 20px;
#             font-weight: 500;
#         }
#
#         .back-link:hover {
#             text-decoration: underline;
#         }
#
#         .recipe-header {
#             text-align: center;
#             margin-bottom: 40px;
#         }
#
#         .recipe-header h1 {
#             color: #8b4513;
#             font-size: 2.5rem;
#             margin-bottom: 10px;
#         }
#
#         .recipe-meta {
#             display: flex;
#             justify-content: center;
#             gap: 30px;
#             color: #666;
#             margin-bottom: 30px;
#         }
#
#         .recipe-image-main {
#             width: 100%;
#             height: 400px;
#             object-fit: cover;
#             border-radius: 15px;
#             margin-bottom: 30px;
#             box-shadow: 0 10px 25px rgba(0, 0, 0, 0.1);
#         }
#
#         .recipe-content {
#             background: white;
#             padding: 40px;
#             border-radius: 15px;
#             box-shadow: 0 5px 20px rgba(0, 0, 0, 0.05);
#         }
#
#         .ingredients, .instructions {
#             margin-bottom: 40px;
#         }
#
#         .ingredients h2, .instructions h2 {
#             color: #8b4513;
#             border-bottom: 2px solid #f0e6d6;
#             padding-bottom: 10px;
#             margin-bottom: 20px;
#         }
#
#         .ingredients ul {
#             list-style: none;
#             padding: 0;
#         }
#
#         .ingredients li {
#             padding: 8px 0;
#             padding-left: 30px;
#             position: relative;
#             border-bottom: 1px solid #f0e6d6;
#         }
#
#         .ingredients li:before {
#             content: "•";
#             position: absolute;
#             left: 0;
#         }
#
#         .instructions ol {
#             padding-left: 20px;
#         }
#
#         .instructions li {
#             margin-bottom: 15px;
#             line-height: 1.6;
#         }
#
#         .note {
#             background: #f9f3ec;
#             padding: 20px;
#             border-radius: 10px;
#             border-left: 4px solid #d4a574;
#             margin-top: 30px;
#         }
#     </style>
# </head>
# <body>
#     <header class="main-header">
#         <div class="header-top">
#             <h1>Кулинарные заметки</h1>
#         </div>
#     </header>
#
#     <main class="recipe-page">
#         <a href="../index.html" class="back-link">
#             <i class="fas fa-arrow-left"></i>
#             Вернуться к рецептам
#         </a>
#
#         <div class="recipe-header">
#             <h1>Пасха</h1>
#             <div class="recipe-meta">
#                 <span><i class="far fa-clock"></i> 45+720 мин</span>
#                 <span><i class="fas fa-user-friends"></i> 12 порций</span>
#
#             </div>
#         </div>
#
#         <img src="../site-photos/dessert_paskha.jpg"
#              alt="Пасха" class="recipe-image-main">
#
#         <div class="recipe-content">
#             <div class="ingredients">
#                 <h2><i class="fas fa-shopping-basket"></i> Ингредиенты</h2>
#                 <ul>
#                     <li>450 г творога сухого 9%</li>
# <li>130 г сливочного масла 82% (мягкого, комнатной температуры)</li>
# <li>80 г греческого йогурта без добавок</li>
# <li>70 г сахара (или чуть меньше, если не любите сладко)</li>
# <li>10 г ванильного сахара</li>
# <li>1 ч.л. без горки цедры апельсина</li>
#
#
#
#                 </ul>
#             </div>
#
#             <div class="instructions">
#                 <h2><i class="fas fa-list-ol"></i> Способ приготовления</h2>
#                 <ol>
#                     <li>Протрите творог через сито дважды. Это критично для нерассыпчатой текстуры.</li>
# <li>Взбейте сливочное масло с сахаром и ванильным сахаром до кремообразного состояния.</li>
# <li>Добавьте греческий йогурт и перемешайте.</li>
# <li>Добавьте апельсиновую цедру. Берите только желтый слой, без белой горькой части.</li>
# <li>Соедините масляную смесь с творогом и вымешивайте 3-4 минуты до полной однородности и блеска. Масса должна стать похожей на густой крем.</li>
# <li>Выложите массу в марлю, помещенную в пасочницу. Сверху поставьте груз весом 0.7-1 кг.</li>
# <li>Уберите в холодильник на 12 часов. Не держите дольше, иначе пасха станет суше.</li>
# <li>Переверните пасху на тарелку и снимите марлю.</li>
#
#                 </ol>
#             </div>
#
#
#                 <div class="note">
#                 <p><strong>Совет:</strong> Апельсиновая цедра дает нежную сладковатую свежесть. С лимоном вкус будет резче и кислее. Для более насыщенного вкуса можно добавить изюм или цукаты после замачивания. Пасху лучше готовить в классической деревянной пасочнице, но подойдет пластиковая пасочница или обычный дуршлаг. </p>
#                 </div>
#
#         </div>
#     </main>
#
#     <footer class="main-footer">
#         <div class="footer-content">
#             <div class="footer-lang-switcher">
#                 <button class="footer-lang-btn active" data-lang="ru">RU</button>
#                 <button class="footer-lang-btn" data-lang="en">EN</button>
#             </div>
#             <p>2026 Кулинарные заметки</p>
#             <p class="footer-note">С любовью к вкусной еде ❤️</p>
#         </div>
#     </footer>
#
#     <script src="../translations.js" defer></script>
#     <script src="../script.js" defer></script>
# </body>
# </html>

# %% [markdown]
# ### 4. В файл translations.js добавляем в раздел с названиями блюд:

# %%
print(meal_name_translation)
# Out:
#         "Пасха": {
#             ru: "Пасха",
#             en: "Russian Easter Paskha"
#             },

# %% [markdown]
# ### 5. Затем в этом же файле вставляем в конце в разделе recipeDetails:

# %%
print(recipedetail_new_text)
# Out:
#         "dessert_paskha":  {
#             ru: {
#                 title: "Пасха",
#                 meta:  {
#                     time: "45+720 мин",
#                     servings: "12 порций"
#                   },
#                 ingredients: [
#                 "450 г творога сухого 9%",
# "130 г сливочного масла 82% (мягкого, комнатной температуры)",
# "80 г греческого йогурта без добавок",
# "70 г сахара (или чуть меньше, если не любите сладко)",
# "10 г ванильного сахара",
# "1 ч.л. без горки цедры апельсина",
#
#                 ],
#                 instructions: [
#                 "Протрите творог через сито дважды. Это критично для нерассыпчатой текстуры.",
# "Взбейте сливочное масло с сахаром и ванильным сахаром до кремообразного состояния.",
# "Добавьте греческий йогурт и перемешайте.",
# "Добавьте апельсиновую цедру. Берите только желтый слой, без белой горькой части.",
# "Соедините масляную смесь с творогом и вымешивайте 3-4 минуты до полной однородности и блеска. Масса должна стать похожей на густой крем.",
# "Выложите массу в марлю, помещенную в пасочницу. Сверху поставьте груз весом 0.7-1 кг.",
# "Уберите в холодильник на 12 часов. Не держите дольше, иначе пасха станет суше.",
# "Переверните пасху на тарелку и снимите марлю.",
#
#                 ],
#                 note: "Апельсиновая цедра дает нежную сладковатую свежесть. С лимоном вкус будет резче и кислее. Для более насыщенного вкуса можно добавить изюм или цукаты после замачивания. Пасху лучше готовить в классической деревянной пасочнице, но подойдет пластиковая пасочница или обычный дуршлаг."
#              },
#             en: {
#                 title: "Russian Easter Paskha",
#                 meta:  {
#                     time: "45+720 minutes",
#                     servings: "Serves 12"
#                   },
#                 ingredients: [
#                 "450 g dry curd cottage cheese (9% fat)",
# "130 g unsalted butter (82% fat, softened, room temperature)",
# "80 g plain Greek yogurt",
# "70 g sugar (or a little less if you don’t like it too sweet)",
# "10 g vanilla sugar",
# "1 tsp orange zest (lightly packed, no heaping)",
#
#                 ],
#                 instructions: [
#                 "Press the cottage cheese through a sieve twice. This is key to getting a non-crumbly texture.",
# "Beat the butter with the sugar and vanilla sugar until creamy and smooth.",
# "Add the Greek yogurt and mix it in.",
# "Add the orange zest. Use only the orange part, not the white bitter pith underneath.",
# "Combine the butter mixture with the cottage cheese and mix for 3–4 minutes until completely smooth and glossy. The mixture should look like a thick cream.",
# "Line a traditional Easter cheese mold (passochnitsa) with cheesecloth and spoon the mixture in. Place a weight of about 0.7–1 kg on top.",
# "Refrigerate for 12 hours. Don’t leave it longer than that, or the Easter cheese will become dry.",
# "Flip the Easter cheese onto a plate and remove the cheesecloth.",
#
#                 ],
#                 note: "Orange zest adds a gentle sweet freshness. Lemon zest will make it sharper and more tangy. For a richer flavor, you can add soaked raisins or candied fruit. This dish is best made in a classic wooden Easter cheese mold, but a plastic one or a regular colander will also work."
#              }
#         },

# %% [markdown]
# ### 6. На последнем этапе в файл script.js d поискать много else if и в конце добавить следующее:

# %%
print(sript_js_add)
# Out:
#  else if (path.includes('dessert_paskha')) {
# recipeKey = 'dessert_paskha';
# }
