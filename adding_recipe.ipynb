# %%
recipe_id_name = "main_dish_сhicken_spinach_pasta"

recipe_ru_name = "Паста с курицей и шпинатом"
recipe_time_ru = "45 мин"
recipe_portion_ru = "6 порций"
ingredients_ru = [
    "700 г куриного филе",
    "400 г пасты",
    "200 мл 15% сливок",
    "150 г шпината (свежего или замороженного)",
    "50 г пармезана (+ для подачи)",
    "2 зубчика чеснока",
    "2 ст.л. молока",
    "2 ч.л. кукурзного крахмала"
    "Соль, перец, паприка - по вкусу"
]

instruction_ru = [
"Нарежьте куриное филе на небльшие кусочки и переложите в миску. Добавьте щепотку соли, молоко и кукурзный крахмал. Перемешайте и оставьте на 15-20 минут.",
"Отварите пасту так, как указано на упаковке.",
"В большой сковороде с высокими бортами (или сотейнике) разогрейте оливковое масло. Выложите курицу.",
"Обжаривайте на среднем огне по 3-4 минуты с каждой стороны, до золотистой корочки. Курица не обязательно должна дойти до полной готовности внутри (она «дойдет» в соусе).",
"Добавьте сливки, измельченный чеснок и шпинат. Если шпинат свежий, вводите шпинат порциями.",
"Добавьте половник воды из под пасты и доведите до слабого кипения, но не кипятите бурно (сливки могут свернуться).",  
"Добавьте сыр и перемешайте, пока он не растает. Добавьте специи.",
"Накройте сковороду крышкой и томите на самом маленьком огне 5-7 минут, пока курица не дойдет до полной готовности.",
"Объедините курицу с соусом с пастой , подавая, посыпьте еще пармезаном.",
]

note_ru = ""

recipe_eng_name = "Chicken and Spinach Pasta"
recipe_time_eng = "45 minutes"
recipe_portion_eng = "Serves 6"

ingredients_eng = [
    "700 g chicken breast (or thighs), cut into bite-sized pieces",
    "400 g pasta (fettuccine or penne work well)",
    "200 ml heavy cream (15% milk fat; use \"half-and-half\" or light cream in the US)",
    "150 g fresh or frozen spinach",
    "50 g Parmesan cheese, plus more for serving",
    "2 garlic cloves, minced",
    "2 tbsp milk",
    "2 tsp cornstarch",
    "Salt, black pepper, and paprika to taste"
  ]

instruction_eng = [
    "Cut the chicken into bite-sized pieces and place them in a bowl. Add a pinch of salt, the milk, and cornstarch. Stir to combine and let it sit for 15–20 minutes.",
    "Cook the pasta according to the package directions. Reserve about a cup of pasta water before draining.",
    "Heat a splash of olive oil in a large, deep skillet or sauté pan over medium-high heat. Add the chicken in a single layer.",
    "Sear the chicken for 3–4 minutes per side, until golden brown. It doesn't need to be cooked through at this point—it will finish cooking in the sauce.",
    "Reduce the heat to medium. Add the heavy cream, minced garlic, and spinach. If using fresh spinach, add it in handfuls, stirring until it wilts before adding more.",
    "Pour in a ladleful of the reserved pasta water and bring the sauce to a gentle simmer. Don't let it boil hard, or the cream might separate.",
    "Stir in the Parmesan cheese until melted and smooth. Season with salt, pepper, and paprika to taste.",
    "Cover the skillet, reduce the heat to low, and let it simmer for 5–7 minutes, until the chicken is cooked through and tender.",
    "Toss the cooked pasta with the chicken and sauce. Serve with extra Parmesan on top."
]

note_eng = ""

# %% [markdown]
# # Организационные вопросики

# %%
index_html_output = f'''
                    <!-- Рецепт {recipe_ru_name} -->
                    <a href="recipes/{recipe_id_name}.html" class="recipe-card"> 
                        <div class="recipe-image">
                            <img src="site-photos/{recipe_id_name}.jpg" alt="{recipe_ru_name}"> 
                            <div class="recipe-overlay">
                                <i class="fas fa-external-link-alt"></i>
                            </div>
                        </div>
                        <div class="recipe-info">
                            <h3>{recipe_ru_name}</h3> 
                            <p class="recipe-time"><i class="far fa-clock"></i> {recipe_time_ru} </p> 
                        </div>
                    </a>
                    <!-- Рецепт {recipe_ru_name} конец -->
                    
                    '''

# %%
ingredients_spin_new_html = ''
for ing_list_length in ingredients_ru:
    ingredients_spin_new_html += "<li>" + ing_list_length + "</li> \n"

instruction_spin_new_html = ''
for inst_list_length in instruction_ru:
    instruction_spin_new_html += "<li>" + inst_list_length + "</li> \n"

# %%
if note_ru != '':
    notes_new_html = f'''
                <div class="note">
                <p><strong>Совет:</strong> {note_ru} </p>
                </div>'''
else:
    notes_new_html = ''

# %%
print(ingredients_spin_new_html)
print(instruction_spin_new_html)
# Out:
# <li>150 г малины (свежей или замороженной)</li>
# <li>2 яйца</li>
# <li>50 г сахара</li>
# <li>30 сливочного масла</li>
# <li>2 ст.л. лимонного сока</li>
#
# <li>Пробейте блендером малину и протрите через сито, чтобы удалить косточки.</li>
# <li>Взбейте яйца с половиной сахара.</li>
# <li>В кастрюлю выложите малиновое пюре, лимонный сок и вторую половину сахара. Нагрейте почти до кипения.</li>
# <li>Осторожно, постоянно помешивая яйца, влейте 1/3 горячего малинового пюре в яичную смесь. Эта процедура нужна, чтобы яйца не свернулись.</li>
# <li>Тонкой струйкой, постоянно помешивая, влейте темперированную яичную смесь обратно в оставшееся пюре и, не переставая мешать, варите на очень медленном огне до появления характерных пыхов (как у заварного крема), то есть до загустения.</li>
# <li>Слегка остудите крем, добавьте кусочки мягкого сливочного масла и очень хорошо взбейте венчиком.</li>
# <li>Накройте пищевой пленкой так, чтобы она касалась поверхности крема, оставьте до полного остывания.</li>

# %%
styler_text = '''<style>
        .recipe-page {
            max-width: 800px;
            margin: 40px auto;
            padding: 0 20px;
        }
        
        .back-link {
            display: inline-flex;
            align-items: center;
            gap: 8px;
            color: #8b4513;
            text-decoration: none;
            margin-bottom: 20px;
            font-weight: 500;
        }
        
        .back-link:hover {
            text-decoration: underline;
        }
        
        .recipe-header {
            text-align: center;
            margin-bottom: 40px;
        }
        
        .recipe-header h1 {
            color: #8b4513;
            font-size: 2.5rem;
            margin-bottom: 10px;
        }
        
        .recipe-meta {
            display: flex;
            justify-content: center;
            gap: 30px;
            color: #666;
            margin-bottom: 30px;
        }
        
        .recipe-image-main {
            width: 100%;
            height: 400px;
            object-fit: cover;
            border-radius: 15px;
            margin-bottom: 30px;
            box-shadow: 0 10px 25px rgba(0, 0, 0, 0.1);
        }
        
        .recipe-content {
            background: white;
            padding: 40px;
            border-radius: 15px;
            box-shadow: 0 5px 20px rgba(0, 0, 0, 0.05);
        }
        
        .ingredients, .instructions {
            margin-bottom: 40px;
        }
        
        .ingredients h2, .instructions h2 {
            color: #8b4513;
            border-bottom: 2px solid #f0e6d6;
            padding-bottom: 10px;
            margin-bottom: 20px;
        }
        
        .ingredients ul {
            list-style: none;
            padding: 0;
        }
        
        .ingredients li {
            padding: 8px 0;
            padding-left: 30px;
            position: relative;
            border-bottom: 1px solid #f0e6d6;
        }
        
        .ingredients li:before {
            content: "•";
            position: absolute;
            left: 0;
        }
        
        .instructions ol {
            padding-left: 20px;
        }
        
        .instructions li {
            margin-bottom: 15px;
            line-height: 1.6;
        }
        
        .note {
            background: #f9f3ec;
            padding: 20px;
            border-radius: 10px;
            border-left: 4px solid #d4a574;
            margin-top: 30px;
        }
    </style>'''

# %%
new_html_page_output = f'''
<!DOCTYPE html>
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>{recipe_ru_name} - Кулинарные заметки</title>
    <!-- Favicon (иконка вкладки) -->
    <link rel="icon" href="../assets/icons/icons8-girl-64.png" type="image/png">
    <link rel="stylesheet" href="../style.css">
    <script src="../script.js" defer></script>
    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css">
    {styler_text}
</head>
<body>
    <header class="main-header">
        <div class="header-top"> 
            <h1>Кулинарные заметки</h1>
        </div>
    </header>

    <main class="recipe-page">
        <a href="../index.html" class="back-link">
            <i class="fas fa-arrow-left"></i>
            Вернуться к рецептам
        </a>
        
        <div class="recipe-header">
            <h1>{recipe_ru_name}</h1>
            <div class="recipe-meta">
                <span><i class="far fa-clock"></i> {recipe_time_ru}</span>
                <span><i class="fas fa-user-friends"></i> {recipe_portion_ru}</span>
                
            </div>
        </div>
        
        <img src="../site-photos/{recipe_id_name}.jpg" 
             alt="{recipe_ru_name}" class="recipe-image-main">
        
        <div class="recipe-content">
            <div class="ingredients">
                <h2><i class="fas fa-shopping-basket"></i> Ингредиенты</h2>
                <ul>
                    {ingredients_spin_new_html}
                    

                </ul>
            </div>
            
            <div class="instructions">
                <h2><i class="fas fa-list-ol"></i> Способ приготовления</h2>
                <ol>
                    {instruction_spin_new_html}
                </ol>
            </div>
            
            {notes_new_html}
            
        </div>
    </main>

    <footer class="main-footer">
        <div class="footer-content">
            <div class="footer-lang-switcher">
                <button class="footer-lang-btn active" data-lang="ru">RU</button>
                <button class="footer-lang-btn" data-lang="en">EN</button>
            </div>
            <p>2026 Кулинарные заметки</p>
            <p class="footer-note">С любовью к вкусной еде ❤️</p>
        </div>
    </footer>

    <script src="../translations.js" defer></script>
    <script src="../script.js" defer></script>
</body>
</html>'''

# %%
meal_name_translation = f'''
        "{recipe_ru_name}": '''
meal_name_translation += '''{ '''
meal_name_translation += f''' 
            ru: "{recipe_ru_name}",
            en: "{recipe_eng_name}"'''
meal_name_translation += '''
            },'''

# %%
ingredient_shift_ru = ''
for ingredient_list in ingredients_ru:
    ingredient_shift_ru += '"' + ingredient_list + '", \n'

instruction_shift_ru = ''
for instruction_list in instruction_ru:
    instruction_shift_ru += '"' + instruction_list + '", \n'

ingredient_shift_eng = ''
for ingredient_list in ingredients_eng:
    ingredient_shift_eng += '"' + ingredient_list + '", \n'

instruction_shift_eng = ''
for instruction_list in instruction_eng:
    instruction_shift_eng += '"' + instruction_list + '", \n'

# %%
recipedetail_new_text = f'''
        "{recipe_id_name}": '''

recipedetail_new_text += ''' {
            ru: {
                title:'''
recipedetail_new_text += f''' "{recipe_ru_name}",
                meta: '''
recipedetail_new_text += ''' {
                    time: '''
recipedetail_new_text += f'''"{recipe_time_ru}",
                    servings: "{recipe_portion_ru}"
                 '''       
recipedetail_new_text += ''' },
                ingredients: [
                '''    
recipedetail_new_text += f'''{ingredient_shift_ru}
                ],
                instructions: [
                {instruction_shift_ru}
                ],
                note: "{note_ru}"
            '''     
recipedetail_new_text += ''' },
            en: {
                title:'''
recipedetail_new_text += f''' "{recipe_eng_name}",
                meta: '''
recipedetail_new_text += ''' {
                    time: '''
recipedetail_new_text += f'''"{recipe_time_eng}",
                    servings: "{recipe_portion_eng}"
                 '''       
recipedetail_new_text += ''' },
                ingredients: [
                '''    
recipedetail_new_text += f'''{ingredient_shift_eng}
                ],
                instructions: [
                {instruction_shift_eng}
                ],
                note: "{note_eng}"
            '''     
recipedetail_new_text += ''' }
        },'''

# %%
sript_js_add = f""" else if (path.includes('{recipe_id_name}')) """
sript_js_add += '''{
'''
sript_js_add += f"""recipeKey = '{recipe_id_name}';
"""
sript_js_add += '''}'''

# %% [markdown]
# # Добавление рецепта

# %% [markdown]
# ### 1. Добавляем в соответствующем месте в index.html следующее:

# %%
print(index_html_output)
# Out:
#                     <!-- Рецепт Малиновый курд -->
#                     <a href="recipes/sauce_raspberry_curd.html" class="recipe-card">
#                         <div class="recipe-image">
#                             <img src="site-photos/sauce_raspberry_curd.jpg" alt="Малиновый курд">
#                             <div class="recipe-overlay">
#                                 <i class="fas fa-external-link-alt"></i>
#                             </div>
#                         </div>
#                         <div class="recipe-info">
#                             <h3>Малиновый курд</h3>
#                             <p class="recipe-time"><i class="far fa-clock"></i> 30 мин </p>
#                         </div>
#                     </a>
#                     <!-- Рецепт Малиновый курд конец -->

# %% [markdown]
# ### 2.Далее создаем файл с названием:

# %%
print(recipe_id_name+'.html')
# Out:
# sauce_raspberry_curd.html

# %% [markdown]
# ### 3. В новый файл вставляем следующее:

# %%
print(new_html_page_output)
# Out:
# <!DOCTYPE html>
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Малиновый курд - Кулинарные заметки</title>
#     <!-- Favicon (иконка вкладки) -->
#     <link rel="icon" href="../assets/icons/icons8-girl-64.png" type="image/png">
#     <link rel="stylesheet" href="../style.css">
#     <script src="../script.js" defer></script>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css">
#     <style>
#         .recipe-page {
#             max-width: 800px;
#             margin: 40px auto;
#             padding: 0 20px;
#         }
#
#         .back-link {
#             display: inline-flex;
#             align-items: center;
#             gap: 8px;
#             color: #8b4513;
#             text-decoration: none;
#             margin-bottom: 20px;
#             font-weight: 500;
#         }
#
#         .back-link:hover {
#             text-decoration: underline;
#         }
#
#         .recipe-header {
#             text-align: center;
#             margin-bottom: 40px;
#         }
#
#         .recipe-header h1 {
#             color: #8b4513;
#             font-size: 2.5rem;
#             margin-bottom: 10px;
#         }
#
#         .recipe-meta {
#             display: flex;
#             justify-content: center;
#             gap: 30px;
#             color: #666;
#             margin-bottom: 30px;
#         }
#
#         .recipe-image-main {
#             width: 100%;
#             height: 400px;
#             object-fit: cover;
#             border-radius: 15px;
#             margin-bottom: 30px;
#             box-shadow: 0 10px 25px rgba(0, 0, 0, 0.1);
#         }
#
#         .recipe-content {
#             background: white;
#             padding: 40px;
#             border-radius: 15px;
#             box-shadow: 0 5px 20px rgba(0, 0, 0, 0.05);
#         }
#
#         .ingredients, .instructions {
#             margin-bottom: 40px;
#         }
#
#         .ingredients h2, .instructions h2 {
#             color: #8b4513;
#             border-bottom: 2px solid #f0e6d6;
#             padding-bottom: 10px;
#             margin-bottom: 20px;
#         }
#
#         .ingredients ul {
#             list-style: none;
#             padding: 0;
#         }
#
#         .ingredients li {
#             padding: 8px 0;
#             padding-left: 30px;
#             position: relative;
#             border-bottom: 1px solid #f0e6d6;
#         }
#
#         .ingredients li:before {
#             content: "•";
#             position: absolute;
#             left: 0;
#         }
#
#         .instructions ol {
#             padding-left: 20px;
#         }
#
#         .instructions li {
#             margin-bottom: 15px;
#             line-height: 1.6;
#         }
#
#         .note {
#             background: #f9f3ec;
#             padding: 20px;
#             border-radius: 10px;
#             border-left: 4px solid #d4a574;
#             margin-top: 30px;
#         }
#     </style>
# </head>
# <body>
#     <header class="main-header">
#         <div class="header-top">
#             <h1>Кулинарные заметки</h1>
#         </div>
#     </header>
#
#     <main class="recipe-page">
#         <a href="../index.html" class="back-link">
#             <i class="fas fa-arrow-left"></i>
#             Вернуться к рецептам
#         </a>
#
#         <div class="recipe-header">
#             <h1>Малиновый курд</h1>
#             <div class="recipe-meta">
#                 <span><i class="far fa-clock"></i> 30 мин</span>
#                 <span><i class="fas fa-user-friends"></i> 200 - 220 г</span>
#
#             </div>
#         </div>
#
#         <img src="../site-photos/sauce_raspberry_curd.jpg"
#              alt="Малиновый курд" class="recipe-image-main">
#
#         <div class="recipe-content">
#             <div class="ingredients">
#                 <h2><i class="fas fa-shopping-basket"></i> Ингредиенты</h2>
#                 <ul>
#                     <li>150 г малины (свежей или замороженной)</li>
# <li>2 яйца</li>
# <li>50 г сахара</li>
# <li>30 сливочного масла</li>
# <li>2 ст.л. лимонного сока</li>
#
#
#
#                 </ul>
#             </div>
#
#             <div class="instructions">
#                 <h2><i class="fas fa-list-ol"></i> Способ приготовления</h2>
#                 <ol>
#                     <li>Пробейте блендером малину и протрите через сито, чтобы удалить косточки.</li>
# <li>Взбейте яйца с половиной сахара.</li>
# <li>В кастрюлю выложите малиновое пюре, лимонный сок и вторую половину сахара. Нагрейте почти до кипения.</li>
# <li>Осторожно, постоянно помешивая яйца, влейте 1/3 горячего малинового пюре в яичную смесь. Эта процедура нужна, чтобы яйца не свернулись.</li>
# <li>Тонкой струйкой, постоянно помешивая, влейте темперированную яичную смесь обратно в оставшееся пюре и, не переставая мешать, варите на очень медленном огне до появления характерных пыхов (как у заварного крема), то есть до загустения.</li>
# <li>Слегка остудите крем, добавьте кусочки мягкого сливочного масла и очень хорошо взбейте венчиком.</li>
# <li>Накройте пищевой пленкой так, чтобы она касалась поверхности крема, оставьте до полного остывания.</li>
#
#                 </ol>
#             </div>
#
#
#                 <div class="note">
#                 <p><strong>Совет:</strong> Отличная начинка для для <a href='dessert_napoleon_cake.html' class='elegant-link keep-link'>dessert_cupcake_creamchease_straberry_jam</a> или как добавка к <a href='breakfast_oat_porridge.html' class='elegant-link keep-link'>овсяной каше</a>. </p>
#                 </div>
#
#         </div>
#     </main>
#
#     <footer class="main-footer">
#         <div class="footer-content">
#             <div class="footer-lang-switcher">
#                 <button class="footer-lang-btn active" data-lang="ru">RU</button>
#                 <button class="footer-lang-btn" data-lang="en">EN</button>
#             </div>
#             <p>2026 Кулинарные заметки</p>
#             <p class="footer-note">С любовью к вкусной еде ❤️</p>
#         </div>
#     </footer>
#
#     <script src="../translations.js" defer></script>
#     <script src="../script.js" defer></script>
# </body>
# </html>

# %% [markdown]
# ### 4. В файл translations.js добавляем в раздел с названиями блюд:

# %%
print(meal_name_translation)
# Out:
#         "Малиновый курд": {
#             ru: "Малиновый курд",
#             en: "Raspberry Curd"
#             },

# %% [markdown]
# ### 5. Затем в этом же файле вставляем в конце в разделе recipeDetails:

# %%
print(recipedetail_new_text)
# Out:
#         "sauce_raspberry_curd":  {
#             ru: {
#                 title: "Малиновый курд",
#                 meta:  {
#                     time: "30 мин",
#                     servings: "200 - 220 г"
#                   },
#                 ingredients: [
#                 "150 г малины (свежей или замороженной)",
# "2 яйца",
# "50 г сахара",
# "30 сливочного масла",
# "2 ст.л. лимонного сока",
#
#                 ],
#                 instructions: [
#                 "Пробейте блендером малину и протрите через сито, чтобы удалить косточки.",
# "Взбейте яйца с половиной сахара.",
# "В кастрюлю выложите малиновое пюре, лимонный сок и вторую половину сахара. Нагрейте почти до кипения.",
# "Осторожно, постоянно помешивая яйца, влейте 1/3 горячего малинового пюре в яичную смесь. Эта процедура нужна, чтобы яйца не свернулись.",
# "Тонкой струйкой, постоянно помешивая, влейте темперированную яичную смесь обратно в оставшееся пюре и, не переставая мешать, варите на очень медленном огне до появления характерных пыхов (как у заварного крема), то есть до загустения.",
# "Слегка остудите крем, добавьте кусочки мягкого сливочного масла и очень хорошо взбейте венчиком.",
# "Накройте пищевой пленкой так, чтобы она касалась поверхности крема, оставьте до полного остывания.",
#
#                 ],
#                 note: "Отличная начинка для для <a href='dessert_napoleon_cake.html' class='elegant-link keep-link'>dessert_cupcake_creamchease_straberry_jam</a> или как добавка к <a href='breakfast_oat_porridge.html' class='elegant-link keep-link'>овсяной каше</a>."
#              },
#             en: {
#                 title: "Raspberry Curd",
#                 meta:  {
#                     time: "30 minutes",
#                     servings: "200 - 220 g"
#                   },
#                 ingredients: [
#                 "150 g raspberries (fresh or frozen)",
# "2 eggs",
# "50 g sugar",
# "30 g butter",
# "2 tbsp lemon juice",
#
#                 ],
#                 instructions: [
#                 "Blend the raspberries and strain the puree through a sieve to remove the seeds.",
# "Whisk the eggs with half of the sugar.",
# "In a saucepan, combine the raspberry puree, lemon juice, and the remaining sugar. Heat until just below boiling.",
# "Carefully temper the eggs: while constantly whisking the egg mixture, slowly pour in about one-third of the hot raspberry puree. This prevents the eggs from curdling.",
# "In a thin stream, pour the tempered egg mixture back into the remaining puree, stirring constantly. Cook over very low heat until it thickens and begins to release gentle bubbles, similar to custard.",
# "Let the cream cool slightly, then add the softened butter in pieces and whisk thoroughly until smooth.",
# "Cover with plastic wrap touching the surface of the cream and leave to cool completely.",
#
#                 ],
#                 note: "A wonderful filling for <a href='dessert_napoleon_cake.html' class='elegant-link keep-link'>cupcakes with cream cheese and strawberry jam</a> or as an addition to <a href='breakfast_oat_porridge.html' class='elegant-link keep-link'>oatmeal</a>."
#              }
#         },

# %% [markdown]
# ### 6. На последнем этапе в файл script.js d поискать много else if и в конце добавить следующее:

# %%
print(sript_js_add)
# Out:
#  else if (path.includes('sauce_raspberry_curd')) {
# recipeKey = 'sauce_raspberry_curd';
# }
