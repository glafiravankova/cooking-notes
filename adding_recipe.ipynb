# %%
recipe_id_name = "dessert_profiterol"

recipe_ru_name = "Профитроли с заварным кремом"
recipe_time_ru = "150 мин"
recipe_portion_ru = "15 порций"
ingredients_ru = [
    "Для теста:"
    "150 г муки",
    "250 г воды",
    "100 г сливочного масла",
    "4–6 штук яиц (в зависимости от размера)",
    "1 щепотка соли",
    "5 г сахарной пудры (для посыпки)",
    "Для крема:"
    "500 мл молока",
    "2 яйца",
    "50 г крахмала (или 40 г муки)",
    "150 г сахара",
    "100 г сливочного масла",
    "10 г ванильного сахара"
]

instruction_ru = [
"Начните с теста. Налейте воду в кастрюлю, добавьте сливочное масло и соль, доведите до кипения, помешивая, пока масло не растает",
"Всыпьте сразу всю муку и перемешивайте, пока не исчезнут комочки",
"Варите тесто на слабом огне около 3 минут, постоянно помешивая, затем снимите с огня и дайте немного остыть, примерно до 70°C",
"Добавляйте яйца по одному, тщательно вымешивая после каждого до получения однородной массы. Первые 3 яйца вмешивайте без сомнений; начиная с 4-го ориентируйтесь по консистенции. Тесто должно падать с лопатки широкой гладкой лентой, не разрываясь, а образовавшиеся пики медленно оседать. Если тесто слишком густое и не стекает, продолжайте добавлять яйца, пока не достигнете нужной консистенции",
"Разогрейте духовку до 200°C. Переложите тесто в кондитерский мешок с насадкой или в бумажный корнетик с отрезанным кончиком",
"Выпекайте профитроли при 200°C в течение 15 минут, затем уменьшите температуру до 180°C и выпекайте еще 20 минут. НЕ ОТКРЫВАЙТЕ ДУХОВКУ ПЕРВЫЕ 15 МИНУТ",
"Перейдите к приготовлению крема. В небольшой кастрюльке венчиком взбейте муку, сахар, ванильный сахар и яйца до однородности",
"Постепенно влейте небольшое количество молока, тщательно взбивая, чтобы не было комочков",
"Продолжайте вливать оставшееся молоко, взбивая смесь до полной однородности",
"Поставьте кастрюльку на слабый огонь. Варите, постоянно помешивая, особенно по дну, чтобы не образовались комочки",
"Как только крем загустеет и начнет закипать, снимите его с огня",
"Добавьте размягченное сливочное масло в горячий крем и мешайте, пока оно полностью не растает и не вмешается",
"Переложите крем в широкую миску для более быстрого остывания. Накройте пищевой пленкой «в контакт», чтобы не образовалась корочка. Дайте остыть в течение 2–3 часов",
"Наполните профитроли кремом: либо разрежьте их, отсадите крем и накройте верхушками, либо сделайте маленькое отверстие и отсадите начинку внутрь"
]

note_ru = ""

recipe_eng_name = "Creamy Mushroom Soup"
recipe_time_eng = "45 minutes"
recipe_portion_eng = "Serves 4"

ingredients_eng = [
    "700-1000 g chicken (preferably bone-in)",
    "1 onion",
    "1 carrot",
    "1 bunch of dill",
    "5 peppercorns",
    "Salt to taste"
]

instruction_eng = [
    "Place the chicken in a big pot and cover with cold water.",
    "Set over high heat and bring to a boil.",
    "Skim off any foam that rises to the surface.",
    "Add the salt, peppercorns, dill, peeled carrot, and onion. Reduce the heat so the broth simmers gently.",
    "Cover with a lid and cook for 1-1.5 hours.",
    "Once the broth is ready, remove the onion, carrot, and herbs (if used).",
    "Lift out the chicken, allow it to cool slightly, then separate the meat from the bones. Slice or shred and return the meat to the broth (or store separately if preparing ahead).",
    "If you plan to add vermicelli or potatoes, pour the required amount of broth into a separate saucepan — only as much as you intend to serve now.",
    "Bring the broth to a boil. Add vermicelli (about 20 g per serving) or diced potatoes (1 medium potato per serving).",
    "Cook until done: vermicelli according to the package instructions; potatoes until tender and easily pierced with a fork."
]

note_eng = "For crisp croutons, cut the bread into cubes. Combine olive oil with finely minced garlic, drizzle over the bread, and dry in the oven at 180°C for about 10 minutes."

# %% [markdown]
# # Организационные вопросики

# %%
index_html_output = f'''
                    <!-- Рецепт {recipe_ru_name} -->
                    <a href="recipes/{recipe_id_name}.html" class="recipe-card"> 
                        <div class="recipe-image">
                            <img src="site-photos/{recipe_id_name}.jpg" alt="{recipe_ru_name}"> 
                            <div class="recipe-overlay">
                                <i class="fas fa-external-link-alt"></i>
                            </div>
                        </div>
                        <div class="recipe-info">
                            <h3>{recipe_ru_name}</h3> 
                            <p class="recipe-time"><i class="far fa-clock"></i> {recipe_time_ru} </p> 
                        </div>
                    </a>
                    <!-- Рецепт {recipe_ru_name} конец -->
                    
                    '''

# %%
ingredients_spin_new_html = ''
for ing_list_length in ingredients_ru:
    ingredients_spin_new_html += "<li>" + ing_list_length + "</li> \n"

instruction_spin_new_html = ''
for inst_list_length in instruction_ru:
    instruction_spin_new_html += "<li>" + inst_list_length + "</li> \n"

# %%
if note_ru != '':
    notes_new_html = f'''
                <div class="note">
                <p><strong>Совет:</strong> {note_ru} </p>
                </div>'''
else:
    notes_new_html = ''

# %%
print(ingredients_spin_new_html)
print(instruction_spin_new_html)
# Out:
# <li>400 г шампиньонов</li>
# <li>300 г картофеля</li>
# <li>600 мл воды или куриного бульона</li>
# <li>200 мл сливок (20%)</li>
# <li>1 луковица</li>
# <li>20 г сливочного масла</li>
# <li>10 мл растительного масла</li>
# <li>Соль, перец по вкусу</li>
#
# <li>Очистите картофель и нарежьте небольшими кубиками - так он сварится быстрее.</li>
# <li>Залейте картофель водой, поставьте на максимальный огонь и доведите до кипения.</li>
# <li>После закипания посолите, убавьте огонь и варите до мягкости (картофель должен легко протыкаться вилкой). Воду от картофеля слейте.</li>
# <li>Тем временем очистите шампиньоны. Удобнее всего делать это с помощью небольшой щетки (пригодится старая зубная щетка).</li>
# <li>В сковороде разогрейте растительное масло, добавьте сливочное. Обжарьте мелко нарезанный лук до прозрачности.</li>
# <li>Добавьте к луку нарезанные шампиньоны. Жарьте на сильном огне, пока не выпарится вся жидкость, а грибы не подрумянятся. На этом этапе не солите - иначе грибы пустят сок и начнут тушиться.</li>
# <li>Переложите обжаренные грибы к картофелю, влейте воду или бульон и прогрейте массу.</li>
# <li>Измельчите суп погружным блендером до состояния гладкого пюре.</li>
# <li>Посолите, поперчите по вкусу и влейте сливки.</li>
# <li>Поставьте суп на самый маленький огонь и прогревайте, постоянно помешивая, 2-3 минуты. Как только появятся первые пузырьки - суп готов.</li>

# %%
styler_text = '''<style>
        .recipe-page {
            max-width: 800px;
            margin: 40px auto;
            padding: 0 20px;
        }
        
        .back-link {
            display: inline-flex;
            align-items: center;
            gap: 8px;
            color: #8b4513;
            text-decoration: none;
            margin-bottom: 20px;
            font-weight: 500;
        }
        
        .back-link:hover {
            text-decoration: underline;
        }
        
        .recipe-header {
            text-align: center;
            margin-bottom: 40px;
        }
        
        .recipe-header h1 {
            color: #8b4513;
            font-size: 2.5rem;
            margin-bottom: 10px;
        }
        
        .recipe-meta {
            display: flex;
            justify-content: center;
            gap: 30px;
            color: #666;
            margin-bottom: 30px;
        }
        
        .recipe-image-main {
            width: 100%;
            height: 400px;
            object-fit: cover;
            border-radius: 15px;
            margin-bottom: 30px;
            box-shadow: 0 10px 25px rgba(0, 0, 0, 0.1);
        }
        
        .recipe-content {
            background: white;
            padding: 40px;
            border-radius: 15px;
            box-shadow: 0 5px 20px rgba(0, 0, 0, 0.05);
        }
        
        .ingredients, .instructions {
            margin-bottom: 40px;
        }
        
        .ingredients h2, .instructions h2 {
            color: #8b4513;
            border-bottom: 2px solid #f0e6d6;
            padding-bottom: 10px;
            margin-bottom: 20px;
        }
        
        .ingredients ul {
            list-style: none;
            padding: 0;
        }
        
        .ingredients li {
            padding: 8px 0;
            padding-left: 30px;
            position: relative;
            border-bottom: 1px solid #f0e6d6;
        }
        
        .ingredients li:before {
            content: "•";
            position: absolute;
            left: 0;
        }
        
        .instructions ol {
            padding-left: 20px;
        }
        
        .instructions li {
            margin-bottom: 15px;
            line-height: 1.6;
        }
        
        .note {
            background: #f9f3ec;
            padding: 20px;
            border-radius: 10px;
            border-left: 4px solid #d4a574;
            margin-top: 30px;
        }
    </style>'''

# %%
new_html_page_output = f'''
<!DOCTYPE html>
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>{recipe_ru_name} - Кулинарные заметки</title>
    <!-- Favicon (иконка вкладки) -->
    <link rel="icon" href="../assets/icons/icons8-girl-64.png" type="image/png">
    <link rel="stylesheet" href="../style.css">
    <script src="../script.js" defer></script>
    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css">
    {styler_text}
</head>
<body>
    <header class="main-header">
        <div class="header-top"> 
            <h1>Кулинарные заметки</h1>
        </div>
    </header>

    <main class="recipe-page">
        <a href="../index.html" class="back-link">
            <i class="fas fa-arrow-left"></i>
            Вернуться к рецептам
        </a>
        
        <div class="recipe-header">
            <h1>{recipe_ru_name}</h1>
            <div class="recipe-meta">
                <span><i class="far fa-clock"></i> {recipe_time_ru}</span>
                <span><i class="fas fa-user-friends"></i> {recipe_portion_ru}</span>
                
            </div>
        </div>
        
        <img src="../site-photos/{recipe_id_name}.jpg" 
             alt="{recipe_ru_name}" class="recipe-image-main">
        
        <div class="recipe-content">
            <div class="ingredients">
                <h2><i class="fas fa-shopping-basket"></i> Ингредиенты</h2>
                <ul>
                    {ingredients_spin_new_html}
                    

                </ul>
            </div>
            
            <div class="instructions">
                <h2><i class="fas fa-list-ol"></i> Способ приготовления</h2>
                <ol>
                    {instruction_spin_new_html}
                </ol>
            </div>
            
            {notes_new_html}
            
        </div>
    </main>

    <footer class="main-footer">
        <div class="footer-content">
            <div class="footer-lang-switcher">
                <button class="footer-lang-btn active" data-lang="ru">RU</button>
                <button class="footer-lang-btn" data-lang="en">EN</button>
            </div>
            <p>2026 Кулинарные заметки</p>
            <p class="footer-note">С любовью к вкусной еде ❤️</p>
        </div>
    </footer>

    <script src="../translations.js" defer></script>
    <script src="../script.js" defer></script>
</body>
</html>'''

# %%
meal_name_translation = f'''
        "{recipe_ru_name}": '''
meal_name_translation += '''{ '''
meal_name_translation += f''' 
            ru: "{recipe_ru_name}",
            en: "{recipe_eng_name}"'''
meal_name_translation += '''
            },'''

# %%
ingredient_shift_ru = ''
for ingredient_list in ingredients_ru:
    ingredient_shift_ru += '"' + ingredient_list + '", \n'

instruction_shift_ru = ''
for instruction_list in instruction_ru:
    instruction_shift_ru += '"' + instruction_list + '", \n'

ingredient_shift_eng = ''
for ingredient_list in ingredients_eng:
    ingredient_shift_eng += '"' + ingredient_list + '", \n'

instruction_shift_eng = ''
for instruction_list in instruction_eng:
    instruction_shift_eng += '"' + instruction_list + '", \n'

# %%
recipedetail_new_text = f'''
        "{recipe_id_name}": '''

recipedetail_new_text += ''' {
            ru: {
                title:'''
recipedetail_new_text += f''' "{recipe_ru_name}",
                meta: '''
recipedetail_new_text += ''' {
                    time: '''
recipedetail_new_text += f'''"{recipe_time_ru}",
                    servings: "{recipe_portion_ru}"
                 '''       
recipedetail_new_text += ''' },
                ingredients: [
                '''    
recipedetail_new_text += f'''{ingredient_shift_ru}
                ],
                instructions: [
                {instruction_shift_ru}
                ],
                note: "{note_ru}"
            '''     
recipedetail_new_text += ''' },
            en: {
                title:'''
recipedetail_new_text += f''' "{recipe_eng_name}",
                meta: '''
recipedetail_new_text += ''' {
                    time: '''
recipedetail_new_text += f'''"{recipe_time_eng}",
                    servings: "{recipe_portion_eng}"
                 '''       
recipedetail_new_text += ''' },
                ingredients: [
                '''    
recipedetail_new_text += f'''{ingredient_shift_eng}
                ],
                instructions: [
                {instruction_shift_eng}
                ],
                note: "{note_eng}"
            '''     
recipedetail_new_text += ''' }
        },'''

# %%
sript_js_add = f""" else if (path.includes('{recipe_id_name}')) """
sript_js_add += '''{
'''
sript_js_add += f"""recipeKey = '{recipe_id_name}';
"""
sript_js_add += '''}'''

# %% [markdown]
# # Добавление рецепта

# %% [markdown]
# ### 1. Добавляем в соответствующем месте в index.html следующее:

# %%
print(index_html_output)
# Out:
#                     <!-- Рецепт Крем-суп из шампиньонов -->
#                     <a href="recipes/soup_creamy_mashroom_soup.html" class="recipe-card">
#                         <div class="recipe-image">
#                             <img src="site-photos/soup_creamy_mashroom_soup.jpg" alt="Крем-суп из шампиньонов">
#                             <div class="recipe-overlay">
#                                 <i class="fas fa-external-link-alt"></i>
#                             </div>
#                         </div>
#                         <div class="recipe-info">
#                             <h3>Крем-суп из шампиньонов</h3>
#                             <p class="recipe-time"><i class="far fa-clock"></i> 45 мин </p>
#                         </div>
#                     </a>
#                     <!-- Рецепт Крем-суп из шампиньонов конец -->

# %% [markdown]
# ### 2.Далее создаем файл с названием:

# %%
print(recipe_id_name+'.html')
# Out:
# soup_creamy_mashroom_soup.html

# %% [markdown]
# ### 3. В новый файл вставляем следующее:

# %%
print(new_html_page_output)
# Out:
# <!DOCTYPE html>
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Крем-суп из шампиньонов - Кулинарные заметки</title>
#     <!-- Favicon (иконка вкладки) -->
#     <link rel="icon" href="../assets/icons/icons8-girl-64.png" type="image/png">
#     <link rel="stylesheet" href="../style.css">
#     <script src="../script.js" defer></script>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css">
#     <style>
#         .recipe-page {
#             max-width: 800px;
#             margin: 40px auto;
#             padding: 0 20px;
#         }
#
#         .back-link {
#             display: inline-flex;
#             align-items: center;
#             gap: 8px;
#             color: #8b4513;
#             text-decoration: none;
#             margin-bottom: 20px;
#             font-weight: 500;
#         }
#
#         .back-link:hover {
#             text-decoration: underline;
#         }
#
#         .recipe-header {
#             text-align: center;
#             margin-bottom: 40px;
#         }
#
#         .recipe-header h1 {
#             color: #8b4513;
#             font-size: 2.5rem;
#             margin-bottom: 10px;
#         }
#
#         .recipe-meta {
#             display: flex;
#             justify-content: center;
#             gap: 30px;
#             color: #666;
#             margin-bottom: 30px;
#         }
#
#         .recipe-image-main {
#             width: 100%;
#             height: 400px;
#             object-fit: cover;
#             border-radius: 15px;
#             margin-bottom: 30px;
#             box-shadow: 0 10px 25px rgba(0, 0, 0, 0.1);
#         }
#
#         .recipe-content {
#             background: white;
#             padding: 40px;
#             border-radius: 15px;
#             box-shadow: 0 5px 20px rgba(0, 0, 0, 0.05);
#         }
#
#         .ingredients, .instructions {
#             margin-bottom: 40px;
#         }
#
#         .ingredients h2, .instructions h2 {
#             color: #8b4513;
#             border-bottom: 2px solid #f0e6d6;
#             padding-bottom: 10px;
#             margin-bottom: 20px;
#         }
#
#         .ingredients ul {
#             list-style: none;
#             padding: 0;
#         }
#
#         .ingredients li {
#             padding: 8px 0;
#             padding-left: 30px;
#             position: relative;
#             border-bottom: 1px solid #f0e6d6;
#         }
#
#         .ingredients li:before {
#             content: "•";
#             position: absolute;
#             left: 0;
#         }
#
#         .instructions ol {
#             padding-left: 20px;
#         }
#
#         .instructions li {
#             margin-bottom: 15px;
#             line-height: 1.6;
#         }
#
#         .note {
#             background: #f9f3ec;
#             padding: 20px;
#             border-radius: 10px;
#             border-left: 4px solid #d4a574;
#             margin-top: 30px;
#         }
#     </style>
# </head>
# <body>
#     <header class="main-header">
#         <div class="header-top">
#             <h1>Кулинарные заметки</h1>
#         </div>
#     </header>
#
#     <main class="recipe-page">
#         <a href="../index.html" class="back-link">
#             <i class="fas fa-arrow-left"></i>
#             Вернуться к рецептам
#         </a>
#
#         <div class="recipe-header">
#             <h1>Крем-суп из шампиньонов</h1>
#             <div class="recipe-meta">
#                 <span><i class="far fa-clock"></i> 45 мин</span>
#                 <span><i class="fas fa-user-friends"></i> 4 порции</span>
#
#             </div>
#         </div>
#
#         <img src="../site-photos/soup_creamy_mashroom_soup.jpg"
#              alt="Крем-суп из шампиньонов" class="recipe-image-main">
#
#         <div class="recipe-content">
#             <div class="ingredients">
#                 <h2><i class="fas fa-shopping-basket"></i> Ингредиенты</h2>
#                 <ul>
#                     <li>400 г шампиньонов</li>
# <li>300 г картофеля</li>
# <li>600 мл воды или куриного бульона</li>
# <li>200 мл сливок (20%)</li>
# <li>1 луковица</li>
# <li>20 г сливочного масла</li>
# <li>10 мл растительного масла</li>
# <li>Соль, перец по вкусу</li>
#
#
#
#                 </ul>
#             </div>
#
#             <div class="instructions">
#                 <h2><i class="fas fa-list-ol"></i> Способ приготовления</h2>
#                 <ol>
#                     <li>Очистите картофель и нарежьте небольшими кубиками - так он сварится быстрее.</li>
# <li>Залейте картофель водой, поставьте на максимальный огонь и доведите до кипения.</li>
# <li>После закипания посолите, убавьте огонь и варите до мягкости (картофель должен легко протыкаться вилкой). Воду от картофеля слейте.</li>
# <li>Тем временем очистите шампиньоны. Удобнее всего делать это с помощью небольшой щетки (пригодится старая зубная щетка).</li>
# <li>В сковороде разогрейте растительное масло, добавьте сливочное. Обжарьте мелко нарезанный лук до прозрачности.</li>
# <li>Добавьте к луку нарезанные шампиньоны. Жарьте на сильном огне, пока не выпарится вся жидкость, а грибы не подрумянятся. На этом этапе не солите - иначе грибы пустят сок и начнут тушиться.</li>
# <li>Переложите обжаренные грибы к картофелю, влейте воду или бульон и прогрейте массу.</li>
# <li>Измельчите суп погружным блендером до состояния гладкого пюре.</li>
# <li>Посолите, поперчите по вкусу и влейте сливки.</li>
# <li>Поставьте суп на самый маленький огонь и прогревайте, постоянно помешивая, 2-3 минуты. Как только появятся первые пузырьки - суп готов.</li>
#
#                 </ol>
#             </div>
#
#
#                 <div class="note">
#                 <p><strong>Совет:</strong> Для хрустящих гренок нарежьте хлеб кубиками, смешайте оливковое масло с измельченным чесноком, сбрызните хлеб и подсушите в духовке при 180°C около 10 минут. </p>
#                 </div>
#
#         </div>
#     </main>
#
#     <footer class="main-footer">
#         <div class="footer-content">
#             <div class="footer-lang-switcher">
#                 <button class="footer-lang-btn active" data-lang="ru">RU</button>
#                 <button class="footer-lang-btn" data-lang="en">EN</button>
#             </div>
#             <p>2026 Кулинарные заметки</p>
#             <p class="footer-note">С любовью к вкусной еде ❤️</p>
#         </div>
#     </footer>
#
#     <script src="../translations.js" defer></script>
#     <script src="../script.js" defer></script>
# </body>
# </html>

# %% [markdown]
# ### 4. В файл translations.js добавляем в раздел с названиями блюд:

# %%
print(meal_name_translation)
# Out:
#         "Крем-суп из шампиньонов": {
#             ru: "Крем-суп из шампиньонов",
#             en: "Creamy Mushroom Soup"
#             },

# %% [markdown]
# ### 5. Затем в этом же файле вставляем в конце в разделе recipeDetails:

# %%
print(recipedetail_new_text)
# Out:
#         "soup_creamy_mashroom_soup":  {
#             ru: {
#                 title: "Крем-суп из шампиньонов",
#                 meta:  {
#                     time: "45 мин",
#                     servings: "4 порции"
#                   },
#                 ingredients: [
#                 "400 г шампиньонов",
# "300 г картофеля",
# "600 мл воды или куриного бульона",
# "200 мл сливок (20%)",
# "1 луковица",
# "20 г сливочного масла",
# "10 мл растительного масла",
# "Соль, перец по вкусу",
#
#                 ],
#                 instructions: [
#                 "Очистите картофель и нарежьте небольшими кубиками - так он сварится быстрее.",
# "Залейте картофель водой, поставьте на максимальный огонь и доведите до кипения.",
# "После закипания посолите, убавьте огонь и варите до мягкости (картофель должен легко протыкаться вилкой). Воду от картофеля слейте.",
# "Тем временем очистите шампиньоны. Удобнее всего делать это с помощью небольшой щетки (пригодится старая зубная щетка).",
# "В сковороде разогрейте растительное масло, добавьте сливочное. Обжарьте мелко нарезанный лук до прозрачности.",
# "Добавьте к луку нарезанные шампиньоны. Жарьте на сильном огне, пока не выпарится вся жидкость, а грибы не подрумянятся. На этом этапе не солите - иначе грибы пустят сок и начнут тушиться.",
# "Переложите обжаренные грибы к картофелю, влейте воду или бульон и прогрейте массу.",
# "Измельчите суп погружным блендером до состояния гладкого пюре.",
# "Посолите, поперчите по вкусу и влейте сливки.",
# "Поставьте суп на самый маленький огонь и прогревайте, постоянно помешивая, 2-3 минуты. Как только появятся первые пузырьки - суп готов.",
#
#                 ],
#                 note: "Для хрустящих гренок нарежьте хлеб кубиками, смешайте оливковое масло с измельченным чесноком, сбрызните хлеб и подсушите в духовке при 180°C около 10 минут."
#              },
#             en: {
#                 title: "Creamy Mushroom Soup",
#                 meta:  {
#                     time: "45 minutes",
#                     servings: "Serves 4"
#                   },
#                 ingredients: [
#                 "700-1000 g chicken (preferably bone-in)",
# "1 onion",
# "1 carrot",
# "1 bunch of dill",
# "5 peppercorns",
# "Salt to taste",
#
#                 ],
#                 instructions: [
#                 "Place the chicken in a big pot and cover with cold water.",
# "Set over high heat and bring to a boil.",
# "Skim off any foam that rises to the surface.",
# "Add the salt, peppercorns, dill, peeled carrot, and onion. Reduce the heat so the broth simmers gently.",
# "Cover with a lid and cook for 1-1.5 hours.",
# "Once the broth is ready, remove the onion, carrot, and herbs (if used).",
# "Lift out the chicken, allow it to cool slightly, then separate the meat from the bones. Slice or shred and return the meat to the broth (or store separately if preparing ahead).",
# "If you plan to add vermicelli or potatoes, pour the required amount of broth into a separate saucepan — only as much as you intend to serve now.",
# "Bring the broth to a boil. Add vermicelli (about 20 g per serving) or diced potatoes (1 medium potato per serving).",
# "Cook until done: vermicelli according to the package instructions; potatoes until tender and easily pierced with a fork.",
#
#                 ],
#                 note: "For crisp croutons, cut the bread into cubes. Combine olive oil with finely minced garlic, drizzle over the bread, and dry in the oven at 180°C for about 10 minutes."
#              }
#         },

# %% [markdown]
# ### 6. На последнем этапе в файл script.js d поискать много else if и в конце добавить следующее:

# %%
print(sript_js_add)
# Out:
#  else if (path.includes('soup_creamy_mashroom_soup')) {
# recipeKey = 'soup_creamy_mashroom_soup';
# }
